# %%
import os
import numpy as np
from ncempy.io import dm
import tifffile as tiff

# 입력 폴더와 출력 폴더 경로
input_folder = r"D:\Users\doyeob\Desktop\3layerBP data\fitting using gatan\ring\dm4"
output_folder = r"D:\Users\doyeob\Desktop\3layerBP data\fitting using gatan\ring"
# 출력 폴더가 없으면 생성
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# 입력 폴더 내 모든 DM4 파일에 대해 작업 수행
for filename in os.listdir(input_folder):
    if filename.endswith('.dm4'):
        input_dm4_file = os.path.join(input_folder, filename)
        output_tiff_file = os.path.join(output_folder, f'{os.path.splitext(filename)[0]}.tif')

        # DM4 파일 읽기
        dm4_data = dm.fileDM(input_dm4_file)

        # DM4 데이터 내용 확인
        print(f"Processing {filename}...")

        # 모든 메타데이터와 키를 출력하여 구조 파악
        dm4_metadata = dm4_data.allTags
        for key, value in dm4_metadata.items():
            print(f"{key}: {value}")

        # 데이터셋 이름을 사용하여 데이터 추출
        try:
            dataset = dm4_data.getDataset(0)  # 첫 번째 데이터셋 접근
            image_data = dataset['data']      # 데이터 추출

            # TIFF 파일로 저장 (그레이 스케일)
            tiff.imwrite(output_tiff_file, image_data.astype(np.float32), photometric='minisblack')
            print(f"Saved {output_tiff_file}")

        except Exception as e:
            print(f"Failed to process {filename}: {e}")

print("모든 DM4 파일이 TIFF 파일로 성공적으로 변환되었습니다.")
# Out:
# Processing Amplitude (Gaussian 1).dm4...
# .ApplicationBounds: [   0.    0.  928. 1174.]
# .BackgroundColor: [-2571. -2571. -1286.]
# .DocumentObjectList.1.AnnotationGroupList.1.AnnotationType: 13
# .DocumentObjectList.1.AnnotationGroupList.1.BackgroundColor: [-1. -1. -1.]
# .DocumentObjectList.1.AnnotationGroupList.1.BackgroundMode: 2
# .DocumentObjectList.1.AnnotationGroupList.1.FillMode: 2
# .DocumentObjectList.1.AnnotationGroupList.1.FixedPoint: [0. 0.]
# .DocumentObjectList.1.AnnotationGroupList.1.ForegroundColor: [-1. -1.  0.]
# .DocumentObjectList.1.AnnotationGroupList.1.HasBackground: 0
# .DocumentObjectList.1.AnnotationGroupList.1.IsMoveable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsResizable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsSelectable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsTransferrable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsTranslatable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsVisible: 1
# .DocumentObjectList.1.AnnotationGroupList.1.ObjectTags.LSFITMapLabel: 1
# .DocumentObjectList.1.AnnotationGroupList.1.Rectangle: [ 32.82500076   0.          53.61912155 139.61764526]
# .DocumentObjectList.1.AnnotationGroupList.1.ResizeStyle: 48
# .DocumentObjectList.1.AnnotationGroupList.1.RestrictionStyle: 0
# .DocumentObjectList.1.AnnotationGroupList.1.Text: Amplitude (Gaussian 1)
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.DrawingMode: 2
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.FontAttributes: 7
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.FontFaceName: 굴림체
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.FontSize: 11.882353782653809
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.Justification: 3
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.ScreenSize: [94. 14.]
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.TextLength: 22
# .DocumentObjectList.1.AnnotationGroupList.1.Transparency: 0.0
# .DocumentObjectList.1.AnnotationGroupList.1.UniqueID: 10
# .DocumentObjectList.1.AnnotationType: 20
# .DocumentObjectList.1.BackgroundColor: [-1. -1. -1.]
# .DocumentObjectList.1.BackgroundMode: 2
# .DocumentObjectList.1.FillMode: 1
# .DocumentObjectList.1.ForegroundColor: [0. 0. 0.]
# .DocumentObjectList.1.HasBackground: 0
# .DocumentObjectList.1.ImageDisplayInfo.BrightColor: [-1. -1. -1.]
# .DocumentObjectList.1.ImageDisplayInfo.Brightness: 0.5
# .DocumentObjectList.1.ImageDisplayInfo.CaptionOn: 0
# .DocumentObjectList.1.ImageDisplayInfo.CaptionSize: 10
# .DocumentObjectList.1.ImageDisplayInfo.CLUT.arraySize: 1536
# .DocumentObjectList.1.ImageDisplayInfo.CLUT.arrayOffset: 2931
# .DocumentObjectList.1.ImageDisplayInfo.CLUT.arrayType: 2.0
# .DocumentObjectList.1.ImageDisplayInfo.CLUT: Array unread. Encoded type = 2.0
# .DocumentObjectList.1.ImageDisplayInfo.CLUTName: Greyscale
# .DocumentObjectList.1.ImageDisplayInfo.ComplexMode: 4
# .DocumentObjectList.1.ImageDisplayInfo.ComplexRange: 1000.0
# .DocumentObjectList.1.ImageDisplayInfo.Contrast: 0.5
# .DocumentObjectList.1.ImageDisplayInfo.ContrastMode: 1
# .DocumentObjectList.1.ImageDisplayInfo.DiffractionMode: 0
# .DocumentObjectList.1.ImageDisplayInfo.DoAutoSurvey: 1
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMax: -424299.53125
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMaxTrimPercentage: 0.0010000000474974513
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMin: 1925188.875
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMinTrimPercentage: 0.0010000000474974513
# .DocumentObjectList.1.ImageDisplayInfo.Gamma: 0.5
# .DocumentObjectList.1.ImageDisplayInfo.HighLimit: 1925188.875
# .DocumentObjectList.1.ImageDisplayInfo.HiLimitContrastDeltaTriggerPercentage: 0.10000000149011612
# .DocumentObjectList.1.ImageDisplayInfo.IsIgnoreGirdBar: 0
# .DocumentObjectList.1.ImageDisplayInfo.IsInverted: 0
# .DocumentObjectList.1.ImageDisplayInfo.LowLimit: -424299.53125
# .DocumentObjectList.1.ImageDisplayInfo.LowLimitContrastDeltaTriggerPercentage: 0.10000000149011612
# .DocumentObjectList.1.ImageDisplayInfo.MainSliceId.1: 0
# .DocumentObjectList.1.ImageDisplayInfo.MinimumContrast: 0.0
# .DocumentObjectList.1.ImageDisplayInfo.RangeAdjust: 1.0
# .DocumentObjectList.1.ImageDisplayInfo.SparseSurvey_GridSize: 32
# .DocumentObjectList.1.ImageDisplayInfo.SparseSurvey_NumberPixels: 64
# .DocumentObjectList.1.ImageDisplayInfo.SparseSurvey_UseNumberPixels: 1
# .DocumentObjectList.1.ImageDisplayInfo.SurveyTechique: 2
# .DocumentObjectList.1.ImageDisplayType: 1
# .DocumentObjectList.1.ImageSource: 0
# .DocumentObjectList.1.IsMoveable: 1
# .DocumentObjectList.1.IsResizable: 1
# .DocumentObjectList.1.IsSelectable: 1
# .DocumentObjectList.1.IsTransferrable: 1
# .DocumentObjectList.1.IsTranslatable: 1
# .DocumentObjectList.1.IsVisible: 1
# .DocumentObjectList.1.Rectangle: [  0.           0.         884.           6.73267317]
# .DocumentObjectList.1.RestrictionStyle: 0
# .DocumentObjectList.1.Transparency: 0.0
# .DocumentObjectList.1.UniqueID: 8
# .HasWindowPosition: 1
# .Image Behavior.ImageDisplayBounds: [  0.           0.         884.           6.73267317]
# .Image Behavior.IsZoomedToWindow: 1
# .Image Behavior.UnscaledTransform.Offset: [0. 0.]
# .Image Behavior.UnscaledTransform.Scale: [1. 1.]
# .Image Behavior.ViewDisplayID: 8
# .Image Behavior.WindowRect: [  0.   0. 884.   9.]
# .Image Behavior.ZoomAndMoveTransform.Offset: [1.13366342 0.        ]
# .Image Behavior.ZoomAndMoveTransform.Scale: [1. 1.]
# .ImageList.1.ImageData.Calibrations.Brightness.Label:
# .ImageList.1.ImageData.Calibrations.Brightness.Origin: 0.0
# .ImageList.1.ImageData.Calibrations.Brightness.Scale: 1.0
# .ImageList.1.ImageData.Calibrations.Brightness.Units:
# .ImageList.1.ImageData.Calibrations.Dimension.1.Label:
# .ImageList.1.ImageData.Calibrations.Dimension.1.Origin: 0.0
# .ImageList.1.ImageData.Calibrations.Dimension.1.Scale: 1.0
# .ImageList.1.ImageData.Calibrations.Dimension.1.Units:
# .ImageList.1.ImageData.Calibrations.Dimension.2.Label:
# .ImageList.1.ImageData.Calibrations.Dimension.2.Origin: 0.0
# .ImageList.1.ImageData.Calibrations.Dimension.2.Scale: 1.0
# .ImageList.1.ImageData.Calibrations.Dimension.2.Units:
# .ImageList.1.ImageData.Calibrations.DisplayCalibratedUnits: 1
# .ImageList.1.ImageData.Data.arraySize: 62976
# .ImageList.1.ImageData.Data.arrayOffset: 8276
# .ImageList.1.ImageData.Data.arrayType: 3
# .ImageList.1.ImageData.Data: Data unread. Encoded type = 3
# .ImageList.1.ImageData.DataType: 23
# .ImageList.1.ImageData.Dimensions.1: 41
# .ImageList.1.ImageData.Dimensions.2: 384
# .ImageList.1.ImageData.PixelDepth: 4
# .ImageList.1.ImageTags.GMS Version.Created: 3.60.4441.0
# .ImageList.1.Name: Image Of Amplitude (Gaussian 1)
# .ImageList.1.UniqueID.1: 1760901114
# .ImageList.1.UniqueID.2: 2062171620
# .ImageList.1.UniqueID.3: 355796401
# .ImageList.1.UniqueID.4: 2051897530
# .ImageList.2.ImageData.Calibrations.Brightness.Label:
# .ImageList.2.ImageData.Calibrations.Brightness.Origin: 0.0
# .ImageList.2.ImageData.Calibrations.Brightness.Scale: 1.0
# .ImageList.2.ImageData.Calibrations.Brightness.Units:
# .ImageList.2.ImageData.Calibrations.Dimension.1.Label:
# .ImageList.2.ImageData.Calibrations.Dimension.1.Origin: 0.0
# .ImageList.2.ImageData.Calibrations.Dimension.1.Scale: 1.0
# .ImageList.2.ImageData.Calibrations.Dimension.1.Units:
# .ImageList.2.ImageData.Calibrations.Dimension.2.Label:
# .ImageList.2.ImageData.Calibrations.Dimension.2.Origin: 0.0
# .ImageList.2.ImageData.Calibrations.Dimension.2.Scale: 1.0
# .ImageList.2.ImageData.Calibrations.Dimension.2.Units:
# .ImageList.2.ImageData.Calibrations.DisplayCalibratedUnits: 1
# .ImageList.2.ImageData.Data.arraySize: 105040
# .ImageList.2.ImageData.Data.arrayOffset: 72708
# .ImageList.2.ImageData.Data.arrayType: 7
# .ImageList.2.ImageData.Data: Data unread. Encoded type = 7
# .ImageList.2.ImageData.DataType: 12
# .ImageList.2.ImageData.Dimensions.1: 10
# .ImageList.2.ImageData.Dimensions.2: 1313
# .ImageList.2.ImageData.PixelDepth: 8
# .ImageList.2.ImageTags.GMS Version.Created: 3.60.4441.0
# .ImageList.2.ImageTags.GMS Version.Saved: 3.60.4441.0
# .ImageList.2.ImageTags.Meta Data.Format: Image
# .ImageList.2.ImageTags.Processing.1.Operation: LS Fitting
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Fit range.From: 44.0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Fit range.To: 73.0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Is background: 0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Name: Gaussian 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.1.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.1.Name: Amplitude
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.1.Value: 661932.8375398618
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.2.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.2.Name: Position
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.2.Value: 60.956777387957
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.3.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.3.Force positive value: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.3.Name: FWHM
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.3.Value: 27.82515443006394
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Type: Gaussian
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Fit range.From: 92.0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Fit range.To: 151.0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Is background: 0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Name: Gaussian 2
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.1.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.1.Name: Amplitude
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.1.Value: 2363996.9664884564
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.2.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.2.Name: Position
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.2.Value: 123.97839005053441
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.3.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.3.Force positive value: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.3.Name: FWHM
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.3.Value: 56.39527767337606
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Type: Gaussian
# .ImageList.2.ImageTags.Processing.1.Parameters.Fitter.Name: MinPack
# .ImageList.2.ImageTags.Processing.1.Parameters.Last fit's red.chi.sqr.: 9053493935.568539
# .ImageList.2.ImageTags.Processing.1.Parameters.Mode: NLLS
# .ImageList.2.ImageTags.Processing.1.Parameters.Value: Amplitude (Gaussian 1)
# .ImageList.2.ImageTags.Processing.1.Parent.Name: DP profile(ring)(without baseline)
# .ImageList.2.ImageTags.Processing.1.Parent.Unique Image ID: [1.86609234e+09 1.98037105e+09 1.59026305e+09 9.99555789e+08]
# .ImageList.2.ImageTags.Processing.1.Time: 2024-07-10, 오후 3:47:04
# .ImageList.2.Name: Amplitude (Gaussian 1)
# .ImageList.2.UniqueID.1: 1384734231
# .ImageList.2.UniqueID.2: 1108955674
# .ImageList.2.UniqueID.3: 761284307
# .ImageList.2.UniqueID.4: 1815292868
# .ImageSourceList.1.ClassName: ImageSource:Simple
# .ImageSourceList.1.Id.1: 0
# .ImageSourceList.1.ImageRef: 1
# .InImageMode: 1
# .LayoutType: Unknown
# .MinVersionList.1.RequiredVersion: 50659328
# .NextDocumentObjectID: 11
# .Page Behavior.DrawMargins: 1
# .Page Behavior.DrawPaper: 1
# .Page Behavior.IsFixedInPageMode: 0
# .Page Behavior.IsZoomedToWindow: 1
# .Page Behavior.LayedOut: 0
# .Page Behavior.PageTransform.Offset: [0. 0.]
# .Page Behavior.PageTransform.Scale: [1. 1.]
# .Page Behavior.RestoreImageDisplayBounds: [   0.    0. 1313.   10.]
# .Page Behavior.RestoreImageDisplayID: 8
# .Page Behavior.TargetDisplayID: 4294967295
# .PageSetup.General: [ 1.00000000e+00  2.68435556e+08  2.10000000e+04  2.97000000e+04
#   2.50000000e+03  2.50000000e+03 -2.50000000e+03 -2.50000000e+03]
# .PageSetup.Win32:RtÄ	Ä	Ä	Ä
# .PageSetup.Win32_DevModeW.arraySize: 5420
# .PageSetup.Win32_DevModeW.arrayOffset: 182929
# .PageSetup.Win32_DevModeW.arrayType: 10
# .PageSetup.Win32_DevModeW: Array unread. Encoded type = 10
# .PageSetup.Win32_DevNamesW: 2Microsoft Print To PDFMicrosoft Print to PDFPORTPROMPT:
# .Thumbnails.1.ImageIndex: 0
# .Thumbnails.1.SourceSize_Pixels: [ 94. 884.]
# .WindowPosition: [ 31.   8. 915.  17.]
# Saved D:\Users\doyeob\Desktop\3layerBP data\fitting using gatan\ring\Amplitude (Gaussian 1).tif
# Processing Amplitude (Gaussian 2).dm4...
# .ApplicationBounds: [   0.    0.  928. 1174.]
# .BackgroundColor: [-2571. -2571. -1286.]
# .DocumentObjectList.1.AnnotationGroupList.1.AnnotationType: 13
# .DocumentObjectList.1.AnnotationGroupList.1.BackgroundColor: [-1. -1. -1.]
# .DocumentObjectList.1.AnnotationGroupList.1.BackgroundMode: 2
# .DocumentObjectList.1.AnnotationGroupList.1.FillMode: 2
# .DocumentObjectList.1.AnnotationGroupList.1.FixedPoint: [0. 0.]
# .DocumentObjectList.1.AnnotationGroupList.1.ForegroundColor: [-1. -1.  0.]
# .DocumentObjectList.1.AnnotationGroupList.1.HasBackground: 0
# .DocumentObjectList.1.AnnotationGroupList.1.IsMoveable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsResizable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsSelectable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsTransferrable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsTranslatable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsVisible: 1
# .DocumentObjectList.1.AnnotationGroupList.1.ObjectTags.LSFITMapLabel: 1
# .DocumentObjectList.1.AnnotationGroupList.1.Rectangle: [ 32.82500076   0.          53.61912155 139.61764526]
# .DocumentObjectList.1.AnnotationGroupList.1.ResizeStyle: 48
# .DocumentObjectList.1.AnnotationGroupList.1.RestrictionStyle: 0
# .DocumentObjectList.1.AnnotationGroupList.1.Text: Amplitude (Gaussian 2)
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.DrawingMode: 2
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.FontAttributes: 7
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.FontFaceName: 굴림체
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.FontSize: 11.882353782653809
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.Justification: 3
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.ScreenSize: [94. 14.]
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.TextLength: 22
# .DocumentObjectList.1.AnnotationGroupList.1.Transparency: 0.0
# .DocumentObjectList.1.AnnotationGroupList.1.UniqueID: 10
# .DocumentObjectList.1.AnnotationType: 20
# .DocumentObjectList.1.BackgroundColor: [-1. -1. -1.]
# .DocumentObjectList.1.BackgroundMode: 2
# .DocumentObjectList.1.FillMode: 1
# .DocumentObjectList.1.ForegroundColor: [0. 0. 0.]
# .DocumentObjectList.1.HasBackground: 0
# .DocumentObjectList.1.ImageDisplayInfo.BrightColor: [-1. -1. -1.]
# .DocumentObjectList.1.ImageDisplayInfo.Brightness: 0.5
# .DocumentObjectList.1.ImageDisplayInfo.CaptionOn: 0
# .DocumentObjectList.1.ImageDisplayInfo.CaptionSize: 10
# .DocumentObjectList.1.ImageDisplayInfo.CLUT.arraySize: 1536
# .DocumentObjectList.1.ImageDisplayInfo.CLUT.arrayOffset: 2931
# .DocumentObjectList.1.ImageDisplayInfo.CLUT.arrayType: 2.0
# .DocumentObjectList.1.ImageDisplayInfo.CLUT: Array unread. Encoded type = 2.0
# .DocumentObjectList.1.ImageDisplayInfo.CLUTName: Greyscale
# .DocumentObjectList.1.ImageDisplayInfo.ComplexMode: 4
# .DocumentObjectList.1.ImageDisplayInfo.ComplexRange: 1000.0
# .DocumentObjectList.1.ImageDisplayInfo.Contrast: 0.5
# .DocumentObjectList.1.ImageDisplayInfo.ContrastMode: 1
# .DocumentObjectList.1.ImageDisplayInfo.DiffractionMode: 0
# .DocumentObjectList.1.ImageDisplayInfo.DoAutoSurvey: 1
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMax: 1370220.375
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMaxTrimPercentage: 0.0010000000474974513
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMin: 4775626.5
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMinTrimPercentage: 0.0010000000474974513
# .DocumentObjectList.1.ImageDisplayInfo.Gamma: 0.5
# .DocumentObjectList.1.ImageDisplayInfo.HighLimit: 4775626.5
# .DocumentObjectList.1.ImageDisplayInfo.HiLimitContrastDeltaTriggerPercentage: 0.10000000149011612
# .DocumentObjectList.1.ImageDisplayInfo.IsIgnoreGirdBar: 0
# .DocumentObjectList.1.ImageDisplayInfo.IsInverted: 0
# .DocumentObjectList.1.ImageDisplayInfo.LowLimit: 1370220.375
# .DocumentObjectList.1.ImageDisplayInfo.LowLimitContrastDeltaTriggerPercentage: 0.10000000149011612
# .DocumentObjectList.1.ImageDisplayInfo.MainSliceId.1: 0
# .DocumentObjectList.1.ImageDisplayInfo.MinimumContrast: 0.0
# .DocumentObjectList.1.ImageDisplayInfo.RangeAdjust: 1.0
# .DocumentObjectList.1.ImageDisplayInfo.SparseSurvey_GridSize: 32
# .DocumentObjectList.1.ImageDisplayInfo.SparseSurvey_NumberPixels: 64
# .DocumentObjectList.1.ImageDisplayInfo.SparseSurvey_UseNumberPixels: 1
# .DocumentObjectList.1.ImageDisplayInfo.SurveyTechique: 2
# .DocumentObjectList.1.ImageDisplayType: 1
# .DocumentObjectList.1.ImageSource: 0
# .DocumentObjectList.1.IsMoveable: 1
# .DocumentObjectList.1.IsResizable: 1
# .DocumentObjectList.1.IsSelectable: 1
# .DocumentObjectList.1.IsTransferrable: 1
# .DocumentObjectList.1.IsTranslatable: 1
# .DocumentObjectList.1.IsVisible: 1
# .DocumentObjectList.1.Rectangle: [  0.           0.         884.           6.73267317]
# .DocumentObjectList.1.RestrictionStyle: 0
# .DocumentObjectList.1.Transparency: 0.0
# .DocumentObjectList.1.UniqueID: 8
# .HasWindowPosition: 1
# .Image Behavior.ImageDisplayBounds: [  0.           0.         884.           6.73267317]
# .Image Behavior.IsZoomedToWindow: 1
# .Image Behavior.UnscaledTransform.Offset: [0. 0.]
# .Image Behavior.UnscaledTransform.Scale: [1. 1.]
# .Image Behavior.ViewDisplayID: 8
# .Image Behavior.WindowRect: [  0.   0. 884.   9.]
# .Image Behavior.ZoomAndMoveTransform.Offset: [1.13366342 0.        ]
# .Image Behavior.ZoomAndMoveTransform.Scale: [1. 1.]
# .ImageList.1.ImageData.Calibrations.Brightness.Label:
# .ImageList.1.ImageData.Calibrations.Brightness.Origin: 0.0
# .ImageList.1.ImageData.Calibrations.Brightness.Scale: 1.0
# .ImageList.1.ImageData.Calibrations.Brightness.Units:
# .ImageList.1.ImageData.Calibrations.Dimension.1.Label:
# .ImageList.1.ImageData.Calibrations.Dimension.1.Origin: 0.0
# .ImageList.1.ImageData.Calibrations.Dimension.1.Scale: 1.0
# .ImageList.1.ImageData.Calibrations.Dimension.1.Units:
# .ImageList.1.ImageData.Calibrations.Dimension.2.Label:
# .ImageList.1.ImageData.Calibrations.Dimension.2.Origin: 0.0
# .ImageList.1.ImageData.Calibrations.Dimension.2.Scale: 1.0
# .ImageList.1.ImageData.Calibrations.Dimension.2.Units:
# .ImageList.1.ImageData.Calibrations.DisplayCalibratedUnits: 1
# .ImageList.1.ImageData.Data.arraySize: 62976
# .ImageList.1.ImageData.Data.arrayOffset: 8276
# .ImageList.1.ImageData.Data.arrayType: 3
# .ImageList.1.ImageData.Data: Data unread. Encoded type = 3
# .ImageList.1.ImageData.DataType: 23
# .ImageList.1.ImageData.Dimensions.1: 41
# .ImageList.1.ImageData.Dimensions.2: 384
# .ImageList.1.ImageData.PixelDepth: 4
# .ImageList.1.ImageTags.GMS Version.Created: 3.60.4441.0
# .ImageList.1.Name: Image Of Amplitude (Gaussian 2)
# .ImageList.1.UniqueID.1: 925713532
# .ImageList.1.UniqueID.2: 1541750178
# .ImageList.1.UniqueID.3: 56183953
# .ImageList.1.UniqueID.4: 594443671
# .ImageList.2.ImageData.Calibrations.Brightness.Label:
# .ImageList.2.ImageData.Calibrations.Brightness.Origin: 0.0
# .ImageList.2.ImageData.Calibrations.Brightness.Scale: 1.0
# .ImageList.2.ImageData.Calibrations.Brightness.Units:
# .ImageList.2.ImageData.Calibrations.Dimension.1.Label:
# .ImageList.2.ImageData.Calibrations.Dimension.1.Origin: 0.0
# .ImageList.2.ImageData.Calibrations.Dimension.1.Scale: 1.0
# .ImageList.2.ImageData.Calibrations.Dimension.1.Units:
# .ImageList.2.ImageData.Calibrations.Dimension.2.Label:
# .ImageList.2.ImageData.Calibrations.Dimension.2.Origin: 0.0
# .ImageList.2.ImageData.Calibrations.Dimension.2.Scale: 1.0
# .ImageList.2.ImageData.Calibrations.Dimension.2.Units:
# .ImageList.2.ImageData.Calibrations.DisplayCalibratedUnits: 1
# .ImageList.2.ImageData.Data.arraySize: 105040
# .ImageList.2.ImageData.Data.arrayOffset: 72708
# .ImageList.2.ImageData.Data.arrayType: 7
# .ImageList.2.ImageData.Data: Data unread. Encoded type = 7
# .ImageList.2.ImageData.DataType: 12
# .ImageList.2.ImageData.Dimensions.1: 10
# .ImageList.2.ImageData.Dimensions.2: 1313
# .ImageList.2.ImageData.PixelDepth: 8
# .ImageList.2.ImageTags.GMS Version.Created: 3.60.4441.0
# .ImageList.2.ImageTags.GMS Version.Saved: 3.60.4441.0
# .ImageList.2.ImageTags.Meta Data.Format: Image
# .ImageList.2.ImageTags.Processing.1.Operation: LS Fitting
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Fit range.From: 44.0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Fit range.To: 73.0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Is background: 0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Name: Gaussian 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.1.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.1.Name: Amplitude
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.1.Value: 661932.8375398618
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.2.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.2.Name: Position
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.2.Value: 60.956777387957
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.3.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.3.Force positive value: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.3.Name: FWHM
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.3.Value: 27.82515443006394
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Type: Gaussian
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Fit range.From: 92.0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Fit range.To: 151.0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Is background: 0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Name: Gaussian 2
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.1.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.1.Name: Amplitude
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.1.Value: 2363996.9664884564
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.2.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.2.Name: Position
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.2.Value: 123.97839005053441
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.3.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.3.Force positive value: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.3.Name: FWHM
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.3.Value: 56.39527767337606
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Type: Gaussian
# .ImageList.2.ImageTags.Processing.1.Parameters.Fitter.Name: MinPack
# .ImageList.2.ImageTags.Processing.1.Parameters.Last fit's red.chi.sqr.: 9053493935.568539
# .ImageList.2.ImageTags.Processing.1.Parameters.Mode: NLLS
# .ImageList.2.ImageTags.Processing.1.Parameters.Value: Amplitude (Gaussian 2)
# .ImageList.2.ImageTags.Processing.1.Parent.Name: DP profile(ring)(without baseline)
# .ImageList.2.ImageTags.Processing.1.Parent.Unique Image ID: [1.86609234e+09 1.98037105e+09 1.59026305e+09 9.99555789e+08]
# .ImageList.2.ImageTags.Processing.1.Time: 2024-07-10, 오후 3:47:04
# .ImageList.2.Name: Amplitude (Gaussian 2)
# .ImageList.2.UniqueID.1: 1478624913
# .ImageList.2.UniqueID.2: 1885539708
# .ImageList.2.UniqueID.3: 941363905
# .ImageList.2.UniqueID.4: 909990743
# .ImageSourceList.1.ClassName: ImageSource:Simple
# .ImageSourceList.1.Id.1: 0
# .ImageSourceList.1.ImageRef: 1
# .InImageMode: 1
# .LayoutType: Unknown
# .MinVersionList.1.RequiredVersion: 50659328
# .NextDocumentObjectID: 11
# .Page Behavior.DrawMargins: 1
# .Page Behavior.DrawPaper: 1
# .Page Behavior.IsFixedInPageMode: 0
# .Page Behavior.IsZoomedToWindow: 1
# .Page Behavior.LayedOut: 0
# .Page Behavior.PageTransform.Offset: [0. 0.]
# .Page Behavior.PageTransform.Scale: [1. 1.]
# .Page Behavior.RestoreImageDisplayBounds: [   0.    0. 1313.   10.]
# .Page Behavior.RestoreImageDisplayID: 8
# .Page Behavior.TargetDisplayID: 4294967295
# .PageSetup.General: [ 1.00000000e+00  2.68435556e+08  2.10000000e+04  2.97000000e+04
#   2.50000000e+03  2.50000000e+03 -2.50000000e+03 -2.50000000e+03]
# .PageSetup.Win32:RtÄ	Ä	Ä	Ä
# .PageSetup.Win32_DevModeW.arraySize: 5420
# .PageSetup.Win32_DevModeW.arrayOffset: 182929
# .PageSetup.Win32_DevModeW.arrayType: 10
# .PageSetup.Win32_DevModeW: Array unread. Encoded type = 10
# .PageSetup.Win32_DevNamesW: 2Microsoft Print To PDFMicrosoft Print to PDFPORTPROMPT:
# .Thumbnails.1.ImageIndex: 0
# .Thumbnails.1.SourceSize_Pixels: [ 94. 884.]
# .WindowPosition: [ 31.  83. 915.  92.]
# Saved D:\Users\doyeob\Desktop\3layerBP data\fitting using gatan\ring\Amplitude (Gaussian 2).tif
# Processing FWHM (Gaussian 1).dm4...
# .ApplicationBounds: [   0.    0.  928. 1174.]
# .BackgroundColor: [-2571. -2571. -1286.]
# .DocumentObjectList.1.AnnotationGroupList.1.AnnotationType: 13
# .DocumentObjectList.1.AnnotationGroupList.1.BackgroundColor: [-1. -1. -1.]
# .DocumentObjectList.1.AnnotationGroupList.1.BackgroundMode: 2
# .DocumentObjectList.1.AnnotationGroupList.1.FillMode: 2
# .DocumentObjectList.1.AnnotationGroupList.1.FixedPoint: [0. 0.]
# .DocumentObjectList.1.AnnotationGroupList.1.ForegroundColor: [-1. -1.  0.]
# .DocumentObjectList.1.AnnotationGroupList.1.HasBackground: 0
# .DocumentObjectList.1.AnnotationGroupList.1.IsMoveable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsResizable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsSelectable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsTransferrable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsTranslatable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsVisible: 1
# .DocumentObjectList.1.AnnotationGroupList.1.ObjectTags.LSFITMapLabel: 1
# .DocumentObjectList.1.AnnotationGroupList.1.Rectangle: [ 32.82500076   0.          53.61911774 109.91176605]
# .DocumentObjectList.1.AnnotationGroupList.1.ResizeStyle: 48
# .DocumentObjectList.1.AnnotationGroupList.1.RestrictionStyle: 0
# .DocumentObjectList.1.AnnotationGroupList.1.Text: FWHM (Gaussian 1)
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.DrawingMode: 2
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.FontAttributes: 7
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.FontFaceName: 굴림체
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.FontSize: 11.882353782653809
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.Justification: 3
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.ScreenSize: [74. 14.]
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.TextLength: 17
# .DocumentObjectList.1.AnnotationGroupList.1.Transparency: 0.0
# .DocumentObjectList.1.AnnotationGroupList.1.UniqueID: 10
# .DocumentObjectList.1.AnnotationType: 20
# .DocumentObjectList.1.BackgroundColor: [-1. -1. -1.]
# .DocumentObjectList.1.BackgroundMode: 2
# .DocumentObjectList.1.FillMode: 1
# .DocumentObjectList.1.ForegroundColor: [0. 0. 0.]
# .DocumentObjectList.1.HasBackground: 0
# .DocumentObjectList.1.ImageDisplayInfo.BrightColor: [-1. -1. -1.]
# .DocumentObjectList.1.ImageDisplayInfo.Brightness: 0.5
# .DocumentObjectList.1.ImageDisplayInfo.CaptionOn: 0
# .DocumentObjectList.1.ImageDisplayInfo.CaptionSize: 10
# .DocumentObjectList.1.ImageDisplayInfo.CLUT.arraySize: 1536
# .DocumentObjectList.1.ImageDisplayInfo.CLUT.arrayOffset: 2921
# .DocumentObjectList.1.ImageDisplayInfo.CLUT.arrayType: 2.0
# .DocumentObjectList.1.ImageDisplayInfo.CLUT: Array unread. Encoded type = 2.0
# .DocumentObjectList.1.ImageDisplayInfo.CLUTName: Greyscale
# .DocumentObjectList.1.ImageDisplayInfo.ComplexMode: 4
# .DocumentObjectList.1.ImageDisplayInfo.ComplexRange: 1000.0
# .DocumentObjectList.1.ImageDisplayInfo.Contrast: 0.5
# .DocumentObjectList.1.ImageDisplayInfo.ContrastMode: 1
# .DocumentObjectList.1.ImageDisplayInfo.DiffractionMode: 0
# .DocumentObjectList.1.ImageDisplayInfo.DoAutoSurvey: 1
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMax: 3.603795051574707
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMaxTrimPercentage: 0.0010000000474974513
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMin: 59.14103698730469
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMinTrimPercentage: 0.0010000000474974513
# .DocumentObjectList.1.ImageDisplayInfo.Gamma: 0.5
# .DocumentObjectList.1.ImageDisplayInfo.HighLimit: 59.14103698730469
# .DocumentObjectList.1.ImageDisplayInfo.HiLimitContrastDeltaTriggerPercentage: 0.10000000149011612
# .DocumentObjectList.1.ImageDisplayInfo.IsIgnoreGirdBar: 0
# .DocumentObjectList.1.ImageDisplayInfo.IsInverted: 0
# .DocumentObjectList.1.ImageDisplayInfo.LowLimit: 3.603795051574707
# .DocumentObjectList.1.ImageDisplayInfo.LowLimitContrastDeltaTriggerPercentage: 0.10000000149011612
# .DocumentObjectList.1.ImageDisplayInfo.MainSliceId.1: 0
# .DocumentObjectList.1.ImageDisplayInfo.MinimumContrast: 0.0
# .DocumentObjectList.1.ImageDisplayInfo.RangeAdjust: 1.0
# .DocumentObjectList.1.ImageDisplayInfo.SparseSurvey_GridSize: 32
# .DocumentObjectList.1.ImageDisplayInfo.SparseSurvey_NumberPixels: 64
# .DocumentObjectList.1.ImageDisplayInfo.SparseSurvey_UseNumberPixels: 1
# .DocumentObjectList.1.ImageDisplayInfo.SurveyTechique: 2
# .DocumentObjectList.1.ImageDisplayType: 1
# .DocumentObjectList.1.ImageSource: 0
# .DocumentObjectList.1.IsMoveable: 1
# .DocumentObjectList.1.IsResizable: 1
# .DocumentObjectList.1.IsSelectable: 1
# .DocumentObjectList.1.IsTransferrable: 1
# .DocumentObjectList.1.IsTranslatable: 1
# .DocumentObjectList.1.IsVisible: 1
# .DocumentObjectList.1.Rectangle: [  0.           0.         884.           6.73267317]
# .DocumentObjectList.1.RestrictionStyle: 0
# .DocumentObjectList.1.Transparency: 0.0
# .DocumentObjectList.1.UniqueID: 8
# .HasWindowPosition: 1
# .Image Behavior.ImageDisplayBounds: [  0.           0.         884.           6.73267317]
# .Image Behavior.IsZoomedToWindow: 1
# .Image Behavior.UnscaledTransform.Offset: [0. 0.]
# .Image Behavior.UnscaledTransform.Scale: [1. 1.]
# .Image Behavior.ViewDisplayID: 8
# .Image Behavior.WindowRect: [  0.   0. 884.   9.]
# .Image Behavior.ZoomAndMoveTransform.Offset: [1.13366342 0.        ]
# .Image Behavior.ZoomAndMoveTransform.Scale: [1. 1.]
# .ImageList.1.ImageData.Calibrations.Brightness.Label:
# .ImageList.1.ImageData.Calibrations.Brightness.Origin: 0.0
# .ImageList.1.ImageData.Calibrations.Brightness.Scale: 1.0
# .ImageList.1.ImageData.Calibrations.Brightness.Units:
# .ImageList.1.ImageData.Calibrations.Dimension.1.Label:
# .ImageList.1.ImageData.Calibrations.Dimension.1.Origin: 0.0
# .ImageList.1.ImageData.Calibrations.Dimension.1.Scale: 1.0
# .ImageList.1.ImageData.Calibrations.Dimension.1.Units:
# .ImageList.1.ImageData.Calibrations.Dimension.2.Label:
# .ImageList.1.ImageData.Calibrations.Dimension.2.Origin: 0.0
# .ImageList.1.ImageData.Calibrations.Dimension.2.Scale: 1.0
# .ImageList.1.ImageData.Calibrations.Dimension.2.Units:
# .ImageList.1.ImageData.Calibrations.DisplayCalibratedUnits: 1
# .ImageList.1.ImageData.Data.arraySize: 49152
# .ImageList.1.ImageData.Data.arrayOffset: 8266
# .ImageList.1.ImageData.Data.arrayType: 3
# .ImageList.1.ImageData.Data: Data unread. Encoded type = 3
# .ImageList.1.ImageData.DataType: 23
# .ImageList.1.ImageData.Dimensions.1: 32
# .ImageList.1.ImageData.Dimensions.2: 384
# .ImageList.1.ImageData.PixelDepth: 4
# .ImageList.1.ImageTags.GMS Version.Created: 3.60.4441.0
# .ImageList.1.Name: Image Of FWHM (Gaussian 1)
# .ImageList.1.UniqueID.1: 1120210082
# .ImageList.1.UniqueID.2: 810829368
# .ImageList.1.UniqueID.3: 2084393896
# .ImageList.1.UniqueID.4: 364063200
# .ImageList.2.ImageData.Calibrations.Brightness.Label:
# .ImageList.2.ImageData.Calibrations.Brightness.Origin: 0.0
# .ImageList.2.ImageData.Calibrations.Brightness.Scale: 1.0
# .ImageList.2.ImageData.Calibrations.Brightness.Units:
# .ImageList.2.ImageData.Calibrations.Dimension.1.Label:
# .ImageList.2.ImageData.Calibrations.Dimension.1.Origin: 0.0
# .ImageList.2.ImageData.Calibrations.Dimension.1.Scale: 1.0
# .ImageList.2.ImageData.Calibrations.Dimension.1.Units:
# .ImageList.2.ImageData.Calibrations.Dimension.2.Label:
# .ImageList.2.ImageData.Calibrations.Dimension.2.Origin: 0.0
# .ImageList.2.ImageData.Calibrations.Dimension.2.Scale: 1.0
# .ImageList.2.ImageData.Calibrations.Dimension.2.Units:
# .ImageList.2.ImageData.Calibrations.DisplayCalibratedUnits: 1
# .ImageList.2.ImageData.Data.arraySize: 105040
# .ImageList.2.ImageData.Data.arrayOffset: 58864
# .ImageList.2.ImageData.Data.arrayType: 7
# .ImageList.2.ImageData.Data: Data unread. Encoded type = 7
# .ImageList.2.ImageData.DataType: 12
# .ImageList.2.ImageData.Dimensions.1: 10
# .ImageList.2.ImageData.Dimensions.2: 1313
# .ImageList.2.ImageData.PixelDepth: 8
# .ImageList.2.ImageTags.GMS Version.Created: 3.60.4441.0
# .ImageList.2.ImageTags.GMS Version.Saved: 3.60.4441.0
# .ImageList.2.ImageTags.Meta Data.Format: Image
# .ImageList.2.ImageTags.Processing.1.Operation: LS Fitting
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Fit range.From: 44.0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Fit range.To: 73.0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Is background: 0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Name: Gaussian 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.1.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.1.Name: Amplitude
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.1.Value: 661932.8375398618
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.2.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.2.Name: Position
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.2.Value: 60.956777387957
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.3.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.3.Force positive value: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.3.Name: FWHM
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.3.Value: 27.82515443006394
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Type: Gaussian
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Fit range.From: 92.0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Fit range.To: 151.0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Is background: 0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Name: Gaussian 2
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.1.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.1.Name: Amplitude
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.1.Value: 2363996.9664884564
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.2.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.2.Name: Position
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.2.Value: 123.97839005053441
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.3.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.3.Force positive value: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.3.Name: FWHM
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.3.Value: 56.39527767337606
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Type: Gaussian
# .ImageList.2.ImageTags.Processing.1.Parameters.Fitter.Name: MinPack
# .ImageList.2.ImageTags.Processing.1.Parameters.Last fit's red.chi.sqr.: 9053493935.568539
# .ImageList.2.ImageTags.Processing.1.Parameters.Mode: NLLS
# .ImageList.2.ImageTags.Processing.1.Parameters.Value: FWHM (Gaussian 1)
# .ImageList.2.ImageTags.Processing.1.Parent.Name: DP profile(ring)(without baseline)
# .ImageList.2.ImageTags.Processing.1.Parent.Unique Image ID: [1.86609234e+09 1.98037105e+09 1.59026305e+09 9.99555789e+08]
# .ImageList.2.ImageTags.Processing.1.Time: 2024-07-10, 오후 3:47:04
# .ImageList.2.Name: FWHM (Gaussian 1)
# .ImageList.2.UniqueID.1: 1575307090
# .ImageList.2.UniqueID.2: 1193567887
# .ImageList.2.UniqueID.3: 1880907895
# .ImageList.2.UniqueID.4: 1817448373
# .ImageSourceList.1.ClassName: ImageSource:Simple
# .ImageSourceList.1.Id.1: 0
# .ImageSourceList.1.ImageRef: 1
# .InImageMode: 1
# .LayoutType: Unknown
# .MinVersionList.1.RequiredVersion: 50659328
# .NextDocumentObjectID: 11
# .Page Behavior.DrawMargins: 1
# .Page Behavior.DrawPaper: 1
# .Page Behavior.IsFixedInPageMode: 0
# .Page Behavior.IsZoomedToWindow: 1
# .Page Behavior.LayedOut: 0
# .Page Behavior.PageTransform.Offset: [0. 0.]
# .Page Behavior.PageTransform.Scale: [1. 1.]
# .Page Behavior.RestoreImageDisplayBounds: [   0.    0. 1313.   10.]
# .Page Behavior.RestoreImageDisplayID: 8
# .Page Behavior.TargetDisplayID: 4294967295
# .PageSetup.General: [ 1.00000000e+00  2.68435556e+08  2.10000000e+04  2.97000000e+04
#   2.50000000e+03  2.50000000e+03 -2.50000000e+03 -2.50000000e+03]
# .PageSetup.Win32:RtÄ	Ä	Ä	Ä
# .PageSetup.Win32_DevModeW.arraySize: 5420
# .PageSetup.Win32_DevModeW.arrayOffset: 169065
# .PageSetup.Win32_DevModeW.arrayType: 10
# .PageSetup.Win32_DevModeW: Array unread. Encoded type = 10
# .PageSetup.Win32_DevNamesW: 2Microsoft Print To PDFMicrosoft Print to PDFPORTPROMPT:
# .Thumbnails.1.ImageIndex: 0
# .Thumbnails.1.SourceSize_Pixels: [ 74. 884.]
# .WindowPosition: [ 31.  33. 915.  42.]
# Saved D:\Users\doyeob\Desktop\3layerBP data\fitting using gatan\ring\FWHM (Gaussian 1).tif
# Processing FWHM (Gaussian 2).dm4...
# .ApplicationBounds: [   0.    0.  928. 1174.]
# .BackgroundColor: [-2571. -2571. -1286.]
# .DocumentObjectList.1.AnnotationGroupList.1.AnnotationType: 13
# .DocumentObjectList.1.AnnotationGroupList.1.BackgroundColor: [-1. -1. -1.]
# .DocumentObjectList.1.AnnotationGroupList.1.BackgroundMode: 2
# .DocumentObjectList.1.AnnotationGroupList.1.FillMode: 2
# .DocumentObjectList.1.AnnotationGroupList.1.FixedPoint: [0. 0.]
# .DocumentObjectList.1.AnnotationGroupList.1.ForegroundColor: [-1. -1.  0.]
# .DocumentObjectList.1.AnnotationGroupList.1.HasBackground: 0
# .DocumentObjectList.1.AnnotationGroupList.1.IsMoveable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsResizable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsSelectable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsTransferrable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsTranslatable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsVisible: 1
# .DocumentObjectList.1.AnnotationGroupList.1.ObjectTags.LSFITMapLabel: 1
# .DocumentObjectList.1.AnnotationGroupList.1.Rectangle: [ 32.82500076   0.          53.61911774 109.91176605]
# .DocumentObjectList.1.AnnotationGroupList.1.ResizeStyle: 48
# .DocumentObjectList.1.AnnotationGroupList.1.RestrictionStyle: 0
# .DocumentObjectList.1.AnnotationGroupList.1.Text: FWHM (Gaussian 2)
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.DrawingMode: 2
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.FontAttributes: 7
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.FontFaceName: 굴림체
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.FontSize: 11.882353782653809
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.Justification: 3
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.ScreenSize: [74. 14.]
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.TextLength: 17
# .DocumentObjectList.1.AnnotationGroupList.1.Transparency: 0.0
# .DocumentObjectList.1.AnnotationGroupList.1.UniqueID: 10
# .DocumentObjectList.1.AnnotationType: 20
# .DocumentObjectList.1.BackgroundColor: [-1. -1. -1.]
# .DocumentObjectList.1.BackgroundMode: 2
# .DocumentObjectList.1.FillMode: 1
# .DocumentObjectList.1.ForegroundColor: [0. 0. 0.]
# .DocumentObjectList.1.HasBackground: 0
# .DocumentObjectList.1.ImageDisplayInfo.BrightColor: [-1. -1. -1.]
# .DocumentObjectList.1.ImageDisplayInfo.Brightness: 0.5
# .DocumentObjectList.1.ImageDisplayInfo.CaptionOn: 0
# .DocumentObjectList.1.ImageDisplayInfo.CaptionSize: 10
# .DocumentObjectList.1.ImageDisplayInfo.CLUT.arraySize: 1536
# .DocumentObjectList.1.ImageDisplayInfo.CLUT.arrayOffset: 2921
# .DocumentObjectList.1.ImageDisplayInfo.CLUT.arrayType: 2.0
# .DocumentObjectList.1.ImageDisplayInfo.CLUT: Array unread. Encoded type = 2.0
# .DocumentObjectList.1.ImageDisplayInfo.CLUTName: Greyscale
# .DocumentObjectList.1.ImageDisplayInfo.ComplexMode: 4
# .DocumentObjectList.1.ImageDisplayInfo.ComplexRange: 1000.0
# .DocumentObjectList.1.ImageDisplayInfo.Contrast: 0.5
# .DocumentObjectList.1.ImageDisplayInfo.ContrastMode: 1
# .DocumentObjectList.1.ImageDisplayInfo.DiffractionMode: 0
# .DocumentObjectList.1.ImageDisplayInfo.DoAutoSurvey: 1
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMax: 48.779109954833984
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMaxTrimPercentage: 0.0010000000474974513
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMin: 75.74053192138672
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMinTrimPercentage: 0.0010000000474974513
# .DocumentObjectList.1.ImageDisplayInfo.Gamma: 0.5
# .DocumentObjectList.1.ImageDisplayInfo.HighLimit: 75.74053192138672
# .DocumentObjectList.1.ImageDisplayInfo.HiLimitContrastDeltaTriggerPercentage: 0.10000000149011612
# .DocumentObjectList.1.ImageDisplayInfo.IsIgnoreGirdBar: 0
# .DocumentObjectList.1.ImageDisplayInfo.IsInverted: 0
# .DocumentObjectList.1.ImageDisplayInfo.LowLimit: 48.779109954833984
# .DocumentObjectList.1.ImageDisplayInfo.LowLimitContrastDeltaTriggerPercentage: 0.10000000149011612
# .DocumentObjectList.1.ImageDisplayInfo.MainSliceId.1: 0
# .DocumentObjectList.1.ImageDisplayInfo.MinimumContrast: 0.0
# .DocumentObjectList.1.ImageDisplayInfo.RangeAdjust: 1.0
# .DocumentObjectList.1.ImageDisplayInfo.SparseSurvey_GridSize: 32
# .DocumentObjectList.1.ImageDisplayInfo.SparseSurvey_NumberPixels: 64
# .DocumentObjectList.1.ImageDisplayInfo.SparseSurvey_UseNumberPixels: 1
# .DocumentObjectList.1.ImageDisplayInfo.SurveyTechique: 2
# .DocumentObjectList.1.ImageDisplayType: 1
# .DocumentObjectList.1.ImageSource: 0
# .DocumentObjectList.1.IsMoveable: 1
# .DocumentObjectList.1.IsResizable: 1
# .DocumentObjectList.1.IsSelectable: 1
# .DocumentObjectList.1.IsTransferrable: 1
# .DocumentObjectList.1.IsTranslatable: 1
# .DocumentObjectList.1.IsVisible: 1
# .DocumentObjectList.1.Rectangle: [  0.           0.         884.           6.73267317]
# .DocumentObjectList.1.RestrictionStyle: 0
# .DocumentObjectList.1.Transparency: 0.0
# .DocumentObjectList.1.UniqueID: 8
# .HasWindowPosition: 1
# .Image Behavior.ImageDisplayBounds: [  0.           0.         884.           6.73267317]
# .Image Behavior.IsZoomedToWindow: 1
# .Image Behavior.UnscaledTransform.Offset: [0. 0.]
# .Image Behavior.UnscaledTransform.Scale: [1. 1.]
# .Image Behavior.ViewDisplayID: 8
# .Image Behavior.WindowRect: [  0.   0. 884.   9.]
# .Image Behavior.ZoomAndMoveTransform.Offset: [1.13366342 0.        ]
# .Image Behavior.ZoomAndMoveTransform.Scale: [1. 1.]
# .ImageList.1.ImageData.Calibrations.Brightness.Label:
# .ImageList.1.ImageData.Calibrations.Brightness.Origin: 0.0
# .ImageList.1.ImageData.Calibrations.Brightness.Scale: 1.0
# .ImageList.1.ImageData.Calibrations.Brightness.Units:
# .ImageList.1.ImageData.Calibrations.Dimension.1.Label:
# .ImageList.1.ImageData.Calibrations.Dimension.1.Origin: 0.0
# .ImageList.1.ImageData.Calibrations.Dimension.1.Scale: 1.0
# .ImageList.1.ImageData.Calibrations.Dimension.1.Units:
# .ImageList.1.ImageData.Calibrations.Dimension.2.Label:
# .ImageList.1.ImageData.Calibrations.Dimension.2.Origin: 0.0
# .ImageList.1.ImageData.Calibrations.Dimension.2.Scale: 1.0
# .ImageList.1.ImageData.Calibrations.Dimension.2.Units:
# .ImageList.1.ImageData.Calibrations.DisplayCalibratedUnits: 1
# .ImageList.1.ImageData.Data.arraySize: 49152
# .ImageList.1.ImageData.Data.arrayOffset: 8266
# .ImageList.1.ImageData.Data.arrayType: 3
# .ImageList.1.ImageData.Data: Data unread. Encoded type = 3
# .ImageList.1.ImageData.DataType: 23
# .ImageList.1.ImageData.Dimensions.1: 32
# .ImageList.1.ImageData.Dimensions.2: 384
# .ImageList.1.ImageData.PixelDepth: 4
# .ImageList.1.ImageTags.GMS Version.Created: 3.60.4441.0
# .ImageList.1.Name: Image Of FWHM (Gaussian 2)
# .ImageList.1.UniqueID.1: 1319270930
# .ImageList.1.UniqueID.2: 2097769667
# .ImageList.1.UniqueID.3: 118965635
# .ImageList.1.UniqueID.4: 1814892016
# .ImageList.2.ImageData.Calibrations.Brightness.Label:
# .ImageList.2.ImageData.Calibrations.Brightness.Origin: 0.0
# .ImageList.2.ImageData.Calibrations.Brightness.Scale: 1.0
# .ImageList.2.ImageData.Calibrations.Brightness.Units:
# .ImageList.2.ImageData.Calibrations.Dimension.1.Label:
# .ImageList.2.ImageData.Calibrations.Dimension.1.Origin: 0.0
# .ImageList.2.ImageData.Calibrations.Dimension.1.Scale: 1.0
# .ImageList.2.ImageData.Calibrations.Dimension.1.Units:
# .ImageList.2.ImageData.Calibrations.Dimension.2.Label:
# .ImageList.2.ImageData.Calibrations.Dimension.2.Origin: 0.0
# .ImageList.2.ImageData.Calibrations.Dimension.2.Scale: 1.0
# .ImageList.2.ImageData.Calibrations.Dimension.2.Units:
# .ImageList.2.ImageData.Calibrations.DisplayCalibratedUnits: 1
# .ImageList.2.ImageData.Data.arraySize: 105040
# .ImageList.2.ImageData.Data.arrayOffset: 58864
# .ImageList.2.ImageData.Data.arrayType: 7
# .ImageList.2.ImageData.Data: Data unread. Encoded type = 7
# .ImageList.2.ImageData.DataType: 12
# .ImageList.2.ImageData.Dimensions.1: 10
# .ImageList.2.ImageData.Dimensions.2: 1313
# .ImageList.2.ImageData.PixelDepth: 8
# .ImageList.2.ImageTags.GMS Version.Created: 3.60.4441.0
# .ImageList.2.ImageTags.GMS Version.Saved: 3.60.4441.0
# .ImageList.2.ImageTags.Meta Data.Format: Image
# .ImageList.2.ImageTags.Processing.1.Operation: LS Fitting
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Fit range.From: 44.0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Fit range.To: 73.0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Is background: 0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Name: Gaussian 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.1.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.1.Name: Amplitude
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.1.Value: 661932.8375398618
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.2.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.2.Name: Position
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.2.Value: 60.956777387957
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.3.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.3.Force positive value: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.3.Name: FWHM
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.3.Value: 27.82515443006394
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Type: Gaussian
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Fit range.From: 92.0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Fit range.To: 151.0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Is background: 0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Name: Gaussian 2
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.1.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.1.Name: Amplitude
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.1.Value: 2363996.9664884564
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.2.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.2.Name: Position
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.2.Value: 123.97839005053441
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.3.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.3.Force positive value: 1
# ...
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Type: Gaussian
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Fit range.From: 92.0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Fit range.To: 151.0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Is background: 0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Name: Gaussian 2
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.1.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.1.Name: Amplitude
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.1.Value: 2363996.9664884564
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.2.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.2.Name: Position
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.2.Value: 123.97839005053441
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.3.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.3.Force positive value: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.3.Name: FWHM
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.3.Value: 56.39527767337606
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Type: Gaussian
# .ImageList.2.ImageTags.Processing.1.Parameters.Fitter.Name: MinPack
# .ImageList.2.ImageTags.Processing.1.Parameters.Last fit's red.chi.sqr.: 9053493935.568539
# .ImageList.2.ImageTags.Processing.1.Parameters.Mode: NLLS
# .ImageList.2.ImageTags.Processing.1.Parameters.Value: Position (Gaussian 1)
# .ImageList.2.ImageTags.Processing.1.Parent.Name: DP profile(ring)(without baseline)
# .ImageList.2.ImageTags.Processing.1.Parent.Unique Image ID: [1.86609234e+09 1.98037105e+09 1.59026305e+09 9.99555789e+08]
# .ImageList.2.ImageTags.Processing.1.Time: 2024-07-10, 오후 3:47:04
# .ImageList.2.Name: Position (Gaussian 1)
# .ImageList.2.UniqueID.1: 524249733
# .ImageList.2.UniqueID.2: 1065636444
# .ImageList.2.UniqueID.3: 542713163
# .ImageList.2.UniqueID.4: 865016166
# .ImageSourceList.1.ClassName: ImageSource:Simple
# .ImageSourceList.1.Id.1: 0
# .ImageSourceList.1.ImageRef: 1
# .InImageMode: 1
# .LayoutType: Unknown
# .MinVersionList.1.RequiredVersion: 50659328
# .NextDocumentObjectID: 11
# .Page Behavior.DrawMargins: 1
# .Page Behavior.DrawPaper: 1
# .Page Behavior.IsFixedInPageMode: 0
# .Page Behavior.IsZoomedToWindow: 1
# .Page Behavior.LayedOut: 0
# .Page Behavior.PageTransform.Offset: [0. 0.]
# .Page Behavior.PageTransform.Scale: [1. 1.]
# .Page Behavior.RestoreImageDisplayBounds: [   0.    0. 1313.   10.]
# .Page Behavior.RestoreImageDisplayID: 8
# .Page Behavior.TargetDisplayID: 4294967295
# .PageSetup.General: [ 1.00000000e+00  2.68435556e+08  2.10000000e+04  2.97000000e+04
#   2.50000000e+03  2.50000000e+03 -2.50000000e+03 -2.50000000e+03]
# .PageSetup.Win32:RtÄ	Ä	Ä	Ä
# .PageSetup.Win32_DevModeW.arraySize: 5420
# .PageSetup.Win32_DevModeW.arrayOffset: 179849
# .PageSetup.Win32_DevModeW.arrayType: 10
# .PageSetup.Win32_DevModeW: Array unread. Encoded type = 10
# .PageSetup.Win32_DevNamesW: 2Microsoft Print To PDFMicrosoft Print to PDFPORTPROMPT:
# .Thumbnails.1.ImageIndex: 0
# .Thumbnails.1.SourceSize_Pixels: [ 90. 884.]
# .WindowPosition: [ 31.  58. 915.  67.]
# Saved D:\Users\doyeob\Desktop\3layerBP data\fitting using gatan\ring\Position (Gaussian 1).tif
# Processing Position (Gaussian 2).dm4...
# .ApplicationBounds: [   0.    0.  928. 1174.]
# .BackgroundColor: [-2571. -2571. -1286.]
# .DocumentObjectList.1.AnnotationGroupList.1.AnnotationType: 13
# .DocumentObjectList.1.AnnotationGroupList.1.BackgroundColor: [-1. -1. -1.]
# .DocumentObjectList.1.AnnotationGroupList.1.BackgroundMode: 2
# .DocumentObjectList.1.AnnotationGroupList.1.FillMode: 2
# .DocumentObjectList.1.AnnotationGroupList.1.FixedPoint: [0. 0.]
# .DocumentObjectList.1.AnnotationGroupList.1.ForegroundColor: [-1. -1.  0.]
# .DocumentObjectList.1.AnnotationGroupList.1.HasBackground: 0
# .DocumentObjectList.1.AnnotationGroupList.1.IsMoveable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsResizable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsSelectable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsTransferrable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsTranslatable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsVisible: 1
# .DocumentObjectList.1.AnnotationGroupList.1.ObjectTags.LSFITMapLabel: 1
# .DocumentObjectList.1.AnnotationGroupList.1.Rectangle: [ 32.82500076   0.          53.61911774 133.6764679 ]
# .DocumentObjectList.1.AnnotationGroupList.1.ResizeStyle: 48
# .DocumentObjectList.1.AnnotationGroupList.1.RestrictionStyle: 0
# .DocumentObjectList.1.AnnotationGroupList.1.Text: Position (Gaussian 2)
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.DrawingMode: 2
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.FontAttributes: 7
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.FontFaceName: 굴림체
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.FontSize: 11.882353782653809
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.Justification: 3
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.ScreenSize: [90. 14.]
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.TextLength: 21
# .DocumentObjectList.1.AnnotationGroupList.1.Transparency: 0.0
# .DocumentObjectList.1.AnnotationGroupList.1.UniqueID: 10
# .DocumentObjectList.1.AnnotationType: 20
# .DocumentObjectList.1.BackgroundColor: [-1. -1. -1.]
# .DocumentObjectList.1.BackgroundMode: 2
# .DocumentObjectList.1.FillMode: 1
# .DocumentObjectList.1.ForegroundColor: [0. 0. 0.]
# .DocumentObjectList.1.HasBackground: 0
# .DocumentObjectList.1.ImageDisplayInfo.BrightColor: [-1. -1. -1.]
# .DocumentObjectList.1.ImageDisplayInfo.Brightness: 0.5
# .DocumentObjectList.1.ImageDisplayInfo.CaptionOn: 0
# .DocumentObjectList.1.ImageDisplayInfo.CaptionSize: 10
# .DocumentObjectList.1.ImageDisplayInfo.CLUT.arraySize: 1536
# .DocumentObjectList.1.ImageDisplayInfo.CLUT.arrayOffset: 2929
# .DocumentObjectList.1.ImageDisplayInfo.CLUT.arrayType: 2.0
# .DocumentObjectList.1.ImageDisplayInfo.CLUT: Array unread. Encoded type = 2.0
# .DocumentObjectList.1.ImageDisplayInfo.CLUTName: Greyscale
# .DocumentObjectList.1.ImageDisplayInfo.ComplexMode: 4
# .DocumentObjectList.1.ImageDisplayInfo.ComplexRange: 1000.0
# .DocumentObjectList.1.ImageDisplayInfo.Contrast: 0.5
# .DocumentObjectList.1.ImageDisplayInfo.ContrastMode: 1
# .DocumentObjectList.1.ImageDisplayInfo.DiffractionMode: 0
# .DocumentObjectList.1.ImageDisplayInfo.DoAutoSurvey: 1
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMax: 103.5082015991211
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMaxTrimPercentage: 0.0010000000474974513
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMin: 125.2652359008789
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMinTrimPercentage: 0.0010000000474974513
# .DocumentObjectList.1.ImageDisplayInfo.Gamma: 0.5
# .DocumentObjectList.1.ImageDisplayInfo.HighLimit: 125.2652359008789
# .DocumentObjectList.1.ImageDisplayInfo.HiLimitContrastDeltaTriggerPercentage: 0.10000000149011612
# .DocumentObjectList.1.ImageDisplayInfo.IsIgnoreGirdBar: 0
# .DocumentObjectList.1.ImageDisplayInfo.IsInverted: 0
# .DocumentObjectList.1.ImageDisplayInfo.LowLimit: 103.5082015991211
# .DocumentObjectList.1.ImageDisplayInfo.LowLimitContrastDeltaTriggerPercentage: 0.10000000149011612
# .DocumentObjectList.1.ImageDisplayInfo.MainSliceId.1: 0
# .DocumentObjectList.1.ImageDisplayInfo.MinimumContrast: 0.0
# .DocumentObjectList.1.ImageDisplayInfo.RangeAdjust: 1.0
# .DocumentObjectList.1.ImageDisplayInfo.SparseSurvey_GridSize: 32
# .DocumentObjectList.1.ImageDisplayInfo.SparseSurvey_NumberPixels: 64
# .DocumentObjectList.1.ImageDisplayInfo.SparseSurvey_UseNumberPixels: 1
# .DocumentObjectList.1.ImageDisplayInfo.SurveyTechique: 2
# .DocumentObjectList.1.ImageDisplayType: 1
# .DocumentObjectList.1.ImageSource: 0
# .DocumentObjectList.1.IsMoveable: 1
# .DocumentObjectList.1.IsResizable: 1
# .DocumentObjectList.1.IsSelectable: 1
# .DocumentObjectList.1.IsTransferrable: 1
# .DocumentObjectList.1.IsTranslatable: 1
# .DocumentObjectList.1.IsVisible: 1
# .DocumentObjectList.1.Rectangle: [  0.           0.         884.           6.73267317]
# .DocumentObjectList.1.RestrictionStyle: 0
# .DocumentObjectList.1.Transparency: 0.0
# .DocumentObjectList.1.UniqueID: 8
# .HasWindowPosition: 1
# .Image Behavior.ImageDisplayBounds: [  0.           0.         884.           6.73267317]
# .Image Behavior.IsZoomedToWindow: 1
# .Image Behavior.UnscaledTransform.Offset: [0. 0.]
# .Image Behavior.UnscaledTransform.Scale: [1. 1.]
# .Image Behavior.ViewDisplayID: 8
# .Image Behavior.WindowRect: [  0.   0. 884.   9.]
# .Image Behavior.ZoomAndMoveTransform.Offset: [1.13366342 0.        ]
# .Image Behavior.ZoomAndMoveTransform.Scale: [1. 1.]
# .ImageList.1.ImageData.Calibrations.Brightness.Label:
# .ImageList.1.ImageData.Calibrations.Brightness.Origin: 0.0
# .ImageList.1.ImageData.Calibrations.Brightness.Scale: 1.0
# .ImageList.1.ImageData.Calibrations.Brightness.Units:
# .ImageList.1.ImageData.Calibrations.Dimension.1.Label:
# .ImageList.1.ImageData.Calibrations.Dimension.1.Origin: 0.0
# .ImageList.1.ImageData.Calibrations.Dimension.1.Scale: 1.0
# .ImageList.1.ImageData.Calibrations.Dimension.1.Units:
# .ImageList.1.ImageData.Calibrations.Dimension.2.Label:
# .ImageList.1.ImageData.Calibrations.Dimension.2.Origin: 0.0
# .ImageList.1.ImageData.Calibrations.Dimension.2.Scale: 1.0
# .ImageList.1.ImageData.Calibrations.Dimension.2.Units:
# .ImageList.1.ImageData.Calibrations.DisplayCalibratedUnits: 1
# .ImageList.1.ImageData.Data.arraySize: 59904
# .ImageList.1.ImageData.Data.arrayOffset: 8274
# .ImageList.1.ImageData.Data.arrayType: 3
# .ImageList.1.ImageData.Data: Data unread. Encoded type = 3
# .ImageList.1.ImageData.DataType: 23
# .ImageList.1.ImageData.Dimensions.1: 39
# .ImageList.1.ImageData.Dimensions.2: 384
# .ImageList.1.ImageData.PixelDepth: 4
# .ImageList.1.ImageTags.GMS Version.Created: 3.60.4441.0
# .ImageList.1.Name: Image Of Position (Gaussian 2)
# .ImageList.1.UniqueID.1: 1681460281
# .ImageList.1.UniqueID.2: 1774079365
# .ImageList.1.UniqueID.3: 1113396881
# .ImageList.1.UniqueID.4: 403202823
# .ImageList.2.ImageData.Calibrations.Brightness.Label:
# .ImageList.2.ImageData.Calibrations.Brightness.Origin: 0.0
# .ImageList.2.ImageData.Calibrations.Brightness.Scale: 1.0
# .ImageList.2.ImageData.Calibrations.Brightness.Units:
# .ImageList.2.ImageData.Calibrations.Dimension.1.Label:
# .ImageList.2.ImageData.Calibrations.Dimension.1.Origin: 0.0
# .ImageList.2.ImageData.Calibrations.Dimension.1.Scale: 1.0
# .ImageList.2.ImageData.Calibrations.Dimension.1.Units:
# .ImageList.2.ImageData.Calibrations.Dimension.2.Label:
# .ImageList.2.ImageData.Calibrations.Dimension.2.Origin: 0.0
# .ImageList.2.ImageData.Calibrations.Dimension.2.Scale: 1.0
# .ImageList.2.ImageData.Calibrations.Dimension.2.Units:
# .ImageList.2.ImageData.Calibrations.DisplayCalibratedUnits: 1
# .ImageList.2.ImageData.Data.arraySize: 105040
# .ImageList.2.ImageData.Data.arrayOffset: 69632
# .ImageList.2.ImageData.Data.arrayType: 7
# .ImageList.2.ImageData.Data: Data unread. Encoded type = 7
# .ImageList.2.ImageData.DataType: 12
# .ImageList.2.ImageData.Dimensions.1: 10
# .ImageList.2.ImageData.Dimensions.2: 1313
# .ImageList.2.ImageData.PixelDepth: 8
# .ImageList.2.ImageTags.GMS Version.Created: 3.60.4441.0
# .ImageList.2.ImageTags.GMS Version.Saved: 3.60.4441.0
# .ImageList.2.ImageTags.Meta Data.Format: Image
# .ImageList.2.ImageTags.Processing.1.Operation: LS Fitting
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Fit range.From: 44.0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Fit range.To: 73.0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Is background: 0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Name: Gaussian 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.1.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.1.Name: Amplitude
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.1.Value: 661932.8375398618
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.2.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.2.Name: Position
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.2.Value: 60.956777387957
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.3.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.3.Force positive value: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.3.Name: FWHM
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Parameters.3.Value: 27.82515443006394
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.1.Type: Gaussian
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Fit range.From: 92.0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Fit range.To: 151.0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Is background: 0
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Name: Gaussian 2
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.1.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.1.Name: Amplitude
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.1.Value: 2363996.9664884564
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.2.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.2.Name: Position
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.2.Value: 123.97839005053441
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.3.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.3.Force positive value: 1
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.3.Name: FWHM
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Parameters.3.Value: 56.39527767337606
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Items.2.Type: Gaussian
# .ImageList.2.ImageTags.Processing.1.Parameters.Fitter.Name: MinPack
# .ImageList.2.ImageTags.Processing.1.Parameters.Last fit's red.chi.sqr.: 9053493935.568539
# .ImageList.2.ImageTags.Processing.1.Parameters.Mode: NLLS
# .ImageList.2.ImageTags.Processing.1.Parameters.Value: Position (Gaussian 2)
# .ImageList.2.ImageTags.Processing.1.Parent.Name: DP profile(ring)(without baseline)
# .ImageList.2.ImageTags.Processing.1.Parent.Unique Image ID: [1.86609234e+09 1.98037105e+09 1.59026305e+09 9.99555789e+08]
# .ImageList.2.ImageTags.Processing.1.Time: 2024-07-10, 오후 3:47:04
# .ImageList.2.Name: Position (Gaussian 2)
# .ImageList.2.UniqueID.1: 374674881
# .ImageList.2.UniqueID.2: 869758748
# .ImageList.2.UniqueID.3: 112028713
# .ImageList.2.UniqueID.4: 763893539
# .ImageSourceList.1.ClassName: ImageSource:Simple
# .ImageSourceList.1.Id.1: 0
# .ImageSourceList.1.ImageRef: 1
# .InImageMode: 1
# .LayoutType: Unknown
# .MinVersionList.1.RequiredVersion: 50659328
# .NextDocumentObjectID: 11
# .Page Behavior.DrawMargins: 1
# .Page Behavior.DrawPaper: 1
# .Page Behavior.IsFixedInPageMode: 0
# .Page Behavior.IsZoomedToWindow: 1
# .Page Behavior.LayedOut: 0
# .Page Behavior.PageTransform.Offset: [0. 0.]
# .Page Behavior.PageTransform.Scale: [1. 1.]
# .Page Behavior.RestoreImageDisplayBounds: [   0.    0. 1313.   10.]
# .Page Behavior.RestoreImageDisplayID: 8
# .Page Behavior.TargetDisplayID: 4294967295
# .PageSetup.General: [ 1.00000000e+00  2.68435556e+08  2.10000000e+04  2.97000000e+04
#   2.50000000e+03  2.50000000e+03 -2.50000000e+03 -2.50000000e+03]
# .PageSetup.Win32:RtÄ	Ä	Ä	Ä
# .PageSetup.Win32_DevModeW.arraySize: 5420
# .PageSetup.Win32_DevModeW.arrayOffset: 179849
# .PageSetup.Win32_DevModeW.arrayType: 10
# .PageSetup.Win32_DevModeW: Array unread. Encoded type = 10
# .PageSetup.Win32_DevNamesW: 2Microsoft Print To PDFMicrosoft Print to PDFPORTPROMPT:
# .Thumbnails.1.ImageIndex: 0
# .Thumbnails.1.SourceSize_Pixels: [ 90. 884.]
# .WindowPosition: [ 31. 133. 915. 142.]
# Saved D:\Users\doyeob\Desktop\3layerBP data\fitting using gatan\ring\Position (Gaussian 2).tif
# 모든 DM4 파일이 TIFF 파일로 성공적으로 변환되었습니다.
