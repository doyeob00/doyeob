# %%
import os
import numpy as np
from ncempy.io import dm
import tifffile as tiff
import imageio.v2 as imageio
import matplotlib.pyplot as plt
import pandas as pd

# %%
# 입력 폴더와 출력 폴더 경로
input_folder = r"C:\Users\doyeob\Desktop\3layerBP data\fitting using gatan\101\radial\A\2\dm4"
output_folder = r"C:\Users\doyeob\Desktop\3layerBP data\fitting using gatan\101\radial\A\2"

# 출력 폴더가 없으면 생성
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# 빈 DataFrame 생성
all_data = pd.DataFrame()

# 플롯팅 함수 정의
def plot_first_column_intensity(data, title):
    plt.figure(figsize=(10, 6))
    x = np.arange(data.shape[0])
    plt.plot(x, data, label=title)
    plt.xlabel('Pixel Index')
    plt.ylabel('Intensity')
    plt.title(f'{title}')
    plt.legend()
    plt.ylim(data.min() - 0.5, data.max() + 0.5)
    plt.show()

# 입력 폴더 내 모든 DM4 파일에 대해 작업 수행
for filename in os.listdir(input_folder):
    if filename.endswith('.dm4'):
        input_dm4_file = os.path.join(input_folder, filename)
        output_tiff_file = os.path.join(output_folder, f'{os.path.splitext(filename)[0]}.tif')

        # DM4 파일 읽기
        dm4_data = dm.fileDM(input_dm4_file)

        # DM4 데이터 내용 확인
        print(f"Processing {filename}...")

        # 데이터셋 이름을 사용하여 데이터 추출
        try:
            dataset = dm4_data.getDataset(0)  # 첫 번째 데이터셋 접근
            image_data = dataset['data']      # 데이터 추출

            # TIFF 파일로 저장 (스케일 적용)
            if 'amplitude' in filename:
                scaled_image_data = image_data.astype(np.float32)
            elif 'fwhm' in filename:
                scaled_image_data = (image_data).astype(np.float32)
                print(f"fwhm scaling applied: min={scaled_image_data.min()}, max={scaled_image_data.max()}")
            elif 'position' in filename:
                scaled_image_data = (image_data).astype(np.float32)
                print(f"position scaling applied: min={scaled_image_data.min()}, max={scaled_image_data.max()}")
            else:
                scaled_image_data = image_data.astype(np.float32)  # Default to no scaling if not identified

            tiff.imwrite(output_tiff_file, scaled_image_data, photometric='minisblack')
            print(f"Saved {output_tiff_file}")

            # TIFF 파일 열기
            image = imageio.imread(output_tiff_file)

            # 첫 번째 열의 intensity 값 추출
            first_column_intensity = image[:, 0]

            # 파일 이름에서 기본 이름 추출
            base_name = os.path.basename(output_tiff_file).split('.')[0]

            # pandas DataFrame으로 변환
            df = pd.DataFrame(first_column_intensity, columns=[base_name])

            # 데이터를 병합
            if all_data.empty:
                all_data = df
            else:
                all_data = pd.concat([all_data, df], axis=1)

            # 각 파일의 데이터를 개별적으로 플로팅
            plot_first_column_intensity(first_column_intensity, base_name)

        except Exception as e:
            print(f"Failed to process {filename}: {e}")

# Excel 파일로 저장
excel_file = os.path.join(output_folder, '101_radial_A2 information.xlsx')
all_data.to_excel(excel_file, index=False)

# 확인 메세지 출력
print(f'First column intensity data from all TIFF files saved to {excel_file}')
# Out:
# Processing Amplitude (Lorentzian 1).dm4...
# Saved C:\Users\doyeob\Desktop\3layerBP data\fitting using gatan\101\radial\A\2\Amplitude (Lorentzian 1).tif
# Processing FWHM (Lorentzian 1).dm4...
# Saved C:\Users\doyeob\Desktop\3layerBP data\fitting using gatan\101\radial\A\2\FWHM (Lorentzian 1).tif
# Processing Position (Lorentzian 1).dm4...
# Saved C:\Users\doyeob\Desktop\3layerBP data\fitting using gatan\101\radial\A\2\Position (Lorentzian 1).tif
# First column intensity data from all TIFF files saved to C:\Users\doyeob\Desktop\3layerBP data\fitting using gatan\101\radial\A\2\101_radial_A2 information.xlsx

# %%
import os
import numpy as np
from ncempy.io import dm
import tifffile as tiff

# 입력 폴더와 출력 폴더 경로
input_folder = r"C:\Users\doyeob\Desktop\3layerBP data\fitting using gatan\200\radial\1\dm4"
output_folder = r"C:\Users\doyeob\Desktop\3layerBP data\fitting using gatan\200\radial\1"
# 출력 폴더가 없으면 생성
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# 입력 폴더 내 모든 DM4 파일에 대해 작업 수행
for filename in os.listdir(input_folder):
    if filename.endswith('.dm4'):
        input_dm4_file = os.path.join(input_folder, filename)
        output_tiff_file = os.path.join(output_folder, f'{os.path.splitext(filename)[0]}.tif')

        # DM4 파일 읽기
        dm4_data = dm.fileDM(input_dm4_file)

        # DM4 데이터 내용 확인
        print(f"Processing {filename}...")

        # 모든 메타데이터와 키를 출력하여 구조 파악
        dm4_metadata = dm4_data.allTags
        for key, value in dm4_metadata.items():
            print(f"{key}: {value}")

        # 데이터셋 이름을 사용하여 데이터 추출
        try:
            dataset = dm4_data.getDataset(0)  # 첫 번째 데이터셋 접근
            image_data = dataset['data']      # 데이터 추출

            # TIFF 파일로 저장 (그레이 스케일)
            tiff.imwrite(output_tiff_file, image_data.astype(np.float32), photometric='minisblack')
            print(f"Saved {output_tiff_file}")

        except Exception as e:
            print(f"Failed to process {filename}: {e}")

print("모든 DM4 파일이 TIFF 파일로 성공적으로 변환되었습니다.")
# Out:
# Processing Amplitude (Lorentzian 1).dm4...
# .ApplicationBounds: [   0.    0.  907. 1982.]
# .BackgroundColor: [-2571. -2571. -1286.]
# .DocumentObjectList.1.AnnotationGroupList.1.AnnotationType: 13
# .DocumentObjectList.1.AnnotationGroupList.1.BackgroundColor: [-1. -1. -1.]
# .DocumentObjectList.1.AnnotationGroupList.1.BackgroundMode: 2
# .DocumentObjectList.1.AnnotationGroupList.1.FillMode: 2
# .DocumentObjectList.1.AnnotationGroupList.1.FixedPoint: [0. 0.]
# .DocumentObjectList.1.AnnotationGroupList.1.ForegroundColor: [-1. -1.  0.]
# .DocumentObjectList.1.AnnotationGroupList.1.HasBackground: 0
# .DocumentObjectList.1.AnnotationGroupList.1.IsMoveable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsResizable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsSelectable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsTransferrable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsTranslatable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsVisible: 1
# .DocumentObjectList.1.AnnotationGroupList.1.ObjectTags.LSFITMapLabel: 1
# .DocumentObjectList.1.AnnotationGroupList.1.Rectangle: [ 32.82500076   0.          54.12511444 155.18655396]
# .DocumentObjectList.1.AnnotationGroupList.1.ResizeStyle: 48
# .DocumentObjectList.1.AnnotationGroupList.1.RestrictionStyle: 0
# .DocumentObjectList.1.AnnotationGroupList.1.Text: Amplitude (Lorentzian 1)
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.DrawingMode: 2
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.FontAttributes: 7
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.FontFaceName: 굴림체
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.FontSize: 12.171494483947754
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.Justification: 3
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.ScreenSize: [102.  14.]
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.TextLength: 24
# .DocumentObjectList.1.AnnotationGroupList.1.Transparency: 0.0
# .DocumentObjectList.1.AnnotationGroupList.1.UniqueID: 10
# .DocumentObjectList.1.AnnotationType: 20
# .DocumentObjectList.1.BackgroundColor: [-1. -1. -1.]
# .DocumentObjectList.1.BackgroundMode: 2
# .DocumentObjectList.1.FillMode: 1
# .DocumentObjectList.1.ForegroundColor: [0. 0. 0.]
# .DocumentObjectList.1.HasBackground: 0
# .DocumentObjectList.1.ImageDisplayInfo.BrightColor: [-1. -1. -1.]
# .DocumentObjectList.1.ImageDisplayInfo.Brightness: 0.5
# .DocumentObjectList.1.ImageDisplayInfo.CaptionOn: 0
# .DocumentObjectList.1.ImageDisplayInfo.CaptionSize: 10
# .DocumentObjectList.1.ImageDisplayInfo.CLUT.arraySize: 1536
# .DocumentObjectList.1.ImageDisplayInfo.CLUT.arrayOffset: 2935
# .DocumentObjectList.1.ImageDisplayInfo.CLUT.arrayType: 2.0
# .DocumentObjectList.1.ImageDisplayInfo.CLUT: Array unread. Encoded type = 2.0
# .DocumentObjectList.1.ImageDisplayInfo.CLUTName: Greyscale
# .DocumentObjectList.1.ImageDisplayInfo.ComplexMode: 4
# .DocumentObjectList.1.ImageDisplayInfo.ComplexRange: 1000.0
# .DocumentObjectList.1.ImageDisplayInfo.Contrast: 0.5
# .DocumentObjectList.1.ImageDisplayInfo.ContrastMode: 1
# .DocumentObjectList.1.ImageDisplayInfo.DiffractionMode: 0
# .DocumentObjectList.1.ImageDisplayInfo.DoAutoSurvey: 1
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMax: 6791.94384765625
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMaxTrimPercentage: 0.0010000000474974513
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMin: 1221385.875
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMinTrimPercentage: 0.0010000000474974513
# .DocumentObjectList.1.ImageDisplayInfo.Gamma: 0.5
# .DocumentObjectList.1.ImageDisplayInfo.HighLimit: 1221385.875
# .DocumentObjectList.1.ImageDisplayInfo.HiLimitContrastDeltaTriggerPercentage: 0.10000000149011612
# .DocumentObjectList.1.ImageDisplayInfo.IsIgnoreGirdBar: 0
# .DocumentObjectList.1.ImageDisplayInfo.IsInverted: 0
# .DocumentObjectList.1.ImageDisplayInfo.LowLimit: 6791.94384765625
# .DocumentObjectList.1.ImageDisplayInfo.LowLimitContrastDeltaTriggerPercentage: 0.10000000149011612
# .DocumentObjectList.1.ImageDisplayInfo.MainSliceId.1: 0
# .DocumentObjectList.1.ImageDisplayInfo.MinimumContrast: 0.0
# .DocumentObjectList.1.ImageDisplayInfo.RangeAdjust: 1.0
# .DocumentObjectList.1.ImageDisplayInfo.SparseSurvey_GridSize: 32
# .DocumentObjectList.1.ImageDisplayInfo.SparseSurvey_NumberPixels: 64
# .DocumentObjectList.1.ImageDisplayInfo.SparseSurvey_UseNumberPixels: 1
# .DocumentObjectList.1.ImageDisplayInfo.SurveyTechique: 2
# .DocumentObjectList.1.ImageDisplayType: 1
# .DocumentObjectList.1.ImageSource: 0
# .DocumentObjectList.1.IsMoveable: 1
# .DocumentObjectList.1.IsResizable: 1
# .DocumentObjectList.1.IsSelectable: 1
# .DocumentObjectList.1.IsTransferrable: 1
# .DocumentObjectList.1.IsTranslatable: 1
# .DocumentObjectList.1.IsVisible: 1
# .DocumentObjectList.1.Rectangle: [  0.           0.         863.           6.57273388]
# .DocumentObjectList.1.RestrictionStyle: 0
# .DocumentObjectList.1.Transparency: 0.0
# .DocumentObjectList.1.UniqueID: 8
# .HasWindowPosition: 1
# .Image Behavior.ImageDisplayBounds: [  0.           0.         863.           6.57273388]
# .Image Behavior.IsZoomedToWindow: 1
# .Image Behavior.UnscaledTransform.Offset: [0. 0.]
# .Image Behavior.UnscaledTransform.Scale: [1. 1.]
# .Image Behavior.ViewDisplayID: 8
# .Image Behavior.WindowRect: [  0.   0. 863.   9.]
# .Image Behavior.ZoomAndMoveTransform.Offset: [1.21363306 0.        ]
# .Image Behavior.ZoomAndMoveTransform.Scale: [1. 1.]
# .ImageList.1.ImageData.Calibrations.Brightness.Label:
# .ImageList.1.ImageData.Calibrations.Brightness.Origin: 0.0
# .ImageList.1.ImageData.Calibrations.Brightness.Scale: 1.0
# .ImageList.1.ImageData.Calibrations.Brightness.Units:
# .ImageList.1.ImageData.Calibrations.Dimension.1.Label:
# .ImageList.1.ImageData.Calibrations.Dimension.1.Origin: 0.0
# .ImageList.1.ImageData.Calibrations.Dimension.1.Scale: 1.0
# .ImageList.1.ImageData.Calibrations.Dimension.1.Units:
# .ImageList.1.ImageData.Calibrations.Dimension.2.Label:
# .ImageList.1.ImageData.Calibrations.Dimension.2.Origin: 0.0
# .ImageList.1.ImageData.Calibrations.Dimension.2.Scale: 1.0
# .ImageList.1.ImageData.Calibrations.Dimension.2.Units:
# .ImageList.1.ImageData.Calibrations.DisplayCalibratedUnits: 1
# .ImageList.1.ImageData.Data.arraySize: 69120
# .ImageList.1.ImageData.Data.arrayOffset: 8280
# .ImageList.1.ImageData.Data.arrayType: 3
# .ImageList.1.ImageData.Data: Data unread. Encoded type = 3
# .ImageList.1.ImageData.DataType: 23
# .ImageList.1.ImageData.Dimensions.1: 45
# .ImageList.1.ImageData.Dimensions.2: 384
# .ImageList.1.ImageData.PixelDepth: 4
# .ImageList.1.ImageTags.GMS Version.Created: 3.60.4441.0
# .ImageList.1.Name: Image Of Amplitude (Lorentzian 1)
# .ImageList.1.UniqueID.1: 1010058290
# .ImageList.1.UniqueID.2: 339755326
# .ImageList.1.UniqueID.3: 1980133795
# .ImageList.1.UniqueID.4: 1857765079
# .ImageList.2.ImageData.Calibrations.Brightness.Label:
# .ImageList.2.ImageData.Calibrations.Brightness.Origin: 0.0
# .ImageList.2.ImageData.Calibrations.Brightness.Scale: 1.0
# .ImageList.2.ImageData.Calibrations.Brightness.Units:
# .ImageList.2.ImageData.Calibrations.Dimension.1.Label:
# .ImageList.2.ImageData.Calibrations.Dimension.1.Origin: 0.0
# .ImageList.2.ImageData.Calibrations.Dimension.1.Scale: 1.0
# .ImageList.2.ImageData.Calibrations.Dimension.1.Units:
# .ImageList.2.ImageData.Calibrations.Dimension.2.Label:
# .ImageList.2.ImageData.Calibrations.Dimension.2.Origin: 0.0
# .ImageList.2.ImageData.Calibrations.Dimension.2.Scale: 1.0
# .ImageList.2.ImageData.Calibrations.Dimension.2.Units:
# .ImageList.2.ImageData.Calibrations.DisplayCalibratedUnits: 1
# .ImageList.2.ImageData.Data.arraySize: 105040
# .ImageList.2.ImageData.Data.arrayOffset: 78860
# .ImageList.2.ImageData.Data.arrayType: 7
# .ImageList.2.ImageData.Data: Data unread. Encoded type = 7
# .ImageList.2.ImageData.DataType: 12
# .ImageList.2.ImageData.Dimensions.1: 10
# .ImageList.2.ImageData.Dimensions.2: 1313
# .ImageList.2.ImageData.PixelDepth: 8
# .ImageList.2.ImageTags.GMS Version.Created: 3.60.4441.0
# .ImageList.2.ImageTags.GMS Version.Saved: 3.60.4441.0
# .ImageList.2.ImageTags.Meta Data.Format: Image
# .ImageList.2.ImageTags.Processing.1.Operation: Background Removal
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Parameters.Model equation: y = a0*x^(-a1)
# .ImageList.2.ImageTags.Processing.1.Parameters.Fitting Region(s).1.end channel: 179
# .ImageList.2.ImageTags.Processing.1.Parameters.Fitting Region(s).1.start channel: 124
# .ImageList.2.ImageTags.Processing.1.Parameters.Model: Power Law
# .ImageList.2.ImageTags.Processing.1.Parent.Name: 200radial_1
# .ImageList.2.ImageTags.Processing.1.Parent.Unique Image ID: [1.78474670e+08 7.76218840e+07 1.90004854e+09 1.39185412e+09]
# .ImageList.2.ImageTags.Processing.1.Time: 2024-07-11, 오후 3:38:15
# .ImageList.2.ImageTags.Processing.2.Operation: LS Fitting
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Fit range.From: 186.0
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Fit range.To: 226.0
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Is background: 0
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Name: Lorentzian 1
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.1.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.1.Name: Amplitude
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.1.Value: 530799.6580583813
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.2.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.2.Name: Position
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.2.Value: 201.80981907926034
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.3.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.3.Force positive value: 1
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.3.Name: FWHM
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.3.Value: 1.6401576608168473
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Type: Lorentzian
# .ImageList.2.ImageTags.Processing.2.Parameters.Fitter.Name: MinPack
# .ImageList.2.ImageTags.Processing.2.Parameters.Last fit's red.chi.sqr.: 210104224.03501126
# .ImageList.2.ImageTags.Processing.2.Parameters.Mode: NLLS
# .ImageList.2.ImageTags.Processing.2.Parameters.Value: Amplitude (Lorentzian 1)
# .ImageList.2.ImageTags.Processing.2.Parent.Name: Signal SI
# .ImageList.2.ImageTags.Processing.2.Parent.Unique Image ID: [4.76272922e+08 1.93681541e+08 2.28883774e+08 1.21985012e+09]
# .ImageList.2.ImageTags.Processing.2.Time: 2024-07-11, 오후 3:38:33
# .ImageList.2.Name: Amplitude (Lorentzian 1)
# .ImageList.2.UniqueID.1: 1107259363
# .ImageList.2.UniqueID.2: 289423537
# .ImageList.2.UniqueID.3: 2106555926
# .ImageList.2.UniqueID.4: 968107276
# .ImageSourceList.1.ClassName: ImageSource:Simple
# .ImageSourceList.1.Id.1: 0
# .ImageSourceList.1.ImageRef: 1
# .InImageMode: 1
# .LayoutType: Unknown
# .MinVersionList.1.RequiredVersion: 50659328
# .NextDocumentObjectID: 11
# .Page Behavior.DrawMargins: 1
# .Page Behavior.DrawPaper: 1
# .Page Behavior.IsFixedInPageMode: 0
# .Page Behavior.IsZoomedToWindow: 1
# .Page Behavior.LayedOut: 0
# .Page Behavior.PageTransform.Offset: [0. 0.]
# .Page Behavior.PageTransform.Scale: [1. 1.]
# .Page Behavior.RestoreImageDisplayBounds: [   0.    0. 1313.   10.]
# .Page Behavior.RestoreImageDisplayID: 8
# .Page Behavior.TargetDisplayID: 4294967295
# .PageSetup.General: [ 1.00000000e+00  2.68435556e+08  2.10000000e+04  2.97000000e+04
#   2.50000000e+03  2.50000000e+03 -2.50000000e+03 -2.50000000e+03]
# .PageSetup.Win32:RtÄ	Ä	Ä	Ä
# .PageSetup.Win32_DevModeW.arraySize: 2712
# .PageSetup.Win32_DevModeW.arrayOffset: 188965
# .PageSetup.Win32_DevModeW.arrayType: 10
# .PageSetup.Win32_DevModeW: Array unread. Encoded type = 10
# .PageSetup.Win32_DevNamesW: Hancom PDFHancom PDFHancom PDF Port
# .Thumbnails.1.ImageIndex: 0
# .Thumbnails.1.SourceSize_Pixels: [102. 863.]
# .WindowPosition: [ 31.   8. 894.  17.]
# Saved C:\Users\doyeob\Desktop\3layerBP data\fitting using gatan\200\radial\1\Amplitude (Lorentzian 1).tif
# Processing Fit (Lorentzian 1).dm4...
# .ApplicationBounds: [   0.    0.  907. 1982.]
# .BackgroundColor: [-2571. -2571. -1286.]
# .DocumentObjectList.1.AnnotationType: 20
# .DocumentObjectList.1.BackgroundColor: [-1. -1. -1.]
# .DocumentObjectList.1.BackgroundMode: 2
# .DocumentObjectList.1.FillMode: 1
# .DocumentObjectList.1.ForegroundColor: [0. 0. 0.]
# .DocumentObjectList.1.HasBackground: 0
# .DocumentObjectList.1.ImageDisplayInfo.BrightColor: [-1. -1. -1.]
# .DocumentObjectList.1.ImageDisplayInfo.Brightness: 0.5
# .DocumentObjectList.1.ImageDisplayInfo.CaptionOn: 0
# .DocumentObjectList.1.ImageDisplayInfo.CaptionSize: 10
# .DocumentObjectList.1.ImageDisplayInfo.CLUT.arraySize: 1536
# .DocumentObjectList.1.ImageDisplayInfo.CLUT.arrayOffset: 1210
# .DocumentObjectList.1.ImageDisplayInfo.CLUT.arrayType: 2.0
# .DocumentObjectList.1.ImageDisplayInfo.CLUT: Array unread. Encoded type = 2.0
# .DocumentObjectList.1.ImageDisplayInfo.CLUTName: Greyscale
# .DocumentObjectList.1.ImageDisplayInfo.ComplexMode: 4
# .DocumentObjectList.1.ImageDisplayInfo.ComplexRange: 1000.0
# .DocumentObjectList.1.ImageDisplayInfo.Contrast: 0.5
# .DocumentObjectList.1.ImageDisplayInfo.ContrastMode: 1
# .DocumentObjectList.1.ImageDisplayInfo.DiffractionMode: 0
# .DocumentObjectList.1.ImageDisplayInfo.DoAutoSurvey: 0
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMax: 2.524705648422241
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMaxTrimPercentage: 0.0010000000474974513
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMin: 100.50100708007812
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMinTrimPercentage: 0.0010000000474974513
# .DocumentObjectList.1.ImageDisplayInfo.Gamma: 0.5
# .DocumentObjectList.1.ImageDisplayInfo.HighLimit: 89.5387954711914
# .DocumentObjectList.1.ImageDisplayInfo.HiLimitContrastDeltaTriggerPercentage: 0.10000000149011612
# .DocumentObjectList.1.ImageDisplayInfo.IsIgnoreGirdBar: 0
# .DocumentObjectList.1.ImageDisplayInfo.IsInverted: 0
# .DocumentObjectList.1.ImageDisplayInfo.LowLimit: 0.7343710064888
# .DocumentObjectList.1.ImageDisplayInfo.LowLimitContrastDeltaTriggerPercentage: 0.10000000149011612
# .DocumentObjectList.1.ImageDisplayInfo.MainSliceId.1: 0
# .DocumentObjectList.1.ImageDisplayInfo.MinimumContrast: 0.0
# .DocumentObjectList.1.ImageDisplayInfo.RangeAdjust: 1.0
# .DocumentObjectList.1.ImageDisplayInfo.SparseSurvey_GridSize: 32
# .DocumentObjectList.1.ImageDisplayInfo.SparseSurvey_NumberPixels: 64
# .DocumentObjectList.1.ImageDisplayInfo.SparseSurvey_UseNumberPixels: 1
# .DocumentObjectList.1.ImageDisplayInfo.SurveyTechique: 2
# .DocumentObjectList.1.ImageDisplayType: 1
# .DocumentObjectList.1.ImageSource: 0
# .DocumentObjectList.1.IsMoveable: 1
# .DocumentObjectList.1.IsResizable: 1
# .DocumentObjectList.1.IsSelectable: 1
# .DocumentObjectList.1.IsTransferrable: 1
# .DocumentObjectList.1.IsTranslatable: 1
# .DocumentObjectList.1.IsVisible: 1
# .DocumentObjectList.1.Rectangle: [  0.           0.         863.           6.57273388]
# .DocumentObjectList.1.RestrictionStyle: 0
# .DocumentObjectList.1.Transparency: 0.0
# .DocumentObjectList.1.UniqueID: 8
# .HasWindowPosition: 1
# .Image Behavior.ImageDisplayBounds: [  0.           0.         863.           6.57273388]
# .Image Behavior.IsZoomedToWindow: 1
# .Image Behavior.UnscaledTransform.Offset: [0. 0.]
# .Image Behavior.UnscaledTransform.Scale: [1. 1.]
# .Image Behavior.ViewDisplayID: 8
# .Image Behavior.WindowRect: [  0.   0. 863.   9.]
# .Image Behavior.ZoomAndMoveTransform.Offset: [1.21363306 0.        ]
# .Image Behavior.ZoomAndMoveTransform.Scale: [1. 1.]
# .ImageList.1.ImageData.Calibrations.Brightness.Label:
# .ImageList.1.ImageData.Calibrations.Brightness.Origin: 0.0
# .ImageList.1.ImageData.Calibrations.Brightness.Scale: 1.0
# .ImageList.1.ImageData.Calibrations.Brightness.Units:
# .ImageList.1.ImageData.Calibrations.Dimension.1.Label:
# .ImageList.1.ImageData.Calibrations.Dimension.1.Origin: 0.0
# .ImageList.1.ImageData.Calibrations.Dimension.1.Scale: 1.0
# .ImageList.1.ImageData.Calibrations.Dimension.1.Units:
# .ImageList.1.ImageData.Calibrations.Dimension.2.Label:
# .ImageList.1.ImageData.Calibrations.Dimension.2.Origin: 0.0
# .ImageList.1.ImageData.Calibrations.Dimension.2.Scale: 1.0
# .ImageList.1.ImageData.Calibrations.Dimension.2.Units:
# .ImageList.1.ImageData.Calibrations.DisplayCalibratedUnits: 1
# .ImageList.1.ImageData.Data.arraySize: 4608
# .ImageList.1.ImageData.Data.arrayOffset: 6555
# .ImageList.1.ImageData.Data.arrayType: 3
# .ImageList.1.ImageData.Data: Data unread. Encoded type = 3
# .ImageList.1.ImageData.DataType: 23
# .ImageList.1.ImageData.Dimensions.1: 3
# .ImageList.1.ImageData.Dimensions.2: 384
# .ImageList.1.ImageData.PixelDepth: 4
# .ImageList.1.ImageTags.GMS Version.Created: 3.60.4441.0
# .ImageList.1.Name: Image Of Fit (Lorentzian 1)
# .ImageList.1.UniqueID.1: 1597388779
# .ImageList.1.UniqueID.2: 672818315
# .ImageList.1.UniqueID.3: 2081227998
# .ImageList.1.UniqueID.4: 2112701601
# .ImageList.2.ImageData.Calibrations.Brightness.Label:
# .ImageList.2.ImageData.Calibrations.Brightness.Origin: 0.0
# .ImageList.2.ImageData.Calibrations.Brightness.Scale: 1.0
# .ImageList.2.ImageData.Calibrations.Brightness.Units:
# .ImageList.2.ImageData.Calibrations.Dimension.1.Label:
# .ImageList.2.ImageData.Calibrations.Dimension.1.Origin: 0.0
# .ImageList.2.ImageData.Calibrations.Dimension.1.Scale: 1.0
# .ImageList.2.ImageData.Calibrations.Dimension.1.Units:
# .ImageList.2.ImageData.Calibrations.Dimension.2.Label:
# .ImageList.2.ImageData.Calibrations.Dimension.2.Origin: 0.0
# .ImageList.2.ImageData.Calibrations.Dimension.2.Scale: 1.0
# .ImageList.2.ImageData.Calibrations.Dimension.2.Units:
# .ImageList.2.ImageData.Calibrations.Dimension.3.Label:
# .ImageList.2.ImageData.Calibrations.Dimension.3.Origin: -124.0
# .ImageList.2.ImageData.Calibrations.Dimension.3.Scale: 1.0
# .ImageList.2.ImageData.Calibrations.Dimension.3.Units:
# .ImageList.2.ImageData.Calibrations.DisplayCalibratedUnits: 1
# .ImageList.2.ImageData.Data.arraySize: 94536000
# .ImageList.2.ImageData.Data.arrayOffset: 12817
# .ImageList.2.ImageData.Data.arrayType: 7
# .ImageList.2.ImageData.Data: Data unread. Encoded type = 7
# .ImageList.2.ImageData.DataType: 12
# .ImageList.2.ImageData.Dimensions.1: 10
# .ImageList.2.ImageData.Dimensions.2: 1313
# .ImageList.2.ImageData.Dimensions.3: 900
# .ImageList.2.ImageData.PixelDepth: 8
# .ImageList.2.ImageTags.Elemental Quantification.State.AutoID.Enabled: 0
# .ImageList.2.ImageTags.Elemental Quantification.State.AutoID.Sensitivity: Mid
# .ImageList.2.ImageTags.Elemental Quantification.State.Elemental Parameters.Active Edge Group: -1
# .ImageList.2.ImageTags.Elemental Quantification.State.Elemental Parameters.Active Element: -1
# .ImageList.2.ImageTags.Elemental Quantification.State.Elemental Parameters.Analytical Technique: EELS
# .ImageList.2.ImageTags.Elemental Quantification.State.Elemental Parameters.End Energy: 1024.0
# .ImageList.2.ImageTags.Elemental Quantification.State.Elemental Parameters.Start Energy: 124.0
# .ImageList.2.ImageTags.Elemental Quantification.State.Mark Element.Atomic number: 25
# .ImageList.2.ImageTags.Elemental Quantification.State.Mark Element.Enabled: 0
# .ImageList.2.ImageTags.Elemental Quantification.State.Prefs.Include plural scattering: 0
# .ImageList.2.ImageTags.Elemental Quantification.State.Prefs.Label peaks: Major edge only label
# .ImageList.2.ImageTags.Elemental Quantification.State.Prefs.Show quant windows: 0
# .ImageList.2.ImageTags.Elemental Quantification.State.Prefs.ZLP extraction method (index): 1
# .ImageList.2.ImageTags.GMS Version.Saved: 3.60.4441.0
# .ImageList.2.ImageTags.Meta Data.Format: Spectrum image
# .ImageList.2.ImageTags.Meta Data.Signal: EELS
# .ImageList.2.ImageTags.Processing.1.Operation: Background Removal
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Parameters.Model equation: y = a0*x^(-a1)
# .ImageList.2.ImageTags.Processing.1.Parameters.Fitting Region(s).1.end channel: 179
# .ImageList.2.ImageTags.Processing.1.Parameters.Fitting Region(s).1.start channel: 124
# .ImageList.2.ImageTags.Processing.1.Parameters.Model: Power Law
# .ImageList.2.ImageTags.Processing.1.Parent.Name: 200radial_1
# .ImageList.2.ImageTags.Processing.1.Parent.Unique Image ID: [1.78474670e+08 7.76218840e+07 1.90004854e+09 1.39185412e+09]
# .ImageList.2.ImageTags.Processing.1.Time: 2024-07-11, 오후 3:38:15
# .ImageList.2.ImageTags.Processing.2.Operation: LS Fitting
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Fit range.From: 186.0
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Fit range.To: 226.0
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Is background: 0
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Name: Lorentzian 1
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.1.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.1.Name: Amplitude
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.1.Value: 530799.6580583813
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.2.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.2.Name: Position
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.2.Value: 201.80981907926034
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.3.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.3.Force positive value: 1
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.3.Name: FWHM
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.3.Value: 1.6401576608168473
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Type: Lorentzian
# .ImageList.2.ImageTags.Processing.2.Parameters.Fitter.Name: MinPack
# .ImageList.2.ImageTags.Processing.2.Parameters.Last fit's red.chi.sqr.: 210104224.03501126
# .ImageList.2.ImageTags.Processing.2.Parameters.Mode: NLLS
# .ImageList.2.ImageTags.Processing.2.Parameters.Value: Fit (Lorentzian 1)
# .ImageList.2.ImageTags.Processing.2.Parent.Name: Signal SI
# .ImageList.2.ImageTags.Processing.2.Parent.Unique Image ID: [4.76272922e+08 1.93681541e+08 2.28883774e+08 1.21985012e+09]
# .ImageList.2.ImageTags.Processing.2.Time: 2024-07-11, 오후 3:38:33
# .ImageList.2.Name: Fit (Lorentzian 1)
# .ImageList.2.UniqueID.1: 2103194108
# .ImageList.2.UniqueID.2: 1863413204
# .ImageList.2.UniqueID.3: 1269589084
# .ImageList.2.UniqueID.4: 2090339184
# .ImageSourceList.1.ClassName: ImageSource:Summed
# .ImageSourceList.1.Do Sum: 1
# .ImageSourceList.1.Id.1: 0
# .ImageSourceList.1.ImageRef: 1
# .ImageSourceList.1.LayerEnd: 0
# .ImageSourceList.1.LayerStart: 0
# .ImageSourceList.1.Summed Dimension: 2
# .InImageMode: 1
# .LayoutType: Unknown
# .MinVersionList.1.RequiredVersion: 50659328
# .NextDocumentObjectID: 10
# .Page Behavior.DrawMargins: 1
# .Page Behavior.DrawPaper: 1
# .Page Behavior.IsFixedInPageMode: 0
# .Page Behavior.IsZoomedToWindow: 1
# .Page Behavior.LayedOut: 0
# .Page Behavior.PageTransform.Offset: [0. 0.]
# .Page Behavior.PageTransform.Scale: [1. 1.]
# .Page Behavior.RestoreImageDisplayBounds: [   0.    0. 1313.   10.]
# .Page Behavior.RestoreImageDisplayID: 8
# .Page Behavior.TargetDisplayID: 4294967295
# .PageSetup.General: [ 1.00000000e+00  2.68435556e+08  2.10000000e+04  2.97000000e+04
#   2.50000000e+03  2.50000000e+03 -2.50000000e+03 -2.50000000e+03]
# .PageSetup.Win32:RtÄ	Ä	Ä	Ä
# .PageSetup.Win32_DevModeW.arraySize: 2712
# .PageSetup.Win32_DevModeW.arrayOffset: 94555052
# .PageSetup.Win32_DevModeW.arrayType: 10
# .PageSetup.Win32_DevModeW: Array unread. Encoded type = 10
# .PageSetup.Win32_DevNamesW: Hancom PDFHancom PDFHancom PDF Port
# .Thumbnails.1.ImageIndex: 0
# .Thumbnails.1.SourceSize_Pixels: [  7. 863.]
# .WindowPosition: [ 31.  83. 894.  92.]
# Saved C:\Users\doyeob\Desktop\3layerBP data\fitting using gatan\200\radial\1\Fit (Lorentzian 1).tif
# Processing FWHM (Lorentzian 1).dm4...
# .ApplicationBounds: [   0.    0.  907. 1982.]
# .BackgroundColor: [-2571. -2571. -1286.]
# .DocumentObjectList.1.AnnotationGroupList.1.AnnotationType: 13
# .DocumentObjectList.1.AnnotationGroupList.1.BackgroundColor: [-1. -1. -1.]
# .DocumentObjectList.1.AnnotationGroupList.1.BackgroundMode: 2
# .DocumentObjectList.1.AnnotationGroupList.1.FillMode: 2
# .DocumentObjectList.1.AnnotationGroupList.1.FixedPoint: [0. 0.]
# .DocumentObjectList.1.AnnotationGroupList.1.ForegroundColor: [-1. -1.  0.]
# .DocumentObjectList.1.AnnotationGroupList.1.HasBackground: 0
# .DocumentObjectList.1.AnnotationGroupList.1.IsMoveable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsResizable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsSelectable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsTransferrable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsTranslatable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsVisible: 1
# .DocumentObjectList.1.AnnotationGroupList.1.ObjectTags.LSFITMapLabel: 1
# .DocumentObjectList.1.AnnotationGroupList.1.Rectangle: [ 32.82500076   0.          54.12511444 124.75782013]
# .DocumentObjectList.1.AnnotationGroupList.1.ResizeStyle: 48
# .DocumentObjectList.1.AnnotationGroupList.1.RestrictionStyle: 0
# .DocumentObjectList.1.AnnotationGroupList.1.Text: FWHM (Lorentzian 1)
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.DrawingMode: 2
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.FontAttributes: 7
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.FontFaceName: 굴림체
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.FontSize: 12.171494483947754
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.Justification: 3
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.ScreenSize: [82. 14.]
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.TextLength: 19
# .DocumentObjectList.1.AnnotationGroupList.1.Transparency: 0.0
# .DocumentObjectList.1.AnnotationGroupList.1.UniqueID: 10
# .DocumentObjectList.1.AnnotationType: 20
# .DocumentObjectList.1.BackgroundColor: [-1. -1. -1.]
# .DocumentObjectList.1.BackgroundMode: 2
# .DocumentObjectList.1.FillMode: 1
# .DocumentObjectList.1.ForegroundColor: [0. 0. 0.]
# .DocumentObjectList.1.HasBackground: 0
# .DocumentObjectList.1.ImageDisplayInfo.BrightColor: [-1. -1. -1.]
# .DocumentObjectList.1.ImageDisplayInfo.Brightness: 0.5
# .DocumentObjectList.1.ImageDisplayInfo.CaptionOn: 0
# .DocumentObjectList.1.ImageDisplayInfo.CaptionSize: 10
# .DocumentObjectList.1.ImageDisplayInfo.CLUT.arraySize: 1536
# .DocumentObjectList.1.ImageDisplayInfo.CLUT.arrayOffset: 2925
# .DocumentObjectList.1.ImageDisplayInfo.CLUT.arrayType: 2.0
# .DocumentObjectList.1.ImageDisplayInfo.CLUT: Array unread. Encoded type = 2.0
# .DocumentObjectList.1.ImageDisplayInfo.CLUTName: Greyscale
# .DocumentObjectList.1.ImageDisplayInfo.ComplexMode: 4
# .DocumentObjectList.1.ImageDisplayInfo.ComplexRange: 1000.0
# .DocumentObjectList.1.ImageDisplayInfo.Contrast: 0.5
# .DocumentObjectList.1.ImageDisplayInfo.ContrastMode: 1
# .DocumentObjectList.1.ImageDisplayInfo.DiffractionMode: 0
# .DocumentObjectList.1.ImageDisplayInfo.DoAutoSurvey: 1
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMax: 0.7013680338859558
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMaxTrimPercentage: 0.0010000000474974513
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMin: 12.049954414367676
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMinTrimPercentage: 0.0010000000474974513
# .DocumentObjectList.1.ImageDisplayInfo.Gamma: 0.5
# .DocumentObjectList.1.ImageDisplayInfo.HighLimit: 12.049954414367676
# .DocumentObjectList.1.ImageDisplayInfo.HiLimitContrastDeltaTriggerPercentage: 0.10000000149011612
# .DocumentObjectList.1.ImageDisplayInfo.IsIgnoreGirdBar: 0
# .DocumentObjectList.1.ImageDisplayInfo.IsInverted: 0
# .DocumentObjectList.1.ImageDisplayInfo.LowLimit: 0.7013680338859558
# .DocumentObjectList.1.ImageDisplayInfo.LowLimitContrastDeltaTriggerPercentage: 0.10000000149011612
# .DocumentObjectList.1.ImageDisplayInfo.MainSliceId.1: 0
# .DocumentObjectList.1.ImageDisplayInfo.MinimumContrast: 0.0
# .DocumentObjectList.1.ImageDisplayInfo.RangeAdjust: 1.0
# .DocumentObjectList.1.ImageDisplayInfo.SparseSurvey_GridSize: 32
# .DocumentObjectList.1.ImageDisplayInfo.SparseSurvey_NumberPixels: 64
# .DocumentObjectList.1.ImageDisplayInfo.SparseSurvey_UseNumberPixels: 1
# .DocumentObjectList.1.ImageDisplayInfo.SurveyTechique: 2
# .DocumentObjectList.1.ImageDisplayType: 1
# .DocumentObjectList.1.ImageSource: 0
# .DocumentObjectList.1.IsMoveable: 1
# .DocumentObjectList.1.IsResizable: 1
# .DocumentObjectList.1.IsSelectable: 1
# .DocumentObjectList.1.IsTransferrable: 1
# .DocumentObjectList.1.IsTranslatable: 1
# .DocumentObjectList.1.IsVisible: 1
# .DocumentObjectList.1.Rectangle: [  0.           0.         863.           6.57273388]
# .DocumentObjectList.1.RestrictionStyle: 0
# .DocumentObjectList.1.Transparency: 0.0
# .DocumentObjectList.1.UniqueID: 8
# .HasWindowPosition: 1
# .Image Behavior.ImageDisplayBounds: [  0.           0.         863.           6.57273388]
# .Image Behavior.IsZoomedToWindow: 1
# .Image Behavior.UnscaledTransform.Offset: [0. 0.]
# .Image Behavior.UnscaledTransform.Scale: [1. 1.]
# .Image Behavior.ViewDisplayID: 8
# .Image Behavior.WindowRect: [  0.   0. 863.   9.]
# .Image Behavior.ZoomAndMoveTransform.Offset: [1.21363306 0.        ]
# .Image Behavior.ZoomAndMoveTransform.Scale: [1. 1.]
# .ImageList.1.ImageData.Calibrations.Brightness.Label:
# .ImageList.1.ImageData.Calibrations.Brightness.Origin: 0.0
# .ImageList.1.ImageData.Calibrations.Brightness.Scale: 1.0
# .ImageList.1.ImageData.Calibrations.Brightness.Units:
# .ImageList.1.ImageData.Calibrations.Dimension.1.Label:
# .ImageList.1.ImageData.Calibrations.Dimension.1.Origin: 0.0
# .ImageList.1.ImageData.Calibrations.Dimension.1.Scale: 1.0
# .ImageList.1.ImageData.Calibrations.Dimension.1.Units:
# .ImageList.1.ImageData.Calibrations.Dimension.2.Label:
# .ImageList.1.ImageData.Calibrations.Dimension.2.Origin: 0.0
# .ImageList.1.ImageData.Calibrations.Dimension.2.Scale: 1.0
# .ImageList.1.ImageData.Calibrations.Dimension.2.Units:
# .ImageList.1.ImageData.Calibrations.DisplayCalibratedUnits: 1
# .ImageList.1.ImageData.Data.arraySize: 55296
# .ImageList.1.ImageData.Data.arrayOffset: 8270
# .ImageList.1.ImageData.Data.arrayType: 3
# .ImageList.1.ImageData.Data: Data unread. Encoded type = 3
# .ImageList.1.ImageData.DataType: 23
# .ImageList.1.ImageData.Dimensions.1: 36
# .ImageList.1.ImageData.Dimensions.2: 384
# .ImageList.1.ImageData.PixelDepth: 4
# .ImageList.1.ImageTags.GMS Version.Created: 3.60.4441.0
# .ImageList.1.Name: Image Of FWHM (Lorentzian 1)
# .ImageList.1.UniqueID.1: 707816830
# .ImageList.1.UniqueID.2: 1829206826
# .ImageList.1.UniqueID.3: 1738621913
# .ImageList.1.UniqueID.4: 92678605
# .ImageList.2.ImageData.Calibrations.Brightness.Label:
# .ImageList.2.ImageData.Calibrations.Brightness.Origin: 0.0
# .ImageList.2.ImageData.Calibrations.Brightness.Scale: 1.0
# .ImageList.2.ImageData.Calibrations.Brightness.Units:
# .ImageList.2.ImageData.Calibrations.Dimension.1.Label:
# .ImageList.2.ImageData.Calibrations.Dimension.1.Origin: 0.0
# .ImageList.2.ImageData.Calibrations.Dimension.1.Scale: 1.0
# .ImageList.2.ImageData.Calibrations.Dimension.1.Units:
# .ImageList.2.ImageData.Calibrations.Dimension.2.Label:
# .ImageList.2.ImageData.Calibrations.Dimension.2.Origin: 0.0
# .ImageList.2.ImageData.Calibrations.Dimension.2.Scale: 1.0
# .ImageList.2.ImageData.Calibrations.Dimension.2.Units:
# .ImageList.2.ImageData.Calibrations.DisplayCalibratedUnits: 1
# .ImageList.2.ImageData.Data.arraySize: 105040
# .ImageList.2.ImageData.Data.arrayOffset: 65016
# .ImageList.2.ImageData.Data.arrayType: 7
# .ImageList.2.ImageData.Data: Data unread. Encoded type = 7
# .ImageList.2.ImageData.DataType: 12
# .ImageList.2.ImageData.Dimensions.1: 10
# .ImageList.2.ImageData.Dimensions.2: 1313
# .ImageList.2.ImageData.PixelDepth: 8
# .ImageList.2.ImageTags.GMS Version.Created: 3.60.4441.0
# .ImageList.2.ImageTags.GMS Version.Saved: 3.60.4441.0
# .ImageList.2.ImageTags.Meta Data.Format: Image
# .ImageList.2.ImageTags.Processing.1.Operation: Background Removal
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Parameters.Model equation: y = a0*x^(-a1)
# .ImageList.2.ImageTags.Processing.1.Parameters.Fitting Region(s).1.end channel: 179
# .ImageList.2.ImageTags.Processing.1.Parameters.Fitting Region(s).1.start channel: 124
# .ImageList.2.ImageTags.Processing.1.Parameters.Model: Power Law
# .ImageList.2.ImageTags.Processing.1.Parent.Name: 200radial_1
# .ImageList.2.ImageTags.Processing.1.Parent.Unique Image ID: [1.78474670e+08 7.76218840e+07 1.90004854e+09 1.39185412e+09]
# .ImageList.2.ImageTags.Processing.1.Time: 2024-07-11, 오후 3:38:15
# .ImageList.2.ImageTags.Processing.2.Operation: LS Fitting
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Fit range.From: 186.0
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Fit range.To: 226.0
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Is background: 0
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Name: Lorentzian 1
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.1.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.1.Name: Amplitude
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.1.Value: 530799.6580583813
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.2.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.2.Name: Position
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.2.Value: 201.80981907926034
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.3.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.3.Force positive value: 1
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.3.Name: FWHM
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.3.Value: 1.6401576608168473
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Type: Lorentzian
# .ImageList.2.ImageTags.Processing.2.Parameters.Fitter.Name: MinPack
# .ImageList.2.ImageTags.Processing.2.Parameters.Last fit's red.chi.sqr.: 210104224.03501126
# .ImageList.2.ImageTags.Processing.2.Parameters.Mode: NLLS
# .ImageList.2.ImageTags.Processing.2.Parameters.Value: FWHM (Lorentzian 1)
# .ImageList.2.ImageTags.Processing.2.Parent.Name: Signal SI
# .ImageList.2.ImageTags.Processing.2.Parent.Unique Image ID: [4.76272922e+08 1.93681541e+08 2.28883774e+08 1.21985012e+09]
# .ImageList.2.ImageTags.Processing.2.Time: 2024-07-11, 오후 3:38:33
# .ImageList.2.Name: FWHM (Lorentzian 1)
# .ImageList.2.UniqueID.1: 1504148948
# .ImageList.2.UniqueID.2: 431318012
# .ImageList.2.UniqueID.3: 720990841
# .ImageList.2.UniqueID.4: 469118807
# .ImageSourceList.1.ClassName: ImageSource:Simple
# .ImageSourceList.1.Id.1: 0
# .ImageSourceList.1.ImageRef: 1
# .InImageMode: 1
# .LayoutType: Unknown
# .MinVersionList.1.RequiredVersion: 50659328
# .NextDocumentObjectID: 11
# .Page Behavior.DrawMargins: 1
# .Page Behavior.DrawPaper: 1
# .Page Behavior.IsFixedInPageMode: 0
# .Page Behavior.IsZoomedToWindow: 1
# .Page Behavior.LayedOut: 0
# .Page Behavior.PageTransform.Offset: [0. 0.]
# .Page Behavior.PageTransform.Scale: [1. 1.]
# .Page Behavior.RestoreImageDisplayBounds: [   0.    0. 1313.   10.]
# .Page Behavior.RestoreImageDisplayID: 8
# .Page Behavior.TargetDisplayID: 4294967295
# .PageSetup.General: [ 1.00000000e+00  2.68435556e+08  2.10000000e+04  2.97000000e+04
#   2.50000000e+03  2.50000000e+03 -2.50000000e+03 -2.50000000e+03]
# .PageSetup.Win32:RtÄ	Ä	Ä	Ä
# .PageSetup.Win32_DevModeW.arraySize: 2712
# .PageSetup.Win32_DevModeW.arrayOffset: 175101
# .PageSetup.Win32_DevModeW.arrayType: 10
# .PageSetup.Win32_DevModeW: Array unread. Encoded type = 10
# .PageSetup.Win32_DevNamesW: Hancom PDFHancom PDFHancom PDF Port
# .Thumbnails.1.ImageIndex: 0
# .Thumbnails.1.SourceSize_Pixels: [ 82. 863.]
# .WindowPosition: [ 31.  33. 894.  42.]
# Saved C:\Users\doyeob\Desktop\3layerBP data\fitting using gatan\200\radial\1\FWHM (Lorentzian 1).tif
# Processing Position (Lorentzian 1).dm4...
# .ApplicationBounds: [   0.    0.  907. 1982.]
# .BackgroundColor: [-2571. -2571. -1286.]
# .DocumentObjectList.1.AnnotationGroupList.1.AnnotationType: 13
# .DocumentObjectList.1.AnnotationGroupList.1.BackgroundColor: [-1. -1. -1.]
# .DocumentObjectList.1.AnnotationGroupList.1.BackgroundMode: 2
# .DocumentObjectList.1.AnnotationGroupList.1.FillMode: 2
# .DocumentObjectList.1.AnnotationGroupList.1.FixedPoint: [0. 0.]
# .DocumentObjectList.1.AnnotationGroupList.1.ForegroundColor: [-1. -1.  0.]
# .DocumentObjectList.1.AnnotationGroupList.1.HasBackground: 0
# .DocumentObjectList.1.AnnotationGroupList.1.IsMoveable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsResizable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsSelectable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsTransferrable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsTranslatable: 1
# .DocumentObjectList.1.AnnotationGroupList.1.IsVisible: 1
# .DocumentObjectList.1.AnnotationGroupList.1.ObjectTags.LSFITMapLabel: 1
# .DocumentObjectList.1.AnnotationGroupList.1.Rectangle: [ 32.82500076   0.          54.12511444 149.10081482]
# .DocumentObjectList.1.AnnotationGroupList.1.ResizeStyle: 48
# .DocumentObjectList.1.AnnotationGroupList.1.RestrictionStyle: 0
# .DocumentObjectList.1.AnnotationGroupList.1.Text: Position (Lorentzian 1)
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.DrawingMode: 2
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.FontAttributes: 7
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.FontFaceName: 굴림체
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.FontSize: 12.171494483947754
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.Justification: 3
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.ScreenSize: [98. 14.]
# .DocumentObjectList.1.AnnotationGroupList.1.TextFormat.TextLength: 23
# .DocumentObjectList.1.AnnotationGroupList.1.Transparency: 0.0
# .DocumentObjectList.1.AnnotationGroupList.1.UniqueID: 10
# .DocumentObjectList.1.AnnotationType: 20
# .DocumentObjectList.1.BackgroundColor: [-1. -1. -1.]
# .DocumentObjectList.1.BackgroundMode: 2
# .DocumentObjectList.1.FillMode: 1
# .DocumentObjectList.1.ForegroundColor: [0. 0. 0.]
# .DocumentObjectList.1.HasBackground: 0
# .DocumentObjectList.1.ImageDisplayInfo.BrightColor: [-1. -1. -1.]
# .DocumentObjectList.1.ImageDisplayInfo.Brightness: 0.5
# .DocumentObjectList.1.ImageDisplayInfo.CaptionOn: 0
# .DocumentObjectList.1.ImageDisplayInfo.CaptionSize: 10
# .DocumentObjectList.1.ImageDisplayInfo.CLUT.arraySize: 1536
# .DocumentObjectList.1.ImageDisplayInfo.CLUT.arrayOffset: 2933
# .DocumentObjectList.1.ImageDisplayInfo.CLUT.arrayType: 2.0
# .DocumentObjectList.1.ImageDisplayInfo.CLUT: Array unread. Encoded type = 2.0
# .DocumentObjectList.1.ImageDisplayInfo.CLUTName: Greyscale
# .DocumentObjectList.1.ImageDisplayInfo.ComplexMode: 4
# .DocumentObjectList.1.ImageDisplayInfo.ComplexRange: 1000.0
# .DocumentObjectList.1.ImageDisplayInfo.Contrast: 0.5
# .DocumentObjectList.1.ImageDisplayInfo.ContrastMode: 1
# .DocumentObjectList.1.ImageDisplayInfo.DiffractionMode: 0
# .DocumentObjectList.1.ImageDisplayInfo.DoAutoSurvey: 1
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMax: 201.60243225097656
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMaxTrimPercentage: 0.0010000000474974513
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMin: 205.33688354492188
# .DocumentObjectList.1.ImageDisplayInfo.EstimatedMinTrimPercentage: 0.0010000000474974513
# .DocumentObjectList.1.ImageDisplayInfo.Gamma: 0.5
# .DocumentObjectList.1.ImageDisplayInfo.HighLimit: 205.33688354492188
# .DocumentObjectList.1.ImageDisplayInfo.HiLimitContrastDeltaTriggerPercentage: 0.10000000149011612
# .DocumentObjectList.1.ImageDisplayInfo.IsIgnoreGirdBar: 0
# .DocumentObjectList.1.ImageDisplayInfo.IsInverted: 0
# .DocumentObjectList.1.ImageDisplayInfo.LowLimit: 201.60243225097656
# .DocumentObjectList.1.ImageDisplayInfo.LowLimitContrastDeltaTriggerPercentage: 0.10000000149011612
# .DocumentObjectList.1.ImageDisplayInfo.MainSliceId.1: 0
# .DocumentObjectList.1.ImageDisplayInfo.MinimumContrast: 0.0
# .DocumentObjectList.1.ImageDisplayInfo.RangeAdjust: 1.0
# .DocumentObjectList.1.ImageDisplayInfo.SparseSurvey_GridSize: 32
# .DocumentObjectList.1.ImageDisplayInfo.SparseSurvey_NumberPixels: 64
# .DocumentObjectList.1.ImageDisplayInfo.SparseSurvey_UseNumberPixels: 1
# .DocumentObjectList.1.ImageDisplayInfo.SurveyTechique: 2
# .DocumentObjectList.1.ImageDisplayType: 1
# .DocumentObjectList.1.ImageSource: 0
# .DocumentObjectList.1.IsMoveable: 1
# .DocumentObjectList.1.IsResizable: 1
# .DocumentObjectList.1.IsSelectable: 1
# .DocumentObjectList.1.IsTransferrable: 1
# .DocumentObjectList.1.IsTranslatable: 1
# .DocumentObjectList.1.IsVisible: 1
# .DocumentObjectList.1.Rectangle: [  0.           0.         863.           6.57273388]
# .DocumentObjectList.1.RestrictionStyle: 0
# .DocumentObjectList.1.Transparency: 0.0
# .DocumentObjectList.1.UniqueID: 8
# .HasWindowPosition: 1
# .Image Behavior.ImageDisplayBounds: [  0.           0.         863.           6.57273388]
# .Image Behavior.IsZoomedToWindow: 1
# .Image Behavior.UnscaledTransform.Offset: [0. 0.]
# .Image Behavior.UnscaledTransform.Scale: [1. 1.]
# .Image Behavior.ViewDisplayID: 8
# .Image Behavior.WindowRect: [  0.   0. 863.   9.]
# .Image Behavior.ZoomAndMoveTransform.Offset: [1.21363306 0.        ]
# .Image Behavior.ZoomAndMoveTransform.Scale: [1. 1.]
# .ImageList.1.ImageData.Calibrations.Brightness.Label:
# .ImageList.1.ImageData.Calibrations.Brightness.Origin: 0.0
# .ImageList.1.ImageData.Calibrations.Brightness.Scale: 1.0
# .ImageList.1.ImageData.Calibrations.Brightness.Units:
# .ImageList.1.ImageData.Calibrations.Dimension.1.Label:
# .ImageList.1.ImageData.Calibrations.Dimension.1.Origin: 0.0
# .ImageList.1.ImageData.Calibrations.Dimension.1.Scale: 1.0
# .ImageList.1.ImageData.Calibrations.Dimension.1.Units:
# .ImageList.1.ImageData.Calibrations.Dimension.2.Label:
# .ImageList.1.ImageData.Calibrations.Dimension.2.Origin: 0.0
# .ImageList.1.ImageData.Calibrations.Dimension.2.Scale: 1.0
# .ImageList.1.ImageData.Calibrations.Dimension.2.Units:
# .ImageList.1.ImageData.Calibrations.DisplayCalibratedUnits: 1
# .ImageList.1.ImageData.Data.arraySize: 67584
# .ImageList.1.ImageData.Data.arrayOffset: 8278
# .ImageList.1.ImageData.Data.arrayType: 3
# .ImageList.1.ImageData.Data: Data unread. Encoded type = 3
# .ImageList.1.ImageData.DataType: 23
# .ImageList.1.ImageData.Dimensions.1: 44
# .ImageList.1.ImageData.Dimensions.2: 384
# .ImageList.1.ImageData.PixelDepth: 4
# .ImageList.1.ImageTags.GMS Version.Created: 3.60.4441.0
# .ImageList.1.Name: Image Of Position (Lorentzian 1)
# .ImageList.1.UniqueID.1: 1150626405
# .ImageList.1.UniqueID.2: 1811694015
# .ImageList.1.UniqueID.3: 2014659607
# .ImageList.1.UniqueID.4: 1549870983
# .ImageList.2.ImageData.Calibrations.Brightness.Label:
# .ImageList.2.ImageData.Calibrations.Brightness.Origin: 0.0
# .ImageList.2.ImageData.Calibrations.Brightness.Scale: 1.0
# .ImageList.2.ImageData.Calibrations.Brightness.Units:
# .ImageList.2.ImageData.Calibrations.Dimension.1.Label:
# .ImageList.2.ImageData.Calibrations.Dimension.1.Origin: 0.0
# .ImageList.2.ImageData.Calibrations.Dimension.1.Scale: 1.0
# .ImageList.2.ImageData.Calibrations.Dimension.1.Units:
# .ImageList.2.ImageData.Calibrations.Dimension.2.Label:
# .ImageList.2.ImageData.Calibrations.Dimension.2.Origin: 0.0
# .ImageList.2.ImageData.Calibrations.Dimension.2.Scale: 1.0
# .ImageList.2.ImageData.Calibrations.Dimension.2.Units:
# .ImageList.2.ImageData.Calibrations.DisplayCalibratedUnits: 1
# .ImageList.2.ImageData.Data.arraySize: 105040
# .ImageList.2.ImageData.Data.arrayOffset: 77320
# .ImageList.2.ImageData.Data.arrayType: 7
# .ImageList.2.ImageData.Data: Data unread. Encoded type = 7
# .ImageList.2.ImageData.DataType: 12
# .ImageList.2.ImageData.Dimensions.1: 10
# .ImageList.2.ImageData.Dimensions.2: 1313
# .ImageList.2.ImageData.PixelDepth: 8
# .ImageList.2.ImageTags.GMS Version.Created: 3.60.4441.0
# .ImageList.2.ImageTags.GMS Version.Saved: 3.60.4441.0
# .ImageList.2.ImageTags.Meta Data.Format: Image
# .ImageList.2.ImageTags.Processing.1.Operation: Background Removal
# .ImageList.2.ImageTags.Processing.1.Parameters.Fit Parameters.Model equation: y = a0*x^(-a1)
# .ImageList.2.ImageTags.Processing.1.Parameters.Fitting Region(s).1.end channel: 179
# .ImageList.2.ImageTags.Processing.1.Parameters.Fitting Region(s).1.start channel: 124
# .ImageList.2.ImageTags.Processing.1.Parameters.Model: Power Law
# .ImageList.2.ImageTags.Processing.1.Parent.Name: 200radial_1
# .ImageList.2.ImageTags.Processing.1.Parent.Unique Image ID: [1.78474670e+08 7.76218840e+07 1.90004854e+09 1.39185412e+09]
# .ImageList.2.ImageTags.Processing.1.Time: 2024-07-11, 오후 3:38:15
# .ImageList.2.ImageTags.Processing.2.Operation: LS Fitting
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Fit range.From: 186.0
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Fit range.To: 226.0
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Is background: 0
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Name: Lorentzian 1
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.1.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.1.Name: Amplitude
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.1.Value: 530799.6580583813
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.2.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.2.Name: Position
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.2.Value: 201.80981907926034
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.3.Fit parameter: 1
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.3.Force positive value: 1
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.3.Name: FWHM
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Parameters.3.Value: 1.6401576608168473
# .ImageList.2.ImageTags.Processing.2.Parameters.Fit Items.1.Type: Lorentzian
# .ImageList.2.ImageTags.Processing.2.Parameters.Fitter.Name: MinPack
# .ImageList.2.ImageTags.Processing.2.Parameters.Last fit's red.chi.sqr.: 210104224.03501126
# .ImageList.2.ImageTags.Processing.2.Parameters.Mode: NLLS
# .ImageList.2.ImageTags.Processing.2.Parameters.Value: Position (Lorentzian 1)
# .ImageList.2.ImageTags.Processing.2.Parent.Name: Signal SI
# .ImageList.2.ImageTags.Processing.2.Parent.Unique Image ID: [4.76272922e+08 1.93681541e+08 2.28883774e+08 1.21985012e+09]
# .ImageList.2.ImageTags.Processing.2.Time: 2024-07-11, 오후 3:38:33
# .ImageList.2.Name: Position (Lorentzian 1)
# .ImageList.2.UniqueID.1: 57812142
# .ImageList.2.UniqueID.2: 2027824348
# .ImageList.2.UniqueID.3: 1895192118
# .ImageList.2.UniqueID.4: 375201447
# .ImageSourceList.1.ClassName: ImageSource:Simple
# .ImageSourceList.1.Id.1: 0
# .ImageSourceList.1.ImageRef: 1
# .InImageMode: 1
# .LayoutType: Unknown
# .MinVersionList.1.RequiredVersion: 50659328
# .NextDocumentObjectID: 11
# .Page Behavior.DrawMargins: 1
# .Page Behavior.DrawPaper: 1
# .Page Behavior.IsFixedInPageMode: 0
# .Page Behavior.IsZoomedToWindow: 1
# .Page Behavior.LayedOut: 0
# .Page Behavior.PageTransform.Offset: [0. 0.]
# .Page Behavior.PageTransform.Scale: [1. 1.]
# .Page Behavior.RestoreImageDisplayBounds: [   0.    0. 1313.   10.]
# .Page Behavior.RestoreImageDisplayID: 8
# .Page Behavior.TargetDisplayID: 4294967295
# .PageSetup.General: [ 1.00000000e+00  2.68435556e+08  2.10000000e+04  2.97000000e+04
#   2.50000000e+03  2.50000000e+03 -2.50000000e+03 -2.50000000e+03]
# .PageSetup.Win32:RtÄ	Ä	Ä	Ä
# .PageSetup.Win32_DevModeW.arraySize: 2712
# .PageSetup.Win32_DevModeW.arrayOffset: 187421
# .PageSetup.Win32_DevModeW.arrayType: 10
# .PageSetup.Win32_DevModeW: Array unread. Encoded type = 10
# .PageSetup.Win32_DevNamesW: Hancom PDFHancom PDFHancom PDF Port
# .Thumbnails.1.ImageIndex: 0
# .Thumbnails.1.SourceSize_Pixels: [ 98. 863.]
# .WindowPosition: [ 31.  58. 894.  67.]
# Saved C:\Users\doyeob\Desktop\3layerBP data\fitting using gatan\200\radial\1\Position (Lorentzian 1).tif
# 모든 DM4 파일이 TIFF 파일로 성공적으로 변환되었습니다.

# %%
import os
import shutil
import numpy as np
import tifffile as tiff

def process_tif_files(src_folder, dst_folder):
    if not os.path.exists(dst_folder):
        os.makedirs(dst_folder)

    # Check if the path contains 'radial' or 'angular'
    if 'radial' in src_folder.lower():
        factor = 2.96 / 160
    elif 'angular' in src_folder.lower():
        factor = 360 / 1024
    else:
        factor = None

    for filename in os.listdir(src_folder):
        if filename.endswith(".tif") or filename.endswith(".tiff"):
            src_path = os.path.join(src_folder, filename)
            dst_path = os.path.join(dst_folder, filename)
            
            if factor is not None and ('position' in filename.lower() or 'fwhm' in filename.lower()):
                # Read the TIFF file
                image = tiff.imread(src_path)
                
                # Process the image
                processed_image = image * factor
                
                # Save the processed image
                tiff.imwrite(dst_path, processed_image.astype(image.dtype))
            else:
                # Copy the original file
                shutil.copy2(src_path, dst_path)

# Example usage
src_folder = r"C:\Users\doyeob\Desktop\3layerBP data\fitting using gatan\200\angular\1"
dst_folder = r"C:\Users\doyeob\Desktop\3layerBP data\fitting using gatan\200\angular\1\adjusted"
process_tif_files(src_folder, dst_folder)

# %%
import imageio.v2 as imageio
import numpy as np
import pandas as pd
import glob
import os

# TIFF 파일이 저장된 폴더 경로
folder_path = r"D:\Users\doyeob\Desktop\3layerBP data\fitting using gatan\200\radial\1\adjusted"

# 폴더 내 모든 TIFF 파일 경로 가져오기
tif_files = glob.glob(os.path.join(folder_path, '*.tif'))

# 빈 DataFrame 생성
all_data = pd.DataFrame()

# 모든 TIFF 파일에 대해 작업 수행
for file in tif_files:
    # TIFF 파일 열기
    image = imageio.imread(file)
    
    # 첫 번째 열의 intensity 값 추출
    first_column_intensity = image[:, 0]
    
    # 파일 이름에서 기본 이름 추출
    base_name = os.path.basename(file).split('.')[0]
    
    # pandas DataFrame으로 변환
    df = pd.DataFrame(first_column_intensity, columns=[base_name])
    
    # 데이터를 병합
    if all_data.empty:
        all_data = df
    else:
        all_data = pd.concat([all_data, df], axis=1)

# Excel 파일로 저장
excel_file = r"D:\Users\doyeob\Desktop\3layerBP data\fitting using gatan\200\radial\1\ring information.xlsx"
all_data.to_excel(excel_file, index=False)

# 확인 메세지 출력
print(f'First column intensity data from all TIFF files saved to {excel_file}')

# %%
import imageio.v2 as imageio
import numpy as np
import pandas as pd
import glob
import os

# TIFF 파일이 저장된 폴더 경로
folder_path = r"C:\Users\doyeob\Desktop\3layerBP data\fitting using gatan\200\radial\1\adjusted"

# 폴더 내 모든 TIFF 파일 경로 가져오기
tif_files = glob.glob(os.path.join(folder_path, '*.tif'))

# 빈 DataFrame 생성
all_data = pd.DataFrame()

# 모든 TIFF 파일에 대해 작업 수행
for file in tif_files:
    # TIFF 파일 열기
    image = imageio.imread(file)
    
    # 첫 번째 열의 intensity 값 추출
    first_column_intensity = image[:, 0]
    
    # 파일 이름에서 기본 이름 추출
    base_name = os.path.basename(file).split('.')[0]
    
    # pandas DataFrame으로 변환
    df = pd.DataFrame(first_column_intensity, columns=[base_name])
    
    # 데이터를 병합
    if all_data.empty:
        all_data = df
    else:
        all_data = pd.concat([all_data, df], axis=1)

# 엑셀 파일 저장 경로 설정
parent_folder = os.path.dirname(folder_path)  # 상위 폴더 경로
folder_parts = parent_folder.split(os.sep)  # 폴더 경로를 분할하여 리스트로 저장
excel_filename = '_'.join(folder_parts[-3:]) + '.xlsx'  # 파일 이름 생성
excel_file = os.path.join(parent_folder, excel_filename)  # 전체 파일 경로

# Excel 파일로 저장
all_data.to_excel(excel_file, index=False)

# 확인 메세지 출력
print(f'First column intensity data from all TIFF files saved to {excel_file}')
# Out:
# First column intensity data from all TIFF files saved to C:\Users\doyeob\Desktop\3layerBP data\fitting using gatan\200\radial\1\200_radial_1.xlsx

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 엑셀 파일 경로
excel_file = r"C:\Users\doyeob\Desktop\3layerBP data\fitting using gatan\200\radial\1\200_radial_1.xlsx"

# 엑셀 파일 읽기
data = pd.read_excel(excel_file)

# 필요한 컬럼 추출
amplitude = data['Amplitude (Lorentzian 1)']
FWHM = data['FWHM (Lorentzian 1)']
position = data['Position (Lorentzian 1)']

# 그래프 플롯
plt.figure(figsize=(10, 6))

plt.subplot(3, 1, 1)
plt.plot(amplitude, 'r', label='Amplitude')
plt.title('Amplitude')
plt.legend()

plt.subplot(3, 1, 2)
plt.plot(FWHM, 'g', label='FWHM')
plt.title('FWHM')
plt.legend()

plt.subplot(3, 1, 3)
plt.plot(position, 'b', label='Position')
plt.title('Position')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import pandas as pd

# 엑셀 파일 경로
excel_file = r"C:\Users\doyeob\Desktop\3layerBP data\fitting using gatan\200\radial\1\200_radial_1.xlsx"

# 엑셀 파일 읽기
data = pd.read_excel(excel_file)

# 컬럼 이름 출력
print(data.columns)
# Out:
# Index(['Amplitude (Lorentzian 1)', 'FWHM (Lorentzian 1)',
#        'Position (Lorentzian 1)'],
#       dtype='object')
