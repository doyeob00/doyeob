# %%
import os
import numpy as np
import tifffile as tiff

def process_tif_files(input_folder, output_folder, mask_file):
    # 마스크 파일 읽기
    mask = tiff.imread(mask_file)
    
    # 입력 폴더 내의 모든 .tif 파일에 대해 반복
    for filename in os.listdir(input_folder):
        if filename.endswith('.tif'):
            # 파일 경로 생성
            file_path = os.path.join(input_folder, filename)
            
            # .tif 파일 읽기
            image = tiff.imread(file_path)
            
            # FFT 수행
            fft_image = np.fft.fft2(image)
            
            # FFT 시프트 (저주파 성분을 중앙으로 이동)
            fft_shift = np.fft.fftshift(fft_image)
            
            # FFT 절대값 및 로그 스케일 적용
            magnitude_spectrum = np.abs(fft_shift)
            
            # FFT 결과와 마스크 곱하기
            masked_spectrum = magnitude_spectrum * mask
            
            # 결과를 .tif 파일로 저장
            output_filename = os.path.splitext(filename)[0] + '_fft_masked.tif'
            output_path = os.path.join(output_folder, output_filename)
            tiff.imwrite(output_path, masked_spectrum.astype(np.float32))
            
            print(f'Processed {filename}, saved FFT and masked result to {output_filename}')

# 입력 폴더와 출력 폴더 경로 설정
input_folder = r'D:\Users\doyeob\Desktop\3layerBP data\devided data\original data'
output_folder = r"D:\Users\doyeob\Desktop\3layerBP data\devided data\FFT with new mask"

# 마스크 파일 경로 설정
mask_file = r"D:\Users\doyeob\Desktop\3layerBP data\devided data\mask\G,BP mask.tif"

# 출력 폴더가 존재하지 않으면 생성
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# .tif 파일 처리
process_tif_files(input_folder, output_folder, mask_file)
# Out:
# Processed 91 file_1.tif, saved FFT and masked result to 91 file_1_fft_masked.tif
# Processed 91 file_10.tif, saved FFT and masked result to 91 file_10_fft_masked.tif
# Processed 91 file_100.tif, saved FFT and masked result to 91 file_100_fft_masked.tif
# Processed 91 file_1000.tif, saved FFT and masked result to 91 file_1000_fft_masked.tif
# Processed 91 file_1001.tif, saved FFT and masked result to 91 file_1001_fft_masked.tif
# Processed 91 file_1002.tif, saved FFT and masked result to 91 file_1002_fft_masked.tif
# Processed 91 file_1003.tif, saved FFT and masked result to 91 file_1003_fft_masked.tif
# Processed 91 file_1004.tif, saved FFT and masked result to 91 file_1004_fft_masked.tif
# Processed 91 file_1005.tif, saved FFT and masked result to 91 file_1005_fft_masked.tif
# Processed 91 file_1006.tif, saved FFT and masked result to 91 file_1006_fft_masked.tif
# Processed 91 file_1007.tif, saved FFT and masked result to 91 file_1007_fft_masked.tif
# Processed 91 file_1008.tif, saved FFT and masked result to 91 file_1008_fft_masked.tif
# Processed 91 file_1009.tif, saved FFT and masked result to 91 file_1009_fft_masked.tif
# Processed 91 file_101.tif, saved FFT and masked result to 91 file_101_fft_masked.tif
# Processed 91 file_1010.tif, saved FFT and masked result to 91 file_1010_fft_masked.tif
# Processed 91 file_1011.tif, saved FFT and masked result to 91 file_1011_fft_masked.tif
# Processed 91 file_1012.tif, saved FFT and masked result to 91 file_1012_fft_masked.tif
# Processed 91 file_1013.tif, saved FFT and masked result to 91 file_1013_fft_masked.tif
# Processed 91 file_1014.tif, saved FFT and masked result to 91 file_1014_fft_masked.tif
# Processed 91 file_1015.tif, saved FFT and masked result to 91 file_1015_fft_masked.tif
# Processed 91 file_1016.tif, saved FFT and masked result to 91 file_1016_fft_masked.tif
# Processed 91 file_1017.tif, saved FFT and masked result to 91 file_1017_fft_masked.tif
# Processed 91 file_1018.tif, saved FFT and masked result to 91 file_1018_fft_masked.tif
# Processed 91 file_1019.tif, saved FFT and masked result to 91 file_1019_fft_masked.tif
# Processed 91 file_102.tif, saved FFT and masked result to 91 file_102_fft_masked.tif
# Processed 91 file_1020.tif, saved FFT and masked result to 91 file_1020_fft_masked.tif
# Processed 91 file_1021.tif, saved FFT and masked result to 91 file_1021_fft_masked.tif
# Processed 91 file_1022.tif, saved FFT and masked result to 91 file_1022_fft_masked.tif
# Processed 91 file_1023.tif, saved FFT and masked result to 91 file_1023_fft_masked.tif
# Processed 91 file_1024.tif, saved FFT and masked result to 91 file_1024_fft_masked.tif
# Processed 91 file_1025.tif, saved FFT and masked result to 91 file_1025_fft_masked.tif
# Processed 91 file_1026.tif, saved FFT and masked result to 91 file_1026_fft_masked.tif
# Processed 91 file_1027.tif, saved FFT and masked result to 91 file_1027_fft_masked.tif
# Processed 91 file_1028.tif, saved FFT and masked result to 91 file_1028_fft_masked.tif
# Processed 91 file_1029.tif, saved FFT and masked result to 91 file_1029_fft_masked.tif
# Processed 91 file_103.tif, saved FFT and masked result to 91 file_103_fft_masked.tif
# Processed 91 file_1030.tif, saved FFT and masked result to 91 file_1030_fft_masked.tif
# Processed 91 file_1031.tif, saved FFT and masked result to 91 file_1031_fft_masked.tif
# Processed 91 file_1032.tif, saved FFT and masked result to 91 file_1032_fft_masked.tif
# Processed 91 file_1033.tif, saved FFT and masked result to 91 file_1033_fft_masked.tif
# Processed 91 file_1034.tif, saved FFT and masked result to 91 file_1034_fft_masked.tif
# Processed 91 file_1035.tif, saved FFT and masked result to 91 file_1035_fft_masked.tif
# Processed 91 file_1036.tif, saved FFT and masked result to 91 file_1036_fft_masked.tif
# Processed 91 file_1037.tif, saved FFT and masked result to 91 file_1037_fft_masked.tif
# Processed 91 file_1038.tif, saved FFT and masked result to 91 file_1038_fft_masked.tif
# Processed 91 file_1039.tif, saved FFT and masked result to 91 file_1039_fft_masked.tif
# Processed 91 file_104.tif, saved FFT and masked result to 91 file_104_fft_masked.tif
# Processed 91 file_1040.tif, saved FFT and masked result to 91 file_1040_fft_masked.tif
# Processed 91 file_1041.tif, saved FFT and masked result to 91 file_1041_fft_masked.tif
# Processed 91 file_1042.tif, saved FFT and masked result to 91 file_1042_fft_masked.tif
# Processed 91 file_1043.tif, saved FFT and masked result to 91 file_1043_fft_masked.tif
# Processed 91 file_1044.tif, saved FFT and masked result to 91 file_1044_fft_masked.tif
# Processed 91 file_1045.tif, saved FFT and masked result to 91 file_1045_fft_masked.tif
# Processed 91 file_1046.tif, saved FFT and masked result to 91 file_1046_fft_masked.tif
# Processed 91 file_1047.tif, saved FFT and masked result to 91 file_1047_fft_masked.tif
# Processed 91 file_1048.tif, saved FFT and masked result to 91 file_1048_fft_masked.tif
# Processed 91 file_1049.tif, saved FFT and masked result to 91 file_1049_fft_masked.tif
# Processed 91 file_105.tif, saved FFT and masked result to 91 file_105_fft_masked.tif
# Processed 91 file_1050.tif, saved FFT and masked result to 91 file_1050_fft_masked.tif
# Processed 91 file_1051.tif, saved FFT and masked result to 91 file_1051_fft_masked.tif
# Processed 91 file_1052.tif, saved FFT and masked result to 91 file_1052_fft_masked.tif
# Processed 91 file_1053.tif, saved FFT and masked result to 91 file_1053_fft_masked.tif
# Processed 91 file_1054.tif, saved FFT and masked result to 91 file_1054_fft_masked.tif
# Processed 91 file_1055.tif, saved FFT and masked result to 91 file_1055_fft_masked.tif
# Processed 91 file_1056.tif, saved FFT and masked result to 91 file_1056_fft_masked.tif
# Processed 91 file_1057.tif, saved FFT and masked result to 91 file_1057_fft_masked.tif
# Processed 91 file_1058.tif, saved FFT and masked result to 91 file_1058_fft_masked.tif
# Processed 91 file_1059.tif, saved FFT and masked result to 91 file_1059_fft_masked.tif
# Processed 91 file_106.tif, saved FFT and masked result to 91 file_106_fft_masked.tif
# Processed 91 file_1060.tif, saved FFT and masked result to 91 file_1060_fft_masked.tif
# Processed 91 file_1061.tif, saved FFT and masked result to 91 file_1061_fft_masked.tif
# Processed 91 file_1062.tif, saved FFT and masked result to 91 file_1062_fft_masked.tif
# Processed 91 file_1063.tif, saved FFT and masked result to 91 file_1063_fft_masked.tif
# Processed 91 file_1064.tif, saved FFT and masked result to 91 file_1064_fft_masked.tif
# Processed 91 file_1065.tif, saved FFT and masked result to 91 file_1065_fft_masked.tif
# Processed 91 file_1066.tif, saved FFT and masked result to 91 file_1066_fft_masked.tif
# Processed 91 file_1067.tif, saved FFT and masked result to 91 file_1067_fft_masked.tif
# Processed 91 file_1068.tif, saved FFT and masked result to 91 file_1068_fft_masked.tif
# Processed 91 file_1069.tif, saved FFT and masked result to 91 file_1069_fft_masked.tif
# Processed 91 file_107.tif, saved FFT and masked result to 91 file_107_fft_masked.tif
# Processed 91 file_1070.tif, saved FFT and masked result to 91 file_1070_fft_masked.tif
# Processed 91 file_1071.tif, saved FFT and masked result to 91 file_1071_fft_masked.tif
# Processed 91 file_1072.tif, saved FFT and masked result to 91 file_1072_fft_masked.tif
# Processed 91 file_1073.tif, saved FFT and masked result to 91 file_1073_fft_masked.tif
# Processed 91 file_1074.tif, saved FFT and masked result to 91 file_1074_fft_masked.tif
# Processed 91 file_1075.tif, saved FFT and masked result to 91 file_1075_fft_masked.tif
# Processed 91 file_1076.tif, saved FFT and masked result to 91 file_1076_fft_masked.tif
# Processed 91 file_1077.tif, saved FFT and masked result to 91 file_1077_fft_masked.tif
# Processed 91 file_1078.tif, saved FFT and masked result to 91 file_1078_fft_masked.tif
# Processed 91 file_1079.tif, saved FFT and masked result to 91 file_1079_fft_masked.tif
# Processed 91 file_108.tif, saved FFT and masked result to 91 file_108_fft_masked.tif
# Processed 91 file_1080.tif, saved FFT and masked result to 91 file_1080_fft_masked.tif
# Processed 91 file_1081.tif, saved FFT and masked result to 91 file_1081_fft_masked.tif
# Processed 91 file_1082.tif, saved FFT and masked result to 91 file_1082_fft_masked.tif
# Processed 91 file_1083.tif, saved FFT and masked result to 91 file_1083_fft_masked.tif
# Processed 91 file_1084.tif, saved FFT and masked result to 91 file_1084_fft_masked.tif
# Processed 91 file_1085.tif, saved FFT and masked result to 91 file_1085_fft_masked.tif
# Processed 91 file_1086.tif, saved FFT and masked result to 91 file_1086_fft_masked.tif
# Processed 91 file_1087.tif, saved FFT and masked result to 91 file_1087_fft_masked.tif
# Processed 91 file_1088.tif, saved FFT and masked result to 91 file_1088_fft_masked.tif
# Processed 91 file_1089.tif, saved FFT and masked result to 91 file_1089_fft_masked.tif
# Processed 91 file_109.tif, saved FFT and masked result to 91 file_109_fft_masked.tif
# Processed 91 file_1090.tif, saved FFT and masked result to 91 file_1090_fft_masked.tif
# Processed 91 file_1091.tif, saved FFT and masked result to 91 file_1091_fft_masked.tif
# Processed 91 file_1092.tif, saved FFT and masked result to 91 file_1092_fft_masked.tif
# Processed 91 file_1093.tif, saved FFT and masked result to 91 file_1093_fft_masked.tif
# Processed 91 file_1094.tif, saved FFT and masked result to 91 file_1094_fft_masked.tif
# Processed 91 file_1095.tif, saved FFT and masked result to 91 file_1095_fft_masked.tif
# Processed 91 file_1096.tif, saved FFT and masked result to 91 file_1096_fft_masked.tif
# Processed 91 file_1097.tif, saved FFT and masked result to 91 file_1097_fft_masked.tif
# Processed 91 file_1098.tif, saved FFT and masked result to 91 file_1098_fft_masked.tif
# Processed 91 file_1099.tif, saved FFT and masked result to 91 file_1099_fft_masked.tif
# Processed 91 file_11.tif, saved FFT and masked result to 91 file_11_fft_masked.tif
# Processed 91 file_110.tif, saved FFT and masked result to 91 file_110_fft_masked.tif
# Processed 91 file_1100.tif, saved FFT and masked result to 91 file_1100_fft_masked.tif
# Processed 91 file_1101.tif, saved FFT and masked result to 91 file_1101_fft_masked.tif
# Processed 91 file_1102.tif, saved FFT and masked result to 91 file_1102_fft_masked.tif
# Processed 91 file_1103.tif, saved FFT and masked result to 91 file_1103_fft_masked.tif
# Processed 91 file_1104.tif, saved FFT and masked result to 91 file_1104_fft_masked.tif
# Processed 91 file_1105.tif, saved FFT and masked result to 91 file_1105_fft_masked.tif
# Processed 91 file_1106.tif, saved FFT and masked result to 91 file_1106_fft_masked.tif
# Processed 91 file_1107.tif, saved FFT and masked result to 91 file_1107_fft_masked.tif
# Processed 91 file_1108.tif, saved FFT and masked result to 91 file_1108_fft_masked.tif
# Processed 91 file_1109.tif, saved FFT and masked result to 91 file_1109_fft_masked.tif
# Processed 91 file_111.tif, saved FFT and masked result to 91 file_111_fft_masked.tif
# Processed 91 file_1110.tif, saved FFT and masked result to 91 file_1110_fft_masked.tif
# Processed 91 file_1111.tif, saved FFT and masked result to 91 file_1111_fft_masked.tif
# Processed 91 file_1112.tif, saved FFT and masked result to 91 file_1112_fft_masked.tif
# Processed 91 file_1113.tif, saved FFT and masked result to 91 file_1113_fft_masked.tif
# Processed 91 file_1114.tif, saved FFT and masked result to 91 file_1114_fft_masked.tif
# Processed 91 file_1115.tif, saved FFT and masked result to 91 file_1115_fft_masked.tif
# Processed 91 file_1116.tif, saved FFT and masked result to 91 file_1116_fft_masked.tif
# Processed 91 file_1117.tif, saved FFT and masked result to 91 file_1117_fft_masked.tif
# Processed 91 file_1118.tif, saved FFT and masked result to 91 file_1118_fft_masked.tif
# Processed 91 file_1119.tif, saved FFT and masked result to 91 file_1119_fft_masked.tif
# Processed 91 file_112.tif, saved FFT and masked result to 91 file_112_fft_masked.tif
# Processed 91 file_1120.tif, saved FFT and masked result to 91 file_1120_fft_masked.tif
# Processed 91 file_1121.tif, saved FFT and masked result to 91 file_1121_fft_masked.tif
# Processed 91 file_1122.tif, saved FFT and masked result to 91 file_1122_fft_masked.tif
# Processed 91 file_1123.tif, saved FFT and masked result to 91 file_1123_fft_masked.tif
# Processed 91 file_1124.tif, saved FFT and masked result to 91 file_1124_fft_masked.tif
# Processed 91 file_1125.tif, saved FFT and masked result to 91 file_1125_fft_masked.tif
# Processed 91 file_1126.tif, saved FFT and masked result to 91 file_1126_fft_masked.tif
# Processed 91 file_1127.tif, saved FFT and masked result to 91 file_1127_fft_masked.tif
# Processed 91 file_1128.tif, saved FFT and masked result to 91 file_1128_fft_masked.tif
# Processed 91 file_1129.tif, saved FFT and masked result to 91 file_1129_fft_masked.tif
# Processed 91 file_113.tif, saved FFT and masked result to 91 file_113_fft_masked.tif
# Processed 91 file_1130.tif, saved FFT and masked result to 91 file_1130_fft_masked.tif
# Processed 91 file_1131.tif, saved FFT and masked result to 91 file_1131_fft_masked.tif
# Processed 91 file_1132.tif, saved FFT and masked result to 91 file_1132_fft_masked.tif
# Processed 91 file_1133.tif, saved FFT and masked result to 91 file_1133_fft_masked.tif
# Processed 91 file_1134.tif, saved FFT and masked result to 91 file_1134_fft_masked.tif
# Processed 91 file_1135.tif, saved FFT and masked result to 91 file_1135_fft_masked.tif
# Processed 91 file_1136.tif, saved FFT and masked result to 91 file_1136_fft_masked.tif
# Processed 91 file_1137.tif, saved FFT and masked result to 91 file_1137_fft_masked.tif
# Processed 91 file_1138.tif, saved FFT and masked result to 91 file_1138_fft_masked.tif
# Processed 91 file_1139.tif, saved FFT and masked result to 91 file_1139_fft_masked.tif
# Processed 91 file_114.tif, saved FFT and masked result to 91 file_114_fft_masked.tif
# Processed 91 file_1140.tif, saved FFT and masked result to 91 file_1140_fft_masked.tif
# Processed 91 file_1141.tif, saved FFT and masked result to 91 file_1141_fft_masked.tif
# Processed 91 file_1142.tif, saved FFT and masked result to 91 file_1142_fft_masked.tif
# Processed 91 file_1143.tif, saved FFT and masked result to 91 file_1143_fft_masked.tif
# Processed 91 file_1144.tif, saved FFT and masked result to 91 file_1144_fft_masked.tif
# Processed 91 file_1145.tif, saved FFT and masked result to 91 file_1145_fft_masked.tif
# Processed 91 file_1146.tif, saved FFT and masked result to 91 file_1146_fft_masked.tif
# Processed 91 file_1147.tif, saved FFT and masked result to 91 file_1147_fft_masked.tif
# Processed 91 file_1148.tif, saved FFT and masked result to 91 file_1148_fft_masked.tif
# Processed 91 file_1149.tif, saved FFT and masked result to 91 file_1149_fft_masked.tif
# Processed 91 file_115.tif, saved FFT and masked result to 91 file_115_fft_masked.tif
# Processed 91 file_1150.tif, saved FFT and masked result to 91 file_1150_fft_masked.tif
# Processed 91 file_1151.tif, saved FFT and masked result to 91 file_1151_fft_masked.tif
# Processed 91 file_1152.tif, saved FFT and masked result to 91 file_1152_fft_masked.tif
# Processed 91 file_1153.tif, saved FFT and masked result to 91 file_1153_fft_masked.tif
# Processed 91 file_1154.tif, saved FFT and masked result to 91 file_1154_fft_masked.tif
# Processed 91 file_1155.tif, saved FFT and masked result to 91 file_1155_fft_masked.tif
# Processed 91 file_1156.tif, saved FFT and masked result to 91 file_1156_fft_masked.tif
# Processed 91 file_1157.tif, saved FFT and masked result to 91 file_1157_fft_masked.tif
# Processed 91 file_1158.tif, saved FFT and masked result to 91 file_1158_fft_masked.tif
# Processed 91 file_1159.tif, saved FFT and masked result to 91 file_1159_fft_masked.tif
# Processed 91 file_116.tif, saved FFT and masked result to 91 file_116_fft_masked.tif
# Processed 91 file_1160.tif, saved FFT and masked result to 91 file_1160_fft_masked.tif
# Processed 91 file_1161.tif, saved FFT and masked result to 91 file_1161_fft_masked.tif
# Processed 91 file_1162.tif, saved FFT and masked result to 91 file_1162_fft_masked.tif
# Processed 91 file_1163.tif, saved FFT and masked result to 91 file_1163_fft_masked.tif
# Processed 91 file_1164.tif, saved FFT and masked result to 91 file_1164_fft_masked.tif
# Processed 91 file_1165.tif, saved FFT and masked result to 91 file_1165_fft_masked.tif
# Processed 91 file_1166.tif, saved FFT and masked result to 91 file_1166_fft_masked.tif
# Processed 91 file_1167.tif, saved FFT and masked result to 91 file_1167_fft_masked.tif
# Processed 91 file_1168.tif, saved FFT and masked result to 91 file_1168_fft_masked.tif
# Processed 91 file_1169.tif, saved FFT and masked result to 91 file_1169_fft_masked.tif
# Processed 91 file_117.tif, saved FFT and masked result to 91 file_117_fft_masked.tif
# Processed 91 file_1170.tif, saved FFT and masked result to 91 file_1170_fft_masked.tif
# Processed 91 file_1171.tif, saved FFT and masked result to 91 file_1171_fft_masked.tif
# Processed 91 file_1172.tif, saved FFT and masked result to 91 file_1172_fft_masked.tif
# Processed 91 file_1173.tif, saved FFT and masked result to 91 file_1173_fft_masked.tif
# Processed 91 file_1174.tif, saved FFT and masked result to 91 file_1174_fft_masked.tif
# Processed 91 file_1175.tif, saved FFT and masked result to 91 file_1175_fft_masked.tif
# Processed 91 file_1176.tif, saved FFT and masked result to 91 file_1176_fft_masked.tif
# Processed 91 file_1177.tif, saved FFT and masked result to 91 file_1177_fft_masked.tif
# Processed 91 file_1178.tif, saved FFT and masked result to 91 file_1178_fft_masked.tif
# Processed 91 file_1179.tif, saved FFT and masked result to 91 file_1179_fft_masked.tif
# Processed 91 file_118.tif, saved FFT and masked result to 91 file_118_fft_masked.tif
# Processed 91 file_1180.tif, saved FFT and masked result to 91 file_1180_fft_masked.tif
# Processed 91 file_1181.tif, saved FFT and masked result to 91 file_1181_fft_masked.tif
# Processed 91 file_1182.tif, saved FFT and masked result to 91 file_1182_fft_masked.tif
# Processed 91 file_1183.tif, saved FFT and masked result to 91 file_1183_fft_masked.tif
# Processed 91 file_1184.tif, saved FFT and masked result to 91 file_1184_fft_masked.tif
# Processed 91 file_1185.tif, saved FFT and masked result to 91 file_1185_fft_masked.tif
# Processed 91 file_1186.tif, saved FFT and masked result to 91 file_1186_fft_masked.tif
# Processed 91 file_1187.tif, saved FFT and masked result to 91 file_1187_fft_masked.tif
# Processed 91 file_1188.tif, saved FFT and masked result to 91 file_1188_fft_masked.tif
# Processed 91 file_1189.tif, saved FFT and masked result to 91 file_1189_fft_masked.tif
# Processed 91 file_119.tif, saved FFT and masked result to 91 file_119_fft_masked.tif
# Processed 91 file_1190.tif, saved FFT and masked result to 91 file_1190_fft_masked.tif
# Processed 91 file_1191.tif, saved FFT and masked result to 91 file_1191_fft_masked.tif
# Processed 91 file_1192.tif, saved FFT and masked result to 91 file_1192_fft_masked.tif
# Processed 91 file_1193.tif, saved FFT and masked result to 91 file_1193_fft_masked.tif
# Processed 91 file_1194.tif, saved FFT and masked result to 91 file_1194_fft_masked.tif
# Processed 91 file_1195.tif, saved FFT and masked result to 91 file_1195_fft_masked.tif
# Processed 91 file_1196.tif, saved FFT and masked result to 91 file_1196_fft_masked.tif
# Processed 91 file_1197.tif, saved FFT and masked result to 91 file_1197_fft_masked.tif
# Processed 91 file_1198.tif, saved FFT and masked result to 91 file_1198_fft_masked.tif
# Processed 91 file_1199.tif, saved FFT and masked result to 91 file_1199_fft_masked.tif
# Processed 91 file_12.tif, saved FFT and masked result to 91 file_12_fft_masked.tif
# Processed 91 file_120.tif, saved FFT and masked result to 91 file_120_fft_masked.tif
# Processed 91 file_1200.tif, saved FFT and masked result to 91 file_1200_fft_masked.tif
# Processed 91 file_1201.tif, saved FFT and masked result to 91 file_1201_fft_masked.tif
# Processed 91 file_1202.tif, saved FFT and masked result to 91 file_1202_fft_masked.tif
# Processed 91 file_1203.tif, saved FFT and masked result to 91 file_1203_fft_masked.tif
# Processed 91 file_1204.tif, saved FFT and masked result to 91 file_1204_fft_masked.tif
# Processed 91 file_1205.tif, saved FFT and masked result to 91 file_1205_fft_masked.tif
# Processed 91 file_1206.tif, saved FFT and masked result to 91 file_1206_fft_masked.tif
# Processed 91 file_1207.tif, saved FFT and masked result to 91 file_1207_fft_masked.tif
# Processed 91 file_1208.tif, saved FFT and masked result to 91 file_1208_fft_masked.tif
# Processed 91 file_1209.tif, saved FFT and masked result to 91 file_1209_fft_masked.tif
# Processed 91 file_121.tif, saved FFT and masked result to 91 file_121_fft_masked.tif
# Processed 91 file_1210.tif, saved FFT and masked result to 91 file_1210_fft_masked.tif
# Processed 91 file_1211.tif, saved FFT and masked result to 91 file_1211_fft_masked.tif
# Processed 91 file_1212.tif, saved FFT and masked result to 91 file_1212_fft_masked.tif
# Processed 91 file_1213.tif, saved FFT and masked result to 91 file_1213_fft_masked.tif
# Processed 91 file_1214.tif, saved FFT and masked result to 91 file_1214_fft_masked.tif
# Processed 91 file_1215.tif, saved FFT and masked result to 91 file_1215_fft_masked.tif
# Processed 91 file_1216.tif, saved FFT and masked result to 91 file_1216_fft_masked.tif
# Processed 91 file_1217.tif, saved FFT and masked result to 91 file_1217_fft_masked.tif
# Processed 91 file_1218.tif, saved FFT and masked result to 91 file_1218_fft_masked.tif
# Processed 91 file_1219.tif, saved FFT and masked result to 91 file_1219_fft_masked.tif
# Processed 91 file_122.tif, saved FFT and masked result to 91 file_122_fft_masked.tif
# Processed 91 file_1220.tif, saved FFT and masked result to 91 file_1220_fft_masked.tif
# Processed 91 file_1221.tif, saved FFT and masked result to 91 file_1221_fft_masked.tif
# Processed 91 file_1222.tif, saved FFT and masked result to 91 file_1222_fft_masked.tif
# Processed 91 file_1223.tif, saved FFT and masked result to 91 file_1223_fft_masked.tif
# Processed 91 file_1224.tif, saved FFT and masked result to 91 file_1224_fft_masked.tif
# Processed 91 file_1225.tif, saved FFT and masked result to 91 file_1225_fft_masked.tif
# Processed 91 file_1226.tif, saved FFT and masked result to 91 file_1226_fft_masked.tif
# Processed 91 file_1227.tif, saved FFT and masked result to 91 file_1227_fft_masked.tif
# Processed 91 file_1228.tif, saved FFT and masked result to 91 file_1228_fft_masked.tif
# Processed 91 file_1229.tif, saved FFT and masked result to 91 file_1229_fft_masked.tif
# Processed 91 file_123.tif, saved FFT and masked result to 91 file_123_fft_masked.tif
# Processed 91 file_1230.tif, saved FFT and masked result to 91 file_1230_fft_masked.tif
# Processed 91 file_1231.tif, saved FFT and masked result to 91 file_1231_fft_masked.tif
# Processed 91 file_1232.tif, saved FFT and masked result to 91 file_1232_fft_masked.tif
# Processed 91 file_1233.tif, saved FFT and masked result to 91 file_1233_fft_masked.tif
# Processed 91 file_1234.tif, saved FFT and masked result to 91 file_1234_fft_masked.tif
# Processed 91 file_1235.tif, saved FFT and masked result to 91 file_1235_fft_masked.tif
# Processed 91 file_1236.tif, saved FFT and masked result to 91 file_1236_fft_masked.tif
# Processed 91 file_1237.tif, saved FFT and masked result to 91 file_1237_fft_masked.tif
# Processed 91 file_1238.tif, saved FFT and masked result to 91 file_1238_fft_masked.tif
# Processed 91 file_1239.tif, saved FFT and masked result to 91 file_1239_fft_masked.tif
# Processed 91 file_124.tif, saved FFT and masked result to 91 file_124_fft_masked.tif
# Processed 91 file_1240.tif, saved FFT and masked result to 91 file_1240_fft_masked.tif
# Processed 91 file_1241.tif, saved FFT and masked result to 91 file_1241_fft_masked.tif
# Processed 91 file_1242.tif, saved FFT and masked result to 91 file_1242_fft_masked.tif
# Processed 91 file_1243.tif, saved FFT and masked result to 91 file_1243_fft_masked.tif
# Processed 91 file_1244.tif, saved FFT and masked result to 91 file_1244_fft_masked.tif
# Processed 91 file_1245.tif, saved FFT and masked result to 91 file_1245_fft_masked.tif
# Processed 91 file_1246.tif, saved FFT and masked result to 91 file_1246_fft_masked.tif
# Processed 91 file_1247.tif, saved FFT and masked result to 91 file_1247_fft_masked.tif
# Processed 91 file_1248.tif, saved FFT and masked result to 91 file_1248_fft_masked.tif
# Processed 91 file_1249.tif, saved FFT and masked result to 91 file_1249_fft_masked.tif
# Processed 91 file_125.tif, saved FFT and masked result to 91 file_125_fft_masked.tif
# Processed 91 file_1250.tif, saved FFT and masked result to 91 file_1250_fft_masked.tif
# Processed 91 file_1251.tif, saved FFT and masked result to 91 file_1251_fft_masked.tif
# Processed 91 file_1252.tif, saved FFT and masked result to 91 file_1252_fft_masked.tif
# Processed 91 file_1253.tif, saved FFT and masked result to 91 file_1253_fft_masked.tif
# Processed 91 file_1254.tif, saved FFT and masked result to 91 file_1254_fft_masked.tif
# Processed 91 file_1255.tif, saved FFT and masked result to 91 file_1255_fft_masked.tif
# Processed 91 file_1256.tif, saved FFT and masked result to 91 file_1256_fft_masked.tif
# Processed 91 file_1257.tif, saved FFT and masked result to 91 file_1257_fft_masked.tif
# Processed 91 file_1258.tif, saved FFT and masked result to 91 file_1258_fft_masked.tif
# Processed 91 file_1259.tif, saved FFT and masked result to 91 file_1259_fft_masked.tif
# Processed 91 file_126.tif, saved FFT and masked result to 91 file_126_fft_masked.tif
# Processed 91 file_1260.tif, saved FFT and masked result to 91 file_1260_fft_masked.tif
# Processed 91 file_1261.tif, saved FFT and masked result to 91 file_1261_fft_masked.tif
# Processed 91 file_1262.tif, saved FFT and masked result to 91 file_1262_fft_masked.tif
# Processed 91 file_1263.tif, saved FFT and masked result to 91 file_1263_fft_masked.tif
# Processed 91 file_1264.tif, saved FFT and masked result to 91 file_1264_fft_masked.tif
# Processed 91 file_1265.tif, saved FFT and masked result to 91 file_1265_fft_masked.tif
# Processed 91 file_1266.tif, saved FFT and masked result to 91 file_1266_fft_masked.tif
# Processed 91 file_1267.tif, saved FFT and masked result to 91 file_1267_fft_masked.tif
# Processed 91 file_1268.tif, saved FFT and masked result to 91 file_1268_fft_masked.tif
# Processed 91 file_1269.tif, saved FFT and masked result to 91 file_1269_fft_masked.tif
# Processed 91 file_127.tif, saved FFT and masked result to 91 file_127_fft_masked.tif
# Processed 91 file_1270.tif, saved FFT and masked result to 91 file_1270_fft_masked.tif
# Processed 91 file_1271.tif, saved FFT and masked result to 91 file_1271_fft_masked.tif
# Processed 91 file_1272.tif, saved FFT and masked result to 91 file_1272_fft_masked.tif
# Processed 91 file_1273.tif, saved FFT and masked result to 91 file_1273_fft_masked.tif
# Processed 91 file_1274.tif, saved FFT and masked result to 91 file_1274_fft_masked.tif
# Processed 91 file_1275.tif, saved FFT and masked result to 91 file_1275_fft_masked.tif
# Processed 91 file_1276.tif, saved FFT and masked result to 91 file_1276_fft_masked.tif
# Processed 91 file_1277.tif, saved FFT and masked result to 91 file_1277_fft_masked.tif
# Processed 91 file_1278.tif, saved FFT and masked result to 91 file_1278_fft_masked.tif
# Processed 91 file_1279.tif, saved FFT and masked result to 91 file_1279_fft_masked.tif
# Processed 91 file_128.tif, saved FFT and masked result to 91 file_128_fft_masked.tif
# Processed 91 file_1280.tif, saved FFT and masked result to 91 file_1280_fft_masked.tif
# Processed 91 file_1281.tif, saved FFT and masked result to 91 file_1281_fft_masked.tif
# Processed 91 file_1282.tif, saved FFT and masked result to 91 file_1282_fft_masked.tif
# Processed 91 file_1283.tif, saved FFT and masked result to 91 file_1283_fft_masked.tif
# Processed 91 file_1284.tif, saved FFT and masked result to 91 file_1284_fft_masked.tif
# Processed 91 file_1285.tif, saved FFT and masked result to 91 file_1285_fft_masked.tif
# Processed 91 file_1286.tif, saved FFT and masked result to 91 file_1286_fft_masked.tif
# Processed 91 file_1287.tif, saved FFT and masked result to 91 file_1287_fft_masked.tif
# Processed 91 file_1288.tif, saved FFT and masked result to 91 file_1288_fft_masked.tif
# Processed 91 file_1289.tif, saved FFT and masked result to 91 file_1289_fft_masked.tif
# Processed 91 file_129.tif, saved FFT and masked result to 91 file_129_fft_masked.tif
# Processed 91 file_1290.tif, saved FFT and masked result to 91 file_1290_fft_masked.tif
# Processed 91 file_1291.tif, saved FFT and masked result to 91 file_1291_fft_masked.tif
# Processed 91 file_1292.tif, saved FFT and masked result to 91 file_1292_fft_masked.tif
# Processed 91 file_1293.tif, saved FFT and masked result to 91 file_1293_fft_masked.tif
# Processed 91 file_1294.tif, saved FFT and masked result to 91 file_1294_fft_masked.tif
# Processed 91 file_1295.tif, saved FFT and masked result to 91 file_1295_fft_masked.tif
# Processed 91 file_1296.tif, saved FFT and masked result to 91 file_1296_fft_masked.tif
# Processed 91 file_1297.tif, saved FFT and masked result to 91 file_1297_fft_masked.tif
# Processed 91 file_1298.tif, saved FFT and masked result to 91 file_1298_fft_masked.tif
# Processed 91 file_1299.tif, saved FFT and masked result to 91 file_1299_fft_masked.tif
# Processed 91 file_13.tif, saved FFT and masked result to 91 file_13_fft_masked.tif
# Processed 91 file_130.tif, saved FFT and masked result to 91 file_130_fft_masked.tif
# Processed 91 file_1300.tif, saved FFT and masked result to 91 file_1300_fft_masked.tif
# Processed 91 file_1301.tif, saved FFT and masked result to 91 file_1301_fft_masked.tif
# Processed 91 file_1302.tif, saved FFT and masked result to 91 file_1302_fft_masked.tif
# Processed 91 file_1303.tif, saved FFT and masked result to 91 file_1303_fft_masked.tif
# Processed 91 file_1304.tif, saved FFT and masked result to 91 file_1304_fft_masked.tif
# Processed 91 file_1305.tif, saved FFT and masked result to 91 file_1305_fft_masked.tif
# Processed 91 file_1306.tif, saved FFT and masked result to 91 file_1306_fft_masked.tif
# Processed 91 file_1307.tif, saved FFT and masked result to 91 file_1307_fft_masked.tif
# Processed 91 file_1308.tif, saved FFT and masked result to 91 file_1308_fft_masked.tif
# Processed 91 file_1309.tif, saved FFT and masked result to 91 file_1309_fft_masked.tif
# Processed 91 file_131.tif, saved FFT and masked result to 91 file_131_fft_masked.tif
# Processed 91 file_1310.tif, saved FFT and masked result to 91 file_1310_fft_masked.tif
# Processed 91 file_1311.tif, saved FFT and masked result to 91 file_1311_fft_masked.tif
# Processed 91 file_1312.tif, saved FFT and masked result to 91 file_1312_fft_masked.tif
# Processed 91 file_1313.tif, saved FFT and masked result to 91 file_1313_fft_masked.tif
# Processed 91 file_132.tif, saved FFT and masked result to 91 file_132_fft_masked.tif
# Processed 91 file_133.tif, saved FFT and masked result to 91 file_133_fft_masked.tif
# Processed 91 file_134.tif, saved FFT and masked result to 91 file_134_fft_masked.tif
# Processed 91 file_135.tif, saved FFT and masked result to 91 file_135_fft_masked.tif
# Processed 91 file_136.tif, saved FFT and masked result to 91 file_136_fft_masked.tif
# Processed 91 file_137.tif, saved FFT and masked result to 91 file_137_fft_masked.tif
# Processed 91 file_138.tif, saved FFT and masked result to 91 file_138_fft_masked.tif
# Processed 91 file_139.tif, saved FFT and masked result to 91 file_139_fft_masked.tif
# Processed 91 file_14.tif, saved FFT and masked result to 91 file_14_fft_masked.tif
# Processed 91 file_140.tif, saved FFT and masked result to 91 file_140_fft_masked.tif
# Processed 91 file_141.tif, saved FFT and masked result to 91 file_141_fft_masked.tif
# Processed 91 file_142.tif, saved FFT and masked result to 91 file_142_fft_masked.tif
# Processed 91 file_143.tif, saved FFT and masked result to 91 file_143_fft_masked.tif
# Processed 91 file_144.tif, saved FFT and masked result to 91 file_144_fft_masked.tif
# Processed 91 file_145.tif, saved FFT and masked result to 91 file_145_fft_masked.tif
# Processed 91 file_146.tif, saved FFT and masked result to 91 file_146_fft_masked.tif
# Processed 91 file_147.tif, saved FFT and masked result to 91 file_147_fft_masked.tif
# Processed 91 file_148.tif, saved FFT and masked result to 91 file_148_fft_masked.tif
# Processed 91 file_149.tif, saved FFT and masked result to 91 file_149_fft_masked.tif
# Processed 91 file_15.tif, saved FFT and masked result to 91 file_15_fft_masked.tif
# Processed 91 file_150.tif, saved FFT and masked result to 91 file_150_fft_masked.tif
# Processed 91 file_151.tif, saved FFT and masked result to 91 file_151_fft_masked.tif
# Processed 91 file_152.tif, saved FFT and masked result to 91 file_152_fft_masked.tif
# Processed 91 file_153.tif, saved FFT and masked result to 91 file_153_fft_masked.tif
# Processed 91 file_154.tif, saved FFT and masked result to 91 file_154_fft_masked.tif
# Processed 91 file_155.tif, saved FFT and masked result to 91 file_155_fft_masked.tif
# Processed 91 file_156.tif, saved FFT and masked result to 91 file_156_fft_masked.tif
# Processed 91 file_157.tif, saved FFT and masked result to 91 file_157_fft_masked.tif
# Processed 91 file_158.tif, saved FFT and masked result to 91 file_158_fft_masked.tif
# Processed 91 file_159.tif, saved FFT and masked result to 91 file_159_fft_masked.tif
# Processed 91 file_16.tif, saved FFT and masked result to 91 file_16_fft_masked.tif
# Processed 91 file_160.tif, saved FFT and masked result to 91 file_160_fft_masked.tif
# Processed 91 file_161.tif, saved FFT and masked result to 91 file_161_fft_masked.tif
# Processed 91 file_162.tif, saved FFT and masked result to 91 file_162_fft_masked.tif
# Processed 91 file_163.tif, saved FFT and masked result to 91 file_163_fft_masked.tif
# Processed 91 file_164.tif, saved FFT and masked result to 91 file_164_fft_masked.tif
# Processed 91 file_165.tif, saved FFT and masked result to 91 file_165_fft_masked.tif
# Processed 91 file_166.tif, saved FFT and masked result to 91 file_166_fft_masked.tif
# Processed 91 file_167.tif, saved FFT and masked result to 91 file_167_fft_masked.tif
# Processed 91 file_168.tif, saved FFT and masked result to 91 file_168_fft_masked.tif
# Processed 91 file_169.tif, saved FFT and masked result to 91 file_169_fft_masked.tif
# Processed 91 file_17.tif, saved FFT and masked result to 91 file_17_fft_masked.tif
# Processed 91 file_170.tif, saved FFT and masked result to 91 file_170_fft_masked.tif
# Processed 91 file_171.tif, saved FFT and masked result to 91 file_171_fft_masked.tif
# Processed 91 file_172.tif, saved FFT and masked result to 91 file_172_fft_masked.tif
# Processed 91 file_173.tif, saved FFT and masked result to 91 file_173_fft_masked.tif
# Processed 91 file_174.tif, saved FFT and masked result to 91 file_174_fft_masked.tif
# Processed 91 file_175.tif, saved FFT and masked result to 91 file_175_fft_masked.tif
# Processed 91 file_176.tif, saved FFT and masked result to 91 file_176_fft_masked.tif
# Processed 91 file_177.tif, saved FFT and masked result to 91 file_177_fft_masked.tif
# Processed 91 file_178.tif, saved FFT and masked result to 91 file_178_fft_masked.tif
# Processed 91 file_179.tif, saved FFT and masked result to 91 file_179_fft_masked.tif
# Processed 91 file_18.tif, saved FFT and masked result to 91 file_18_fft_masked.tif
# Processed 91 file_180.tif, saved FFT and masked result to 91 file_180_fft_masked.tif
# Processed 91 file_181.tif, saved FFT and masked result to 91 file_181_fft_masked.tif
# Processed 91 file_182.tif, saved FFT and masked result to 91 file_182_fft_masked.tif
# Processed 91 file_183.tif, saved FFT and masked result to 91 file_183_fft_masked.tif
# Processed 91 file_184.tif, saved FFT and masked result to 91 file_184_fft_masked.tif
# Processed 91 file_185.tif, saved FFT and masked result to 91 file_185_fft_masked.tif
# Processed 91 file_186.tif, saved FFT and masked result to 91 file_186_fft_masked.tif
# Processed 91 file_187.tif, saved FFT and masked result to 91 file_187_fft_masked.tif
# Processed 91 file_188.tif, saved FFT and masked result to 91 file_188_fft_masked.tif
# Processed 91 file_189.tif, saved FFT and masked result to 91 file_189_fft_masked.tif
# Processed 91 file_19.tif, saved FFT and masked result to 91 file_19_fft_masked.tif
# Processed 91 file_190.tif, saved FFT and masked result to 91 file_190_fft_masked.tif
# Processed 91 file_191.tif, saved FFT and masked result to 91 file_191_fft_masked.tif
# Processed 91 file_192.tif, saved FFT and masked result to 91 file_192_fft_masked.tif
# Processed 91 file_193.tif, saved FFT and masked result to 91 file_193_fft_masked.tif
# Processed 91 file_194.tif, saved FFT and masked result to 91 file_194_fft_masked.tif
# Processed 91 file_195.tif, saved FFT and masked result to 91 file_195_fft_masked.tif
# Processed 91 file_196.tif, saved FFT and masked result to 91 file_196_fft_masked.tif
# Processed 91 file_197.tif, saved FFT and masked result to 91 file_197_fft_masked.tif
# Processed 91 file_198.tif, saved FFT and masked result to 91 file_198_fft_masked.tif
# Processed 91 file_199.tif, saved FFT and masked result to 91 file_199_fft_masked.tif
# Processed 91 file_2.tif, saved FFT and masked result to 91 file_2_fft_masked.tif
# Processed 91 file_20.tif, saved FFT and masked result to 91 file_20_fft_masked.tif
# Processed 91 file_200.tif, saved FFT and masked result to 91 file_200_fft_masked.tif
# Processed 91 file_201.tif, saved FFT and masked result to 91 file_201_fft_masked.tif
# Processed 91 file_202.tif, saved FFT and masked result to 91 file_202_fft_masked.tif
# Processed 91 file_203.tif, saved FFT and masked result to 91 file_203_fft_masked.tif
# Processed 91 file_204.tif, saved FFT and masked result to 91 file_204_fft_masked.tif
# Processed 91 file_205.tif, saved FFT and masked result to 91 file_205_fft_masked.tif
# Processed 91 file_206.tif, saved FFT and masked result to 91 file_206_fft_masked.tif
# Processed 91 file_207.tif, saved FFT and masked result to 91 file_207_fft_masked.tif
# Processed 91 file_208.tif, saved FFT and masked result to 91 file_208_fft_masked.tif
# Processed 91 file_209.tif, saved FFT and masked result to 91 file_209_fft_masked.tif
# Processed 91 file_21.tif, saved FFT and masked result to 91 file_21_fft_masked.tif
# Processed 91 file_210.tif, saved FFT and masked result to 91 file_210_fft_masked.tif
# Processed 91 file_211.tif, saved FFT and masked result to 91 file_211_fft_masked.tif
# Processed 91 file_212.tif, saved FFT and masked result to 91 file_212_fft_masked.tif
# Processed 91 file_213.tif, saved FFT and masked result to 91 file_213_fft_masked.tif
# Processed 91 file_214.tif, saved FFT and masked result to 91 file_214_fft_masked.tif
# Processed 91 file_215.tif, saved FFT and masked result to 91 file_215_fft_masked.tif
# Processed 91 file_216.tif, saved FFT and masked result to 91 file_216_fft_masked.tif
# Processed 91 file_217.tif, saved FFT and masked result to 91 file_217_fft_masked.tif
# Processed 91 file_218.tif, saved FFT and masked result to 91 file_218_fft_masked.tif
# Processed 91 file_219.tif, saved FFT and masked result to 91 file_219_fft_masked.tif
# Processed 91 file_22.tif, saved FFT and masked result to 91 file_22_fft_masked.tif
# Processed 91 file_220.tif, saved FFT and masked result to 91 file_220_fft_masked.tif
# Processed 91 file_221.tif, saved FFT and masked result to 91 file_221_fft_masked.tif
# Processed 91 file_222.tif, saved FFT and masked result to 91 file_222_fft_masked.tif
# Processed 91 file_223.tif, saved FFT and masked result to 91 file_223_fft_masked.tif
# Processed 91 file_224.tif, saved FFT and masked result to 91 file_224_fft_masked.tif
# Processed 91 file_225.tif, saved FFT and masked result to 91 file_225_fft_masked.tif
# Processed 91 file_226.tif, saved FFT and masked result to 91 file_226_fft_masked.tif
# Processed 91 file_227.tif, saved FFT and masked result to 91 file_227_fft_masked.tif
# Processed 91 file_228.tif, saved FFT and masked result to 91 file_228_fft_masked.tif
# Processed 91 file_229.tif, saved FFT and masked result to 91 file_229_fft_masked.tif
# Processed 91 file_23.tif, saved FFT and masked result to 91 file_23_fft_masked.tif
# Processed 91 file_230.tif, saved FFT and masked result to 91 file_230_fft_masked.tif
# Processed 91 file_231.tif, saved FFT and masked result to 91 file_231_fft_masked.tif
# Processed 91 file_232.tif, saved FFT and masked result to 91 file_232_fft_masked.tif
# Processed 91 file_233.tif, saved FFT and masked result to 91 file_233_fft_masked.tif
# Processed 91 file_234.tif, saved FFT and masked result to 91 file_234_fft_masked.tif
# Processed 91 file_235.tif, saved FFT and masked result to 91 file_235_fft_masked.tif
# Processed 91 file_236.tif, saved FFT and masked result to 91 file_236_fft_masked.tif
# Processed 91 file_237.tif, saved FFT and masked result to 91 file_237_fft_masked.tif
# Processed 91 file_238.tif, saved FFT and masked result to 91 file_238_fft_masked.tif
# Processed 91 file_239.tif, saved FFT and masked result to 91 file_239_fft_masked.tif
# Processed 91 file_24.tif, saved FFT and masked result to 91 file_24_fft_masked.tif
# Processed 91 file_240.tif, saved FFT and masked result to 91 file_240_fft_masked.tif
# Processed 91 file_241.tif, saved FFT and masked result to 91 file_241_fft_masked.tif
# Processed 91 file_242.tif, saved FFT and masked result to 91 file_242_fft_masked.tif
# Processed 91 file_243.tif, saved FFT and masked result to 91 file_243_fft_masked.tif
# Processed 91 file_244.tif, saved FFT and masked result to 91 file_244_fft_masked.tif
# Processed 91 file_245.tif, saved FFT and masked result to 91 file_245_fft_masked.tif
# Processed 91 file_246.tif, saved FFT and masked result to 91 file_246_fft_masked.tif
# Processed 91 file_247.tif, saved FFT and masked result to 91 file_247_fft_masked.tif
# Processed 91 file_248.tif, saved FFT and masked result to 91 file_248_fft_masked.tif
# Processed 91 file_249.tif, saved FFT and masked result to 91 file_249_fft_masked.tif
# Processed 91 file_25.tif, saved FFT and masked result to 91 file_25_fft_masked.tif
# Processed 91 file_250.tif, saved FFT and masked result to 91 file_250_fft_masked.tif
# Processed 91 file_251.tif, saved FFT and masked result to 91 file_251_fft_masked.tif
# Processed 91 file_252.tif, saved FFT and masked result to 91 file_252_fft_masked.tif
# Processed 91 file_253.tif, saved FFT and masked result to 91 file_253_fft_masked.tif
# Processed 91 file_254.tif, saved FFT and masked result to 91 file_254_fft_masked.tif
# Processed 91 file_255.tif, saved FFT and masked result to 91 file_255_fft_masked.tif
# Processed 91 file_256.tif, saved FFT and masked result to 91 file_256_fft_masked.tif
# Processed 91 file_257.tif, saved FFT and masked result to 91 file_257_fft_masked.tif
# Processed 91 file_258.tif, saved FFT and masked result to 91 file_258_fft_masked.tif
# Processed 91 file_259.tif, saved FFT and masked result to 91 file_259_fft_masked.tif
# Processed 91 file_26.tif, saved FFT and masked result to 91 file_26_fft_masked.tif
# Processed 91 file_260.tif, saved FFT and masked result to 91 file_260_fft_masked.tif
# Processed 91 file_261.tif, saved FFT and masked result to 91 file_261_fft_masked.tif
# Processed 91 file_262.tif, saved FFT and masked result to 91 file_262_fft_masked.tif
# Processed 91 file_263.tif, saved FFT and masked result to 91 file_263_fft_masked.tif
# Processed 91 file_264.tif, saved FFT and masked result to 91 file_264_fft_masked.tif
# Processed 91 file_265.tif, saved FFT and masked result to 91 file_265_fft_masked.tif
# Processed 91 file_266.tif, saved FFT and masked result to 91 file_266_fft_masked.tif
# Processed 91 file_267.tif, saved FFT and masked result to 91 file_267_fft_masked.tif
# Processed 91 file_268.tif, saved FFT and masked result to 91 file_268_fft_masked.tif
# Processed 91 file_269.tif, saved FFT and masked result to 91 file_269_fft_masked.tif
# Processed 91 file_27.tif, saved FFT and masked result to 91 file_27_fft_masked.tif
# Processed 91 file_270.tif, saved FFT and masked result to 91 file_270_fft_masked.tif
# Processed 91 file_271.tif, saved FFT and masked result to 91 file_271_fft_masked.tif
# Processed 91 file_272.tif, saved FFT and masked result to 91 file_272_fft_masked.tif
# Processed 91 file_273.tif, saved FFT and masked result to 91 file_273_fft_masked.tif
# Processed 91 file_274.tif, saved FFT and masked result to 91 file_274_fft_masked.tif
# Processed 91 file_275.tif, saved FFT and masked result to 91 file_275_fft_masked.tif
# Processed 91 file_276.tif, saved FFT and masked result to 91 file_276_fft_masked.tif
# Processed 91 file_277.tif, saved FFT and masked result to 91 file_277_fft_masked.tif
# Processed 91 file_278.tif, saved FFT and masked result to 91 file_278_fft_masked.tif
# Processed 91 file_279.tif, saved FFT and masked result to 91 file_279_fft_masked.tif
# Processed 91 file_28.tif, saved FFT and masked result to 91 file_28_fft_masked.tif
# Processed 91 file_280.tif, saved FFT and masked result to 91 file_280_fft_masked.tif
# Processed 91 file_281.tif, saved FFT and masked result to 91 file_281_fft_masked.tif
# Processed 91 file_282.tif, saved FFT and masked result to 91 file_282_fft_masked.tif
# Processed 91 file_283.tif, saved FFT and masked result to 91 file_283_fft_masked.tif
# Processed 91 file_284.tif, saved FFT and masked result to 91 file_284_fft_masked.tif
# Processed 91 file_285.tif, saved FFT and masked result to 91 file_285_fft_masked.tif
# Processed 91 file_286.tif, saved FFT and masked result to 91 file_286_fft_masked.tif
# Processed 91 file_287.tif, saved FFT and masked result to 91 file_287_fft_masked.tif
# Processed 91 file_288.tif, saved FFT and masked result to 91 file_288_fft_masked.tif
# Processed 91 file_289.tif, saved FFT and masked result to 91 file_289_fft_masked.tif
# Processed 91 file_29.tif, saved FFT and masked result to 91 file_29_fft_masked.tif
# Processed 91 file_290.tif, saved FFT and masked result to 91 file_290_fft_masked.tif
# Processed 91 file_291.tif, saved FFT and masked result to 91 file_291_fft_masked.tif
# Processed 91 file_292.tif, saved FFT and masked result to 91 file_292_fft_masked.tif
# Processed 91 file_293.tif, saved FFT and masked result to 91 file_293_fft_masked.tif
# Processed 91 file_294.tif, saved FFT and masked result to 91 file_294_fft_masked.tif
# Processed 91 file_295.tif, saved FFT and masked result to 91 file_295_fft_masked.tif
# Processed 91 file_296.tif, saved FFT and masked result to 91 file_296_fft_masked.tif
# Processed 91 file_297.tif, saved FFT and masked result to 91 file_297_fft_masked.tif
# Processed 91 file_298.tif, saved FFT and masked result to 91 file_298_fft_masked.tif
# Processed 91 file_299.tif, saved FFT and masked result to 91 file_299_fft_masked.tif
# Processed 91 file_3.tif, saved FFT and masked result to 91 file_3_fft_masked.tif
# Processed 91 file_30.tif, saved FFT and masked result to 91 file_30_fft_masked.tif
# Processed 91 file_300.tif, saved FFT and masked result to 91 file_300_fft_masked.tif
# Processed 91 file_301.tif, saved FFT and masked result to 91 file_301_fft_masked.tif
# Processed 91 file_302.tif, saved FFT and masked result to 91 file_302_fft_masked.tif
# Processed 91 file_303.tif, saved FFT and masked result to 91 file_303_fft_masked.tif
# Processed 91 file_304.tif, saved FFT and masked result to 91 file_304_fft_masked.tif
# Processed 91 file_305.tif, saved FFT and masked result to 91 file_305_fft_masked.tif
# Processed 91 file_306.tif, saved FFT and masked result to 91 file_306_fft_masked.tif
# Processed 91 file_307.tif, saved FFT and masked result to 91 file_307_fft_masked.tif
# Processed 91 file_308.tif, saved FFT and masked result to 91 file_308_fft_masked.tif
# Processed 91 file_309.tif, saved FFT and masked result to 91 file_309_fft_masked.tif
# Processed 91 file_31.tif, saved FFT and masked result to 91 file_31_fft_masked.tif
# Processed 91 file_310.tif, saved FFT and masked result to 91 file_310_fft_masked.tif
# Processed 91 file_311.tif, saved FFT and masked result to 91 file_311_fft_masked.tif
# Processed 91 file_312.tif, saved FFT and masked result to 91 file_312_fft_masked.tif
# Processed 91 file_313.tif, saved FFT and masked result to 91 file_313_fft_masked.tif
# Processed 91 file_314.tif, saved FFT and masked result to 91 file_314_fft_masked.tif
# Processed 91 file_315.tif, saved FFT and masked result to 91 file_315_fft_masked.tif
# Processed 91 file_316.tif, saved FFT and masked result to 91 file_316_fft_masked.tif
# Processed 91 file_317.tif, saved FFT and masked result to 91 file_317_fft_masked.tif
# ...
# Processed 91 file_83.tif, saved FFT and masked result to 91 file_83_fft_masked.tif
# Processed 91 file_830.tif, saved FFT and masked result to 91 file_830_fft_masked.tif
# Processed 91 file_831.tif, saved FFT and masked result to 91 file_831_fft_masked.tif
# Processed 91 file_832.tif, saved FFT and masked result to 91 file_832_fft_masked.tif
# Processed 91 file_833.tif, saved FFT and masked result to 91 file_833_fft_masked.tif
# Processed 91 file_834.tif, saved FFT and masked result to 91 file_834_fft_masked.tif
# Processed 91 file_835.tif, saved FFT and masked result to 91 file_835_fft_masked.tif
# Processed 91 file_836.tif, saved FFT and masked result to 91 file_836_fft_masked.tif
# Processed 91 file_837.tif, saved FFT and masked result to 91 file_837_fft_masked.tif
# Processed 91 file_838.tif, saved FFT and masked result to 91 file_838_fft_masked.tif
# Processed 91 file_839.tif, saved FFT and masked result to 91 file_839_fft_masked.tif
# Processed 91 file_84.tif, saved FFT and masked result to 91 file_84_fft_masked.tif
# Processed 91 file_840.tif, saved FFT and masked result to 91 file_840_fft_masked.tif
# Processed 91 file_841.tif, saved FFT and masked result to 91 file_841_fft_masked.tif
# Processed 91 file_842.tif, saved FFT and masked result to 91 file_842_fft_masked.tif
# Processed 91 file_843.tif, saved FFT and masked result to 91 file_843_fft_masked.tif
# Processed 91 file_844.tif, saved FFT and masked result to 91 file_844_fft_masked.tif
# Processed 91 file_845.tif, saved FFT and masked result to 91 file_845_fft_masked.tif
# Processed 91 file_846.tif, saved FFT and masked result to 91 file_846_fft_masked.tif
# Processed 91 file_847.tif, saved FFT and masked result to 91 file_847_fft_masked.tif
# Processed 91 file_848.tif, saved FFT and masked result to 91 file_848_fft_masked.tif
# Processed 91 file_849.tif, saved FFT and masked result to 91 file_849_fft_masked.tif
# Processed 91 file_85.tif, saved FFT and masked result to 91 file_85_fft_masked.tif
# Processed 91 file_850.tif, saved FFT and masked result to 91 file_850_fft_masked.tif
# Processed 91 file_851.tif, saved FFT and masked result to 91 file_851_fft_masked.tif
# Processed 91 file_852.tif, saved FFT and masked result to 91 file_852_fft_masked.tif
# Processed 91 file_853.tif, saved FFT and masked result to 91 file_853_fft_masked.tif
# Processed 91 file_854.tif, saved FFT and masked result to 91 file_854_fft_masked.tif
# Processed 91 file_855.tif, saved FFT and masked result to 91 file_855_fft_masked.tif
# Processed 91 file_856.tif, saved FFT and masked result to 91 file_856_fft_masked.tif
# Processed 91 file_857.tif, saved FFT and masked result to 91 file_857_fft_masked.tif
# Processed 91 file_858.tif, saved FFT and masked result to 91 file_858_fft_masked.tif
# Processed 91 file_859.tif, saved FFT and masked result to 91 file_859_fft_masked.tif
# Processed 91 file_86.tif, saved FFT and masked result to 91 file_86_fft_masked.tif
# Processed 91 file_860.tif, saved FFT and masked result to 91 file_860_fft_masked.tif
# Processed 91 file_861.tif, saved FFT and masked result to 91 file_861_fft_masked.tif
# Processed 91 file_862.tif, saved FFT and masked result to 91 file_862_fft_masked.tif
# Processed 91 file_863.tif, saved FFT and masked result to 91 file_863_fft_masked.tif
# Processed 91 file_864.tif, saved FFT and masked result to 91 file_864_fft_masked.tif
# Processed 91 file_865.tif, saved FFT and masked result to 91 file_865_fft_masked.tif
# Processed 91 file_866.tif, saved FFT and masked result to 91 file_866_fft_masked.tif
# Processed 91 file_867.tif, saved FFT and masked result to 91 file_867_fft_masked.tif
# Processed 91 file_868.tif, saved FFT and masked result to 91 file_868_fft_masked.tif
# Processed 91 file_869.tif, saved FFT and masked result to 91 file_869_fft_masked.tif
# Processed 91 file_87.tif, saved FFT and masked result to 91 file_87_fft_masked.tif
# Processed 91 file_870.tif, saved FFT and masked result to 91 file_870_fft_masked.tif
# Processed 91 file_871.tif, saved FFT and masked result to 91 file_871_fft_masked.tif
# Processed 91 file_872.tif, saved FFT and masked result to 91 file_872_fft_masked.tif
# Processed 91 file_873.tif, saved FFT and masked result to 91 file_873_fft_masked.tif
# Processed 91 file_874.tif, saved FFT and masked result to 91 file_874_fft_masked.tif
# Processed 91 file_875.tif, saved FFT and masked result to 91 file_875_fft_masked.tif
# Processed 91 file_876.tif, saved FFT and masked result to 91 file_876_fft_masked.tif
# Processed 91 file_877.tif, saved FFT and masked result to 91 file_877_fft_masked.tif
# Processed 91 file_878.tif, saved FFT and masked result to 91 file_878_fft_masked.tif
# Processed 91 file_879.tif, saved FFT and masked result to 91 file_879_fft_masked.tif
# Processed 91 file_88.tif, saved FFT and masked result to 91 file_88_fft_masked.tif
# Processed 91 file_880.tif, saved FFT and masked result to 91 file_880_fft_masked.tif
# Processed 91 file_881.tif, saved FFT and masked result to 91 file_881_fft_masked.tif
# Processed 91 file_882.tif, saved FFT and masked result to 91 file_882_fft_masked.tif
# Processed 91 file_883.tif, saved FFT and masked result to 91 file_883_fft_masked.tif
# Processed 91 file_884.tif, saved FFT and masked result to 91 file_884_fft_masked.tif
# Processed 91 file_885.tif, saved FFT and masked result to 91 file_885_fft_masked.tif
# Processed 91 file_886.tif, saved FFT and masked result to 91 file_886_fft_masked.tif
# Processed 91 file_887.tif, saved FFT and masked result to 91 file_887_fft_masked.tif
# Processed 91 file_888.tif, saved FFT and masked result to 91 file_888_fft_masked.tif
# Processed 91 file_889.tif, saved FFT and masked result to 91 file_889_fft_masked.tif
# Processed 91 file_89.tif, saved FFT and masked result to 91 file_89_fft_masked.tif
# Processed 91 file_890.tif, saved FFT and masked result to 91 file_890_fft_masked.tif
# Processed 91 file_891.tif, saved FFT and masked result to 91 file_891_fft_masked.tif
# Processed 91 file_892.tif, saved FFT and masked result to 91 file_892_fft_masked.tif
# Processed 91 file_893.tif, saved FFT and masked result to 91 file_893_fft_masked.tif
# Processed 91 file_894.tif, saved FFT and masked result to 91 file_894_fft_masked.tif
# Processed 91 file_895.tif, saved FFT and masked result to 91 file_895_fft_masked.tif
# Processed 91 file_896.tif, saved FFT and masked result to 91 file_896_fft_masked.tif
# Processed 91 file_897.tif, saved FFT and masked result to 91 file_897_fft_masked.tif
# Processed 91 file_898.tif, saved FFT and masked result to 91 file_898_fft_masked.tif
# Processed 91 file_899.tif, saved FFT and masked result to 91 file_899_fft_masked.tif
# Processed 91 file_9.tif, saved FFT and masked result to 91 file_9_fft_masked.tif
# Processed 91 file_90.tif, saved FFT and masked result to 91 file_90_fft_masked.tif
# Processed 91 file_900.tif, saved FFT and masked result to 91 file_900_fft_masked.tif
# Processed 91 file_901.tif, saved FFT and masked result to 91 file_901_fft_masked.tif
# Processed 91 file_902.tif, saved FFT and masked result to 91 file_902_fft_masked.tif
# Processed 91 file_903.tif, saved FFT and masked result to 91 file_903_fft_masked.tif
# Processed 91 file_904.tif, saved FFT and masked result to 91 file_904_fft_masked.tif
# Processed 91 file_905.tif, saved FFT and masked result to 91 file_905_fft_masked.tif
# Processed 91 file_906.tif, saved FFT and masked result to 91 file_906_fft_masked.tif
# Processed 91 file_907.tif, saved FFT and masked result to 91 file_907_fft_masked.tif
# Processed 91 file_908.tif, saved FFT and masked result to 91 file_908_fft_masked.tif
# Processed 91 file_909.tif, saved FFT and masked result to 91 file_909_fft_masked.tif
# Processed 91 file_91.tif, saved FFT and masked result to 91 file_91_fft_masked.tif
# Processed 91 file_910.tif, saved FFT and masked result to 91 file_910_fft_masked.tif
# Processed 91 file_911.tif, saved FFT and masked result to 91 file_911_fft_masked.tif
# Processed 91 file_912.tif, saved FFT and masked result to 91 file_912_fft_masked.tif
# Processed 91 file_913.tif, saved FFT and masked result to 91 file_913_fft_masked.tif
# Processed 91 file_914.tif, saved FFT and masked result to 91 file_914_fft_masked.tif
# Processed 91 file_915.tif, saved FFT and masked result to 91 file_915_fft_masked.tif
# Processed 91 file_916.tif, saved FFT and masked result to 91 file_916_fft_masked.tif
# Processed 91 file_917.tif, saved FFT and masked result to 91 file_917_fft_masked.tif
# Processed 91 file_918.tif, saved FFT and masked result to 91 file_918_fft_masked.tif
# Processed 91 file_919.tif, saved FFT and masked result to 91 file_919_fft_masked.tif
# Processed 91 file_92.tif, saved FFT and masked result to 91 file_92_fft_masked.tif
# Processed 91 file_920.tif, saved FFT and masked result to 91 file_920_fft_masked.tif
# Processed 91 file_921.tif, saved FFT and masked result to 91 file_921_fft_masked.tif
# Processed 91 file_922.tif, saved FFT and masked result to 91 file_922_fft_masked.tif
# Processed 91 file_923.tif, saved FFT and masked result to 91 file_923_fft_masked.tif
# Processed 91 file_924.tif, saved FFT and masked result to 91 file_924_fft_masked.tif
# Processed 91 file_925.tif, saved FFT and masked result to 91 file_925_fft_masked.tif
# Processed 91 file_926.tif, saved FFT and masked result to 91 file_926_fft_masked.tif
# Processed 91 file_927.tif, saved FFT and masked result to 91 file_927_fft_masked.tif
# Processed 91 file_928.tif, saved FFT and masked result to 91 file_928_fft_masked.tif
# Processed 91 file_929.tif, saved FFT and masked result to 91 file_929_fft_masked.tif
# Processed 91 file_93.tif, saved FFT and masked result to 91 file_93_fft_masked.tif
# Processed 91 file_930.tif, saved FFT and masked result to 91 file_930_fft_masked.tif
# Processed 91 file_931.tif, saved FFT and masked result to 91 file_931_fft_masked.tif
# Processed 91 file_932.tif, saved FFT and masked result to 91 file_932_fft_masked.tif
# Processed 91 file_933.tif, saved FFT and masked result to 91 file_933_fft_masked.tif
# Processed 91 file_934.tif, saved FFT and masked result to 91 file_934_fft_masked.tif
# Processed 91 file_935.tif, saved FFT and masked result to 91 file_935_fft_masked.tif
# Processed 91 file_936.tif, saved FFT and masked result to 91 file_936_fft_masked.tif
# Processed 91 file_937.tif, saved FFT and masked result to 91 file_937_fft_masked.tif
# Processed 91 file_938.tif, saved FFT and masked result to 91 file_938_fft_masked.tif
# Processed 91 file_939.tif, saved FFT and masked result to 91 file_939_fft_masked.tif
# Processed 91 file_94.tif, saved FFT and masked result to 91 file_94_fft_masked.tif
# Processed 91 file_940.tif, saved FFT and masked result to 91 file_940_fft_masked.tif
# Processed 91 file_941.tif, saved FFT and masked result to 91 file_941_fft_masked.tif
# Processed 91 file_942.tif, saved FFT and masked result to 91 file_942_fft_masked.tif
# Processed 91 file_943.tif, saved FFT and masked result to 91 file_943_fft_masked.tif
# Processed 91 file_944.tif, saved FFT and masked result to 91 file_944_fft_masked.tif
# Processed 91 file_945.tif, saved FFT and masked result to 91 file_945_fft_masked.tif
# Processed 91 file_946.tif, saved FFT and masked result to 91 file_946_fft_masked.tif
# Processed 91 file_947.tif, saved FFT and masked result to 91 file_947_fft_masked.tif
# Processed 91 file_948.tif, saved FFT and masked result to 91 file_948_fft_masked.tif
# Processed 91 file_949.tif, saved FFT and masked result to 91 file_949_fft_masked.tif
# Processed 91 file_95.tif, saved FFT and masked result to 91 file_95_fft_masked.tif
# Processed 91 file_950.tif, saved FFT and masked result to 91 file_950_fft_masked.tif
# Processed 91 file_951.tif, saved FFT and masked result to 91 file_951_fft_masked.tif
# Processed 91 file_952.tif, saved FFT and masked result to 91 file_952_fft_masked.tif
# Processed 91 file_953.tif, saved FFT and masked result to 91 file_953_fft_masked.tif
# Processed 91 file_954.tif, saved FFT and masked result to 91 file_954_fft_masked.tif
# Processed 91 file_955.tif, saved FFT and masked result to 91 file_955_fft_masked.tif
# Processed 91 file_956.tif, saved FFT and masked result to 91 file_956_fft_masked.tif
# Processed 91 file_957.tif, saved FFT and masked result to 91 file_957_fft_masked.tif
# Processed 91 file_958.tif, saved FFT and masked result to 91 file_958_fft_masked.tif
# Processed 91 file_959.tif, saved FFT and masked result to 91 file_959_fft_masked.tif
# Processed 91 file_96.tif, saved FFT and masked result to 91 file_96_fft_masked.tif
# Processed 91 file_960.tif, saved FFT and masked result to 91 file_960_fft_masked.tif
# Processed 91 file_961.tif, saved FFT and masked result to 91 file_961_fft_masked.tif
# Processed 91 file_962.tif, saved FFT and masked result to 91 file_962_fft_masked.tif
# Processed 91 file_963.tif, saved FFT and masked result to 91 file_963_fft_masked.tif
# Processed 91 file_964.tif, saved FFT and masked result to 91 file_964_fft_masked.tif
# Processed 91 file_965.tif, saved FFT and masked result to 91 file_965_fft_masked.tif
# Processed 91 file_966.tif, saved FFT and masked result to 91 file_966_fft_masked.tif
# Processed 91 file_967.tif, saved FFT and masked result to 91 file_967_fft_masked.tif
# Processed 91 file_968.tif, saved FFT and masked result to 91 file_968_fft_masked.tif
# Processed 91 file_969.tif, saved FFT and masked result to 91 file_969_fft_masked.tif
# Processed 91 file_97.tif, saved FFT and masked result to 91 file_97_fft_masked.tif
# Processed 91 file_970.tif, saved FFT and masked result to 91 file_970_fft_masked.tif
# Processed 91 file_971.tif, saved FFT and masked result to 91 file_971_fft_masked.tif
# Processed 91 file_972.tif, saved FFT and masked result to 91 file_972_fft_masked.tif
# Processed 91 file_973.tif, saved FFT and masked result to 91 file_973_fft_masked.tif
# Processed 91 file_974.tif, saved FFT and masked result to 91 file_974_fft_masked.tif
# Processed 91 file_975.tif, saved FFT and masked result to 91 file_975_fft_masked.tif
# Processed 91 file_976.tif, saved FFT and masked result to 91 file_976_fft_masked.tif
# Processed 91 file_977.tif, saved FFT and masked result to 91 file_977_fft_masked.tif
# Processed 91 file_978.tif, saved FFT and masked result to 91 file_978_fft_masked.tif
# Processed 91 file_979.tif, saved FFT and masked result to 91 file_979_fft_masked.tif
# Processed 91 file_98.tif, saved FFT and masked result to 91 file_98_fft_masked.tif
# Processed 91 file_980.tif, saved FFT and masked result to 91 file_980_fft_masked.tif
# Processed 91 file_981.tif, saved FFT and masked result to 91 file_981_fft_masked.tif
# Processed 91 file_982.tif, saved FFT and masked result to 91 file_982_fft_masked.tif
# Processed 91 file_983.tif, saved FFT and masked result to 91 file_983_fft_masked.tif
# Processed 91 file_984.tif, saved FFT and masked result to 91 file_984_fft_masked.tif
# Processed 91 file_985.tif, saved FFT and masked result to 91 file_985_fft_masked.tif
# Processed 91 file_986.tif, saved FFT and masked result to 91 file_986_fft_masked.tif
# Processed 91 file_987.tif, saved FFT and masked result to 91 file_987_fft_masked.tif
# Processed 91 file_988.tif, saved FFT and masked result to 91 file_988_fft_masked.tif
# Processed 91 file_989.tif, saved FFT and masked result to 91 file_989_fft_masked.tif
# Processed 91 file_99.tif, saved FFT and masked result to 91 file_99_fft_masked.tif
# Processed 91 file_990.tif, saved FFT and masked result to 91 file_990_fft_masked.tif
# Processed 91 file_991.tif, saved FFT and masked result to 91 file_991_fft_masked.tif
# Processed 91 file_992.tif, saved FFT and masked result to 91 file_992_fft_masked.tif
# Processed 91 file_993.tif, saved FFT and masked result to 91 file_993_fft_masked.tif
# Processed 91 file_994.tif, saved FFT and masked result to 91 file_994_fft_masked.tif
# Processed 91 file_995.tif, saved FFT and masked result to 91 file_995_fft_masked.tif
# Processed 91 file_996.tif, saved FFT and masked result to 91 file_996_fft_masked.tif
# Processed 91 file_997.tif, saved FFT and masked result to 91 file_997_fft_masked.tif
# Processed 91 file_998.tif, saved FFT and masked result to 91 file_998_fft_masked.tif
# Processed 91 file_999.tif, saved FFT and masked result to 91 file_999_fft_masked.tif
